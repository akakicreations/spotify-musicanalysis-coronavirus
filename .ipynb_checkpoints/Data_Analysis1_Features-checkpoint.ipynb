# %% [markdown]
# # Data Analysis - First Exploration

# %% [markdown]
# ## Cargando dataset y preparación inicial

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# Configuración Jupyter
pd.set_option('display.max_columns', None)
sns.set_style("darkgrid")

# Cargamos el dataframe final de extracción, donde están todas las canciones
data_ana_corona = pd.read_csv("data_global_coronaperiod.csv", sep = ',', parse_dates=['release_date_year'])
print('Tamaño inicial: ',data_ana_corona.shape)

# Quitamos algunas columnas que no usaremos y sobran
data_ana_corona = data_ana_corona.drop(columns=['Unnamed: 0', 'Position'])
print('Tamaño quitando columnas que sobran: ', data_ana_corona.shape)

# Quitamos los duplicados por canciones, no nos sirven de momento para los análisis
data_ana_corona = data_ana_corona.drop_duplicates(subset='spotify_id').copy()
print('Tamaño sin duplicados de canciones: ', data_ana_corona.shape)

# Para analizar teniendo en cuenta los streams totales y que esté ponderado, calculamos los pesos de cada canción respecto a los streams totales
# Importante hacerlo una vez quitados los duplicados
# Versión optimizada corta y sin warnings

data_ana_corona_2020 = data_ana_corona.loc[data_ana_corona['year'] == 2020]
data_ana_corona_2019 = data_ana_corona.loc[data_ana_corona['year'] == 2019]
data_ana_corona_2018 = data_ana_corona.loc[data_ana_corona['year'] == 2018]
data_ana_corona_2017 = data_ana_corona.loc[data_ana_corona['year'] == 2017]

data_ana_corona.loc[data_ana_corona.year == 2020,
                    'streamstotal_weights'] = data_ana_corona_2020['Streamstotal']/data_ana_corona_2020['Streamstotal'].sum()
data_ana_corona.loc[data_ana_corona.year == 2019,
                    'streamstotal_weights'] = data_ana_corona_2019['Streamstotal']/data_ana_corona_2019['Streamstotal'].sum()
data_ana_corona.loc[data_ana_corona.year == 2018,
                    'streamstotal_weights'] = data_ana_corona_2018['Streamstotal']/data_ana_corona_2018['Streamstotal'].sum()
data_ana_corona.loc[data_ana_corona.year == 2017, 
                    'streamstotal_weights'] = data_ana_corona_2017['Streamstotal']/data_ana_corona_2017['Streamstotal'].sum()

# COMPROBACIONES: Deberían sumar 1 los pesos de cada año
print('Peso 2020: ', data_ana_corona.loc[data_ana_corona['year'] == 2020, 'streamstotal_weights'].sum())
print('Peso 2019: ', data_ana_corona.loc[data_ana_corona['year'] == 2019, 'streamstotal_weights'].sum())
print('Peso 2018: ', data_ana_corona.loc[data_ana_corona['year'] == 2018, 'streamstotal_weights'].sum())
print('Peso 2017: ', data_ana_corona.loc[data_ana_corona['year'] == 2017, 'streamstotal_weights'].sum())

#Ver cómo sale
data_ana_corona[data_ana_corona['Track Name'] == 'Punto G']

#Revisamos los tipos de datos:
data_ana_corona.info()
# Out:
# Tamaño inicial:  (48066, 38)
# Tamaño quitando columnas que sobran:  (48066, 36)
# Tamaño sin duplicados de canciones:  (1581, 36)
# Peso 2020:  1.0
# Peso 2019:  0.9999999999999999
# Peso 2018:  1.0
# Peso 2017:  1.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1581 entries, 0 to 48064
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Track Name            1581 non-null   object
#  1   Artist                1581 non-null   object
#  2   Streams               1581 non-null   int64
#  3   date                  1581 non-null   object
#  4   spotify_id            1581 non-null   object
#  5   year                  1581 non-null   int64
#  6   Streamstotal          1581 non-null   int64
#  7   album                 1581 non-null   object
#  8   release_date          1581 non-null   object
#  9   length                1581 non-null   float64
#  10  popularity            1581 non-null   float64
#  11  acousticness          1581 non-null   float64
#  12  danceability          1581 non-null   float64
#  13  energy                1581 non-null   float64
#  14  instrumentalness      1581 non-null   float64
#  15  liveness              1581 non-null   float64
#  16  loudness              1581 non-null   float64
#  17  speechiness           1581 non-null   float64
#  18  valence               1581 non-null   float64
#  19  tempo                 1581 non-null   float64
#  20  time_signature        1581 non-null   int64
#  21  release_date_year     1581 non-null   datetime64[ns]
#  22  genre1                1567 non-null   object
#  23  genre2                1365 non-null   object
#  24  genre3                1095 non-null   object
#  25  genre4                680 non-null    object
#  26  genre5                434 non-null    object
#  27  genre6                217 non-null    object
#  28  genre7                96 non-null     object
#  29  genre8                39 non-null     object
#  30  genre9                13 non-null     object
#  31  genre10               2 non-null      object
#  32  genres_together       1567 non-null   object
#  33  artist_id             1581 non-null   object
#  34  artist_followers      1581 non-null   int64
#  35  artist_popularity     1581 non-null   float64
#  36  streamstotal_weights  1581 non-null   float64
# dtypes: datetime64[ns](1), float64(13), int64(5), object(18)
# memory usage: 469.4+ KB

# %%
'''# Cargamos el dataframe final de extracción, donde están todas las canciones, con duplicados (los hemos dejado
# por si utilizamos en algún momento la columna position)
data_ana = pd.read_csv("data_global_all.csv", sep = ',', parse_dates=['release_year'])
print('Tamaño inicial: ',data_ana.shape)

########## IMPORTANTE!!!!!!: Selecciono solo datos de un periodo
data_ana = data_ana[data_ana['Period'] == 'CoronaPeriod']
data_ana = data_ana[data_ana['Period'] == 'NormalPeriod']
print('Tamaño con solo un periodo: ', data_ana.shape)'''
# Out:
#   File "<ipython-input-91-4813b3252293>", line 7
#     '''data_ana = data_ana[data_ana['Period'] == 'CoronaPeriod']'''
#        ^
# SyntaxError: invalid syntax

# %%
data_ana_corona.sample(2)
# Out:
#            Track Name           Artist  Streams        date  \
# 14711          Vuelve  Sebastian Yatra    43358  2019-03-13
# 45530  Nadie ha dicho    Laura Pausini    22415  2018-03-20
#
#                    spotify_id  year  Streamstotal         album release_date  \
# 14711  6WSAPEkvEfcEUgSTAo1D3S  2019       1179362        Vuelve   2018-09-28
# 45530  2rNymvxE1VQxsPcCaQrOFj  2018         22415  Hazte sentir   2018-03-15
#
#          length  popularity  acousticness  danceability  energy  \
# 14711  0.384087        0.63         0.559         0.716   0.474
# 45530  0.343743        0.50         0.563         0.516   0.573
#
#        instrumentalness  liveness  loudness  speechiness  valence     tempo  \
# 14711               0.0     0.135  0.798687     0.041691    0.302  0.102658
# 45530               0.0     0.102  0.835555     0.021859    0.139  0.450181
#
#        time_signature release_date_year         genre1       genre2  \
# 14711               4        2018-01-01  colombian pop        latin
# 45530               4        2018-01-01        europop  italian pop
#
#           genre3                genre4     genre5       genre6       genre7  \
# 14711  reggaeton  reggaeton colombiano        NaN          NaN          NaN
# 45530      latin       latin arena pop  latin pop  mexican pop  spanish pop
#
#       genre8 genre9 genre10  \
# 14711    NaN    NaN     NaN
# 45530    NaN    NaN     NaN
#
#                                          genres_together  \
# 14711  colombian pop,latin,reggaeton,reggaeton colomb...
# 45530  europop,italian pop,latin,latin arena pop,lati...
#
#                     artist_id  artist_followers  artist_popularity  \
# 14711  07YUOmWljBTXwIseAUd9TW          12856027           0.868687
# 45530  2e4nwiX8ZCU09LGLOpeqTH           1519013           0.737374
#
#        streamstotal_weights
# 14711              0.001265
# 45530              0.000032

# %% [markdown]
# # First exploration

# %% [markdown]
# En el siguiente gráfico vemos que en el aumento de streamstotales en progresivo en años, esto puede significar que se usaba menos Spotify en años anteriores, o que según pasan los años se escuchan más veces las canciones del top200, en vez de otras. Como la idea es que en nuestros análisis se usen datos ponderados respecto al año, esperamos que no afecten.

# %%
data_ana_corona.groupby(['year']).sum()
sns.barplot(x="year", y="Streamstotal", data=data_ana_corona)

# %% [markdown]
# Si hacemos un conteo del número de canciones únicas por año. De primeras es curioso que el 2019 tenga menos canciones únicas en el top200.

# %%
data_ana_corona.groupby(['year']).count()
# Out:
#       Track Name  Artist  Streams  date  spotify_id  Streamstotal  album  \
# year
# 2017         384     384      384   384         384           384    384
# 2018         401     401      401   401         401           401    401
# 2019         372     372      372   372         372           372    372
# 2020         424     424      424   424         424           424    424
#
#       release_date  length  popularity  acousticness  danceability  energy  \
# year
# 2017           384     384         384           384           384     384
# 2018           401     401         401           401           401     401
# 2019           372     372         372           372           372     372
# 2020           424     424         424           424           424     424
#
#       instrumentalness  liveness  loudness  speechiness  valence  tempo  \
# year
# 2017               384       384       384          384      384    384
# 2018               401       401       401          401      401    401
# 2019               372       372       372          372      372    372
# 2020               424       424       424          424      424    424
#
#       time_signature  release_date_year  genre1  genre2  genre3  genre4  \
# year
# 2017             384                384     380     350     276     223
# 2018             401                401     399     363     303     206
# 2019             372                372     372     325     251     153
# 2020             424                424     416     327     265      98
#
#       genre5  genre6  genre7  genre8  genre9  genre10  genres_together  \
# year
# 2017     176      92      38      21       7        1              380
# 2018     112      52      21      10       5        1              399
# 2019      90      49      30       6       1        0              372
# 2020      56      24       7       2       0        0              416
#
#       artist_id  artist_followers  artist_popularity  streamstotal_weights
# year
# 2017        384               384                384                   384
# 2018        401               401                401                   401
# 2019        372               372                372                   372
# 2020        424               424                424                   424

# %% [markdown]
# Ojo, puede ocurrir que una misma canción de un artista se repita, porque está en el top200 dos años diferentes y albunes diferentes (por ejemplo, si se ha hecho un recopilatorio otro año). He decidido ignorarlo porque va a afectar poco en los análisis

# %%
data_ana_corona[data_ana_corona['Artist'] == 'KAROL G']
# Out:
#               Track Name   Artist  Streams        date  \
# 0                   Tusa  KAROL G   432730  2020-03-13
# 61                Follow  KAROL G   152745  2020-04-02
# 102               Créeme  KAROL G    75552  2019-03-13
# 153            Culpables  KAROL G    56202  2019-03-13
# 204              Punto G  KAROL G    51826  2019-04-05
# 232              Punto G  KAROL G   122406  2019-05-03
# 242               Créeme  KAROL G    64151  2019-05-03
# 252  Love With A Quality  KAROL G    46140  2019-05-03
# 253            Culpables  KAROL G    41255  2019-05-03
# 263                Ocean  KAROL G    31994  2019-05-03
# 273            Pineapple  KAROL G    45888  2018-03-13
# 334              La Dama  KAROL G    22573  2018-03-13
# 365              Mi Cama  KAROL G    39209  2018-05-11
# 367               A Ella  KAROL G    20711  2017-05-06
#
#                  spotify_id  year  Streamstotal        album release_date  \
# 0    7k4t7uLgtOxPwTpFmtJNTY  2020      19082982         Tusa   2019-11-07
# 61   2w1rq80FIrbxeJy9WYURxw  2020       6900319       Follow   2020-04-01
# 102  1mT47pKLXUwPYGwB91GcNz  2019       3272814       Créeme   2018-11-02
# 153  6q8Lb50EtqNeeJXXe8mMAH  2019       2136436    Culpables   2018-09-14
# 204  5Lb1pjnll07UQKxNpnnGBy  2019       1930173      Punto G   2019-04-05
# 232  2E82gORVSA7UMEz5M1IP3b  2019       1151711        OCEAN   2019-05-03
# 242  4EKZsrsCKyqr64FBHLc0DU  2019        600475        OCEAN   2019-05-03
# 252  6F9DPkjP6Tbz9FLgLyYgX6  2019         46140        OCEAN   2019-05-03
# 253  4RGKft6YTTWHjpQeRIInuS  2019        362564        OCEAN   2019-05-03
# 263  6qoIFQfdmaQF9A1gb67tR7  2019        541126        OCEAN   2019-05-03
# 273  24snQ8Ew7aIKYCt0ulXHvx  2018       3523304    Pineapple   2018-03-02
# 334  18Lf9mbzkZnQDjksUhpIqY  2018        717355  Unstoppable   2017-10-27
# 365  7sFYVcKSb24qg0dAkqLEFj  2018         84725      Mi Cama   2018-05-11
# 367  3nqrj9bM1clIkejk7BVPtX  2017        145958       A Ella   2017-05-05
#
#        length  popularity  acousticness  danceability  energy  \
# 0    0.324972        0.91       0.29500         0.803   0.715
# 61   0.330442        0.78       0.66700         0.735   0.787
# 102  0.354546        0.73       0.15400         0.715   0.872
# 153  0.390787        0.70       0.27900         0.728   0.801
# 204  0.275291        0.62       0.00796         0.787   0.751
# 232  0.279327        0.63       0.00938         0.791   0.746
# 242  0.359162        0.67       0.12600         0.715   0.874
# 252  0.383438        0.62       0.06460         0.849   0.752
# 253  0.396773        0.61       0.28700         0.728   0.812
# 263  0.209542        0.74       0.93300         0.727   0.482
# 273  0.266983        0.00       0.05080         0.782   0.671
# 334  0.344050        0.00       0.12200         0.842   0.771
# 365  0.197885        0.64       0.22200         0.826   0.815
# 367  0.319228        0.00       0.23100         0.727   0.795
#
#      instrumentalness  liveness  loudness  speechiness  valence     tempo  \
# 0            0.000134    0.0574  0.911425     0.397800    0.574  0.258160
# 61           0.000006    0.0721  0.875476     0.198031    0.455  0.711901
# 102          0.000146    0.1100  0.904169     0.045599    0.682  0.230459
# 153          0.000005    0.1430  0.922521     0.065287    0.416  0.451744
# 204          0.000139    0.0857  0.863559     0.091633    0.926  0.691617
# 232          0.000117    0.1250  0.864281     0.097713    0.905  0.691837
# 242          0.000162    0.1050  0.901707     0.045744    0.652  0.230833
# 252          0.000003    0.1060  0.895798     0.177765    0.586  0.257712
# 253          0.000003    0.1300  0.920059     0.087001    0.418  0.451544
# 263          0.000000    0.3880  0.815791     0.132889    0.487  0.083410
# 273          0.000002    0.3880  0.861031     0.056167    0.667  0.217377
# 334          0.000167    0.0967  0.825870     0.248697    0.750  0.250837
# 365          0.000070    0.0964  0.862410     0.093080    0.680  0.672321
# 367          0.000012    0.1310  0.856500     0.284887    0.584  0.797175
#
#      time_signature release_date_year genre1     genre2                genre3  \
# 0                 4        2019-01-01  latin  reggaeton  reggaeton colombiano
# 61                4        2020-01-01  latin  reggaeton  reggaeton colombiano
# 102               4        2018-01-01  latin  reggaeton  reggaeton colombiano
# 153               4        2018-01-01  latin  reggaeton  reggaeton colombiano
# 204               4        2019-01-01  latin  reggaeton  reggaeton colombiano
# 232               4        2019-01-01  latin  reggaeton  reggaeton colombiano
# 242               4        2019-01-01  latin  reggaeton  reggaeton colombiano
# 252               4        2019-01-01  latin  reggaeton  reggaeton colombiano
# 253               4        2019-01-01  latin  reggaeton  reggaeton colombiano
# 263               4        2019-01-01  latin  reggaeton  reggaeton colombiano
# 273               4        2018-01-01  latin  reggaeton  reggaeton colombiano
# 334               4        2017-01-01  latin  reggaeton  reggaeton colombiano
# 365               4        2018-01-01  latin  reggaeton  reggaeton colombiano
# 367               4        2017-01-01  latin  reggaeton  reggaeton colombiano
#
#     genre4 genre5 genre6 genre7 genre8 genre9 genre10  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 61     NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 102    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 153    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 204    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 232    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 242    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 252    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 253    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 263    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 273    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 334    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 365    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 367    NaN    NaN    NaN    NaN    NaN    NaN     NaN
#
#                           genres_together               artist_id  \
# 0    latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 61   latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 102  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 153  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 204  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 232  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 242  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 252  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 253  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 263  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 273  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 334  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 365  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 367  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
#
#      artist_followers  artist_popularity  streamstotal_weights
# 0            11614405           0.888889              0.017033
# 61           11614405           0.888889              0.006159
# 102          11614405           0.888889              0.003510
# 153          11614405           0.888889              0.002291
# 204          11614405           0.888889              0.002070
# 232          11614405           0.888889              0.001235
# 242          11614405           0.888889              0.000644
# 252          11614405           0.888889              0.000049
# 253          11614405           0.888889              0.000389
# 263          11614405           0.888889              0.000580
# 273          11614405           0.888889              0.005006
# 334          11614405           0.888889              0.001019
# 365          11614405           0.888889              0.000120
# 367          11614405           0.888889              0.000345

# %% [markdown]
# # Pregunta 1: ¿Ha cambiado la cantidad de música que se escucha en spotify?

# %% [markdown]
# Se puede confirmar que sí, pero cuidado, porque puede ocurrir que spotify lo escuchaba menos gente o que la gente escuchaba más variedad (hay que acordarse que los datos son del top200, toda la música que no esté en el top200 se queda fuera)

# %%
data_ana_streams = data_ana_corona.loc[:, ['year', 'Streamstotal']]
data_year_streams = data_ana_streams.groupby(['year']).sum()
data_year_streams.reset_index(inplace=True)
data_year_streams

sns.barplot(x="year", y="Streamstotal", data=data_year_streams)

# %% [markdown]
# # Pregunta 2: ¿Han cambiado las features entre diferentes años?

# %% [markdown]
# Llamamos Features a las características de cada canción y que nos dan información de ella. En la web de Spotify explica qué significa cada feature: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/
#
# Lo primero es ver una aproximación de las medias sin ponderar de las features, a ver si tienen sentido. Parece que sí, y todas están entre 0 y 1 como hicimos anteriormente.

# %%
data_ana_corona.groupby(['year']).mean()
# Out:
#            Streams  Streamstotal    length  popularity  acousticness  \
# year
# 2017  32552.799479  1.102343e+06  0.372746    0.382943      0.206352
# 2018  42820.713217  1.755079e+06  0.346084    0.385411      0.225762
# 2019  62737.709677  2.506742e+06  0.355486    0.580484      0.268883
# 2020  83626.903302  2.642391e+06  0.334065    0.720236      0.244129
#
#       danceability    energy  instrumentalness  liveness  loudness  \
# year
# 2017      0.686312  0.700550          0.006757  0.171757  0.831946
# 2018      0.693599  0.680849          0.005902  0.163658  0.834129
# 2019      0.706296  0.665688          0.014216  0.169047  0.828403
# 2020      0.715670  0.674739          0.007978  0.156612  0.836419
#
#       speechiness   valence     tempo  time_signature  artist_followers  \
# year
# 2017     0.099106  0.584369  0.377991        3.989583      1.226693e+07
# 2018     0.114026  0.542164  0.397529        3.980050      9.245774e+06
# 2019     0.145917  0.569583  0.412505        3.981183      9.157973e+06
# 2020     0.142219  0.592751  0.408719        3.976415      7.301560e+06
#
#       artist_popularity  streamstotal_weights
# year
# 2017           0.807634              0.002604
# 2018           0.799768              0.002494
# 2019           0.805691              0.002688
# 2020           0.808200              0.002358

# %% [markdown]
# Ploteamos algunas medias de una feature concreta (sin ponderar) para ver qué se ve, y podemos ver algunas tendencias, eso sí, ligeras

# %%
data_features_means_nopon = data_ana_corona.groupby(['year']).mean()
data_features_means_nopon.reset_index(inplace=True)

x_years = data_features_means_nopon["year"]

fig, ax = plt.subplots()
ax.bar(x_years,data_features_means_nopon["energy"], color="lightblue", zorder=0)
# sns.regplot(x=x, y=y, ax=ax)
ax.plot(x_years, data_features_means_nopon["energy"])
ax.set_ylim(0, None)
plt.show()

'''fig, axs = plt.subplots(3)
fig.suptitle('Comparative')
axs[0].plot(data_year_means["year"], data_year_means["energy"])
axs[1].plot(data_year_means["year"], data_year_means["danceability"])
axs[2].plot(data_year_means["year"], data_year_means["valence"])'''

fig, axs = plt.subplots(2, 2)
fig.set_size_inches(20, 8)
axs[0, 0].plot(x_years, data_features_means_nopon["energy"])
axs[0, 0].set_title('Energy')
axs[0, 1].plot(x_years, data_features_means_nopon["danceability"], 'tab:orange')
axs[0, 1].set_title('Danceability')
axs[1, 0].plot(x_years, data_features_means_nopon["valence"], 'tab:green')
axs[1, 0].set_title('Valence')
axs[1, 1].plot(x_years, data_features_means_nopon["acousticness"], 'tab:red')
axs[1, 1].set_title('Acousticness')
# Out:
# Text(0.5, 1.0, 'Acousticness')

# %% [markdown]
# Pero antes de analizar nada vamos a ponderar los datos a ver si hay diferencia. Para ello hemos hecho una función para calcular las medias ponderadas de cada feature por años, para poner en gráficos fácilmente después

# %%
 def mediapon_features (feature):
    data_dance_compar = data_ana_corona.loc[:, ['year', feature, 'streamstotal_weights']]
    data_dance_compar["mean_pon_" + feature] = data_dance_compar[feature] * data_dance_compar['streamstotal_weights']
    media_dance_compar = data_dance_compar.groupby(['year']).sum()
    media_dance_compar.reset_index(inplace=True)
    media_dance_compar = media_dance_compar.drop(columns=[feature])
    return media_dance_compar

# Prueba con danceability
media_dance_pon = mediapon_features ('danceability')
sns.barplot(x="year", y="mean_pon_danceability", data=media_dance_pon)

# %% [markdown]
# Hacemos la comparación a ver si hay diferencias. Hay una diferencia sutil, pero que en algunos casos puede variar la tendencia, por lo que haremos la ponderación de todas las features.

# %%
# Comparar medias sin y con ponderación
comparar_pon_ysinpon = pd.merge(data_features_means_nopon, media_dance_pon, how='right', on="year")
comparar_pon_ysinpon = comparar_pon_ysinpon[['year', 'danceability', 'mean_pon_danceability']]

#Hago un melt de la tabla porque quiero comparar
comparar_pon_ysinpon2 = pd.melt(comparar_pon_ysinpon,
        id_vars = ['year'],
       value_vars = ['danceability', "mean_pon_danceability"],
       value_name = 'media_danceability')

list_x = ['2017_sinpon', '2018_sinpon', '2019_sinpon', '2020_sinpon', '2017_pon', '2018_pon', '2019_pon', '2020_pon']
comparar_pon_ysinpon2['yearandmedia'] = list_x
comparar_pon_ysinpon2 =  comparar_pon_ysinpon2.drop(columns=['variable', 'year'])
comparar_pon_ysinpon2 = comparar_pon_ysinpon2.sort_values('yearandmedia')

fig, (ax1) = plt.subplots(ncols=1, figsize=(10, 8))
ax1.set_title('Comparative')
sns.barplot(x="yearandmedia", y ='media_danceability', data=comparar_pon_ysinpon2)

# %% [markdown]
# Ahora vamos a plotear todas las features para ver su tendencia con la ponderación hecha, pero vamos a aprovechar esta visualización y añadimos los datos para comparar el PERIODO PANDEMIA y eL PERIODO NORMAL. Para ello hacemos lo mismo que hemos hecho en las celdas anteriores pero con el PERIODO NORMAL
#
# **Features:**
# 'length'
# 'popularity'
# 'acousticness'
# 'danceability'
# 'energy'
# 'instrumentalness'
# 'liveness'
# 'loudness'
# 'speechiness'
# 'valence'
# 'tempo'

# %%
# EXTRAER DATOS DE PERIODO NORMAL

# Cargamos el dataframe final de extracción, donde están todas las canciones
data_ana_normal = pd.read_csv("data_global_normalperiod.csv", sep = ',', parse_dates=['release_date_year'])
print('Tamaño inicial: ',data_ana_normal.shape)

# Quitamos algunas columnas que no usaremos y sobran
data_ana_normal = data_ana_normal.drop(columns=['Unnamed: 0', 'Position'])
print('Tamaño quitando columnas que sobran: ', data_ana_normal.shape)

# Quitamos los duplicados por canciones, no nos sirven de momento para los análisis
data_ana_normal = data_ana_normal.drop_duplicates(subset='spotify_id').copy()
print('Tamaño sin duplicados de canciones: ', data_ana_normal.shape)

# Para analizar teniendo en cuenta los streams totales y que esté ponderado, calculamos los pesos de cada canción respecto a los streams totales
# Importante hacerlo una vez quitados los duplicados
# Versión optimizada corta y sin warnings

data_ana_normal_2020 = data_ana_normal.loc[data_ana_normal['year'] == 2020]
data_ana_normal_2019 = data_ana_normal.loc[data_ana_normal['year'] == 2019]
data_ana_normal_2018 = data_ana_normal.loc[data_ana_normal['year'] == 2018]
data_ana_normal_2017 = data_ana_normal.loc[data_ana_normal['year'] == 2017]

data_ana_normal.loc[data_ana_normal.year == 2020, 'streamstotal_weights'] = data_ana_normal_2020['Streamstotal']/data_ana_normal_2020['Streamstotal'].sum()
data_ana_normal.loc[data_ana_normal.year == 2019, 'streamstotal_weights'] = data_ana_normal_2019['Streamstotal']/data_ana_normal_2019['Streamstotal'].sum()
data_ana_normal.loc[data_ana_normal.year == 2018, 'streamstotal_weights'] = data_ana_normal_2018['Streamstotal']/data_ana_normal_2018['Streamstotal'].sum()
data_ana_normal.loc[data_ana_normal.year == 2017, 'streamstotal_weights'] = data_ana_normal_2017['Streamstotal']/data_ana_normal_2017['Streamstotal'].sum()

# COMPROBACIONES: Deberían sumar 1 los pesos de cada año
print('Peso 2020: ', data_ana_normal.loc[data_ana_normal['year'] == 2020, 'streamstotal_weights'].sum())
print('Peso 2019: ', data_ana_normal.loc[data_ana_normal['year'] == 2019, 'streamstotal_weights'].sum())
print('Peso 2018: ', data_ana_normal.loc[data_ana_normal['year'] == 2018, 'streamstotal_weights'].sum())
print('Peso 2017: ', data_ana_normal.loc[data_ana_normal['year'] == 2017, 'streamstotal_weights'].sum())

#Ver cómo sale
data_ana_normal[data_ana_normal['Track Name'] == 'Punto G']


# Exportamos un archivo CSV el resultado para tenerlo ya listo en otros análisis
data_ana_normal.to_csv("data_ana_normalperiod.csv", sep = ',')

#Revisamos los tipos de datos:
print(data_ana_normal.info())
data_ana_normal.head(2)
# Out:
# Tamaño inicial:  (48059, 39)
# Tamaño quitando columnas que sobran:  (48059, 37)
# Tamaño sin duplicados de canciones:  (1559, 37)
# Peso 2020:  1.0
# Peso 2019:  1.0
# Peso 2018:  1.0
# Peso 2017:  1.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1559 entries, 0 to 48058
# Data columns (total 38 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Track Name            1559 non-null   object
#  1   Artist                1559 non-null   object
#  2   Streams               1559 non-null   int64
#  3   date                  1559 non-null   object
#  4   spotify_id            1559 non-null   object
#  5   year                  1559 non-null   int64
#  6   Streamstotal          1559 non-null   int64
#  7   album                 1559 non-null   object
#  8   release_date          1559 non-null   object
#  9   length                1559 non-null   float64
#  10  popularity            1559 non-null   float64
#  11  acousticness          1559 non-null   float64
#  12  danceability          1559 non-null   float64
#  13  energy                1559 non-null   float64
#  14  instrumentalness      1559 non-null   float64
#  15  liveness              1559 non-null   float64
#  16  loudness              1559 non-null   float64
#  17  speechiness           1559 non-null   float64
#  18  valence               1559 non-null   float64
#  19  tempo                 1559 non-null   float64
#  20  time_signature        1559 non-null   int64
#  21  release_date_year     1559 non-null   datetime64[ns]
#  22  genre1                1535 non-null   object
#  23  genre2                1371 non-null   object
#  24  genre3                1063 non-null   object
#  25  genre4                657 non-null    object
#  26  genre5                392 non-null    object
#  27  genre6                213 non-null    object
#  28  genre7                94 non-null     object
#  29  genre8                42 non-null     object
#  30  genre9                18 non-null     object
#  31  genre10               3 non-null      object
#  32  genres_together       1535 non-null   object
#  33  artist_id             1559 non-null   object
#  34  artist_followers      1559 non-null   int64
#  35  artist_popularity     1559 non-null   float64
#  36  Period                1559 non-null   object
#  37  streamstotal_weights  1559 non-null   float64
# dtypes: datetime64[ns](1), float64(13), int64(5), object(19)
# memory usage: 475.0+ KB
# None
# /Users/victormac/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (30,31,32,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Track Name   Artist  Streams        date              spotify_id  year  \
# 0        Tusa  KAROL G   432554  2020-01-08  7k4t7uLgtOxPwTpFmtJNTY  2020
# 62      Ocean  KAROL G    29680  2020-01-19  6qoIFQfdmaQF9A1gb67tR7  2020
#
#     Streamstotal  album release_date    length  popularity  acousticness  \
# 0       33218824   Tusa   2019-11-07  0.370381    0.957895         0.295
# 62         90300  OCEAN   2019-05-03  0.262716    0.778947         0.933
#
#     danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0          0.803   0.715          0.000134    0.0574  0.910438     0.520652
# 62         0.727   0.482          0.000000    0.3880  0.814908     0.173930
#
#     valence     tempo  time_signature release_date_year genre1     genre2  \
# 0     0.574  0.294453               4        2019-01-01  latin  reggaeton
# 62    0.487  0.128252               4        2019-01-01  latin  reggaeton
#
#                   genre3 genre4 genre5 genre6 genre7 genre8 genre9 genre10  \
# 0   reggaeton colombiano    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 62  reggaeton colombiano    NaN    NaN    NaN    NaN    NaN    NaN     NaN
#
#                          genres_together               artist_id  \
# 0   latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 62  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
#
#     artist_followers  artist_popularity        Period  streamstotal_weights
# 0           11614405           0.888889  NormalPeriod              0.028869
# 62          11614405           0.888889  NormalPeriod              0.000078

# %% [markdown]
# Preparamos los datos y rehago la función para poder sacar también el periodo NORMAL

# %%
# Rehago la función
def mediapon_features (feature, dataframe_period):
    media_compar = dataframe_period.loc[:, ['year', feature, 'streamstotal_weights']]
    media_compar["mean_pon_" + feature] = media_compar[feature] * media_compar['streamstotal_weights']
    media_compar = media_compar.groupby(['year']).sum()
    media_compar.reset_index(inplace=True)
    media_compar = media_compar.drop(columns=[feature])
    return media_compar

# %%
features = ['length',
            'popularity',
            'acousticness',
            'danceability',
            'energy',
            'instrumentalness',
            'liveness',
            'loudness',
            'speechiness',
            'valence',
            'tempo']

# Creo un diccionario para meter todos los dataframes con los datos ponderados
dic_features_means_corona = {}
for x in features:
    dic_features_means_corona[x] = mediapon_features (x, data_ana_corona)
    
dic_features_means_normal = {}
for x in features:
    dic_features_means_normal[x] = mediapon_features (x, data_ana_normal)
    
    
media_length_corona = dic_features_means_corona['length']['mean_pon_length']
media_popularity_corona = dic_features_means_corona['popularity']['mean_pon_popularity']
media_acousticness_corona = dic_features_means_corona['acousticness']['mean_pon_acousticness']
media_danceability_corona = dic_features_means_corona['danceability']['mean_pon_danceability']
media_energy_corona = dic_features_means_corona['energy']['mean_pon_energy']
media_instrumentalness_corona = dic_features_means_corona['instrumentalness']['mean_pon_instrumentalness']
media_liveness_corona = dic_features_means_corona['liveness']['mean_pon_liveness']
media_loudness_corona = dic_features_means_corona['loudness']['mean_pon_loudness']
media_speechiness_corona = dic_features_means_corona['speechiness']['mean_pon_speechiness']
media_valence_corona = dic_features_means_corona['valence']['mean_pon_valence']
media_tempo_corona = dic_features_means_corona['tempo']['mean_pon_tempo']

media_length_normal = dic_features_means_normal ['length']['mean_pon_length']
media_popularity_normal  = dic_features_means_normal ['popularity']['mean_pon_popularity']
media_acousticness_normal  = dic_features_means_normal ['acousticness']['mean_pon_acousticness']
media_danceability_normal  = dic_features_means_normal ['danceability']['mean_pon_danceability']
media_energy_normal  = dic_features_means_normal ['energy']['mean_pon_energy']
media_instrumentalness_normal  = dic_features_means_normal ['instrumentalness']['mean_pon_instrumentalness']
media_liveness_normal  = dic_features_means_normal ['liveness']['mean_pon_liveness']
media_loudness_normal  = dic_features_means_normal ['loudness']['mean_pon_loudness']
media_speechiness_normal  = dic_features_means_normal ['speechiness']['mean_pon_speechiness']
media_valence_normal  = dic_features_means_normal ['valence']['mean_pon_valence']
media_tempo_normal  = dic_features_means_normal ['tempo']['mean_pon_tempo']

# %% [markdown]
# Ploteamos todos los gráficos para ver la tendencia

# %%
x_years = dic_features_means_corona['length']['year']

fig, axs = plt.subplots(4, 3)
fig.set_size_inches(20, 12)

graph_1 = axs[0, 0]
graph_1.plot(x_years, media_length_corona,label='Corona Period', color = 'orange') # PERIODO CORONA
graph_1.plot(x_years, media_length_normal,label='Normal Period', color = 'grey') # PERIODO NORMAL
graph_1.scatter(x_years, media_length_corona)
graph_1.scatter(x_years, media_length_normal)
graph_1.set_title('length')
graph_1.legend()

graph_2 = axs[0, 1]
graph_2.plot(x_years, media_popularity_corona,label='Corona Period', color = 'orange')
graph_2.plot(x_years, media_popularity_normal,label='Normal Period', color = 'grey')
graph_2.scatter(x_years, media_popularity_corona)
graph_2.scatter(x_years, media_popularity_normal)
graph_2.set_title('popularity')
graph_2.legend()

graph_3 = axs[0, 2]
graph_3.plot(x_years, media_acousticness_corona,label='Corona Period', color = 'orange')
graph_3.plot(x_years, media_acousticness_normal,label='Normal Period', color = 'grey')
graph_3.scatter(x_years, media_acousticness_corona)
graph_3.scatter(x_years, media_acousticness_normal)
graph_3.set_title('acousticness')
graph_3.legend()

graph_4 = axs[1, 0]
graph_4.plot(x_years, media_danceability_corona,label='Corona Period', color = 'orange')
graph_4.plot(x_years, media_danceability_normal,label='Normal Period', color = 'grey')
graph_4.scatter(x_years, media_danceability_corona)
graph_4.scatter(x_years, media_danceability_normal)
graph_4.set_title('danceability')
graph_4.legend()

graph_5 = axs[1, 1]
graph_5.plot(x_years, media_energy_corona,label='Corona Period', color = 'orange')
graph_5.plot(x_years, media_danceability_normal,label='Normal Period', color = 'grey')
graph_5.scatter(x_years, media_energy_corona)
graph_5.scatter(x_years, media_danceability_normal)
graph_5.set_title('energy')
graph_5.legend()

graph_6 = axs[1, 2]
graph_6.plot(x_years, media_instrumentalness_corona,label='Corona Period', color = 'orange')
graph_6.plot(x_years, media_instrumentalness_normal,label='Normal Period', color = 'grey')
graph_6.scatter(x_years, media_instrumentalness_corona)
graph_6.scatter(x_years, media_instrumentalness_normal)
graph_6.set_title('instrumentalness')
graph_6.legend()

graph_7 = axs[2, 0]
graph_7.plot(x_years, media_liveness_corona,label='Corona Period', color = 'orange')
graph_7.plot(x_years, media_liveness_normal,label='Normal Period', color = 'grey')
graph_7.scatter(x_years, media_liveness_corona)
graph_7.scatter(x_years, media_liveness_normal)
graph_7.set_title('liveness')
graph_7.legend()

graph_8 = axs[2, 1]
graph_8.plot(x_years, media_loudness_corona,label='Corona Period', color = 'orange')
graph_8.plot(x_years, media_loudness_normal,label='Normal Period', color = 'grey')
graph_8.scatter(x_years, media_loudness_corona)
graph_8.scatter(x_years, media_loudness_normal)
graph_8.set_title('loudness')
graph_8.legend()

graph_9 = axs[2, 2]
graph_9.plot(x_years, media_valence_corona,label='Corona Period', color = 'orange')
graph_9.plot(x_years, media_valence_normal,label='Normal Period', color = 'grey')
graph_9.scatter(x_years, media_valence_corona)
graph_9.scatter(x_years, media_valence_normal)
graph_9.set_title('valence')
graph_9.legend()


graph_10 = axs[3, 0]
graph_10.plot(x_years, media_speechiness_corona,label='Corona Period', color = 'orange')
graph_10.plot(x_years, media_speechiness_normal,label='Normal Period', color = 'grey')
graph_10.scatter(x_years, media_speechiness_corona)
graph_10.scatter(x_years, media_speechiness_normal)
graph_10.set_title('speechiness')
graph_10.legend()

graph_11 = axs[3, 1]
graph_11.plot(x_years, media_tempo_corona,label='Corona Period', color = 'orange')
graph_11.plot(x_years, media_tempo_normal,label='Normal Period', color = 'grey')
graph_11.scatter(x_years, media_tempo_corona)
graph_11.scatter(x_years, media_tempo_normal)
graph_11.set_title('tempo')
graph_11.legend()

# %% [markdown]
# # Análisis feature por feature

# %% [markdown]
# ### >>> Length
#
#
# - **Feature**: Mide la longitud de las canciones
# - **Tendencia**: Se ve que que la tendencia es que la longitud de las canciones más escuchadas sean cada vez más cortas.
# - **Antes y después**: Se ve que las canciones más escuchadas durante la pandemia son más cortas.
# - **Preguntas**:

# %%
media_length = mediapon_features ('length', data_ana)
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_length", data=media_length, ax=axs[0])
sns.regplot(x="year", y="mean_pon_length", data=media_length, ax=axs[1])

media_length = mediapon_features ('length', data_ana_normal)
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_length", data=media_length, ax=axs[0])
sns.regplot(x="year", y="mean_pon_length", data=media_length, ax=axs[1])

# %% [markdown]
# ### >>> Popularity
#
# - **Feature**: Mide la popularidad de la canción, según unos álculos de Spotify
# - **Tendencia**: Se ve que que la tendencia es que se escuchen canciones que son más populares, pero es lógico si están dentro del top200, así que no nos aporta nada.

# %%
media_popularity = mediapon_features ('popularity')
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_popularity", data=media_popularity, ax=axs[0])
sns.regplot(x="year", y="mean_pon_popularity", data=media_popularity, ax=axs[1])

# %% [markdown]
# ### >>> acousticness
#
# - **Feature**: ¿Cuánto de acústica es una canción?
# - **Tendencia**:
# - **Antes y después**: Parece que hubo una vuelta atrás, donde se escuchan más canciones acústicas en la pandemia que en años anteriores.
# - **Preguntas**:

# %%
media_acousticness = mediapon_features ('acousticness')
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_acousticness", data=media_acousticness, ax=axs[0])
sns.regplot(x="year", y="mean_pon_acousticness", data=media_acousticness, ax=axs[1])

# %% [markdown]
# ### >>> danceability
#
# - **Feature**: ¿Cuánto de bailable es la canción?
# - **Tendencia**:
# - **Antes y después**: Parece que hubo una vuelta atrás, donde se escuchan más canciones acústicas en la pandemia que en años anteriores.
# - **Preguntas**:

# %%
media_danceability = mediapon_features ('danceability')
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_danceability", data=media_danceability, ax=axs[0])
sns.regplot(x="year", y="mean_pon_danceability", data=media_danceability, ax=axs[1])

# %% [markdown]
# ### >>> energy
#
# - **Feature**: Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale.
# - **Tendencia**:
# - **Antes y después**: Parece que hubo una vuelta atrás, donde se escuchan más canciones acústicas en la pandemia que en años anteriores.
# - **Preguntas**:

# %%
media_energy = mediapon_features ('energy')
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_energy", data=media_energy, ax=axs[0])
sns.regplot(x="year", y="mean_pon_energy", data=media_energy, ax=axs[1])

# %% [markdown]
# ### >>> Instrumentalness
#
# - **Feature**:
# - **Tendencia**:
# - **Antes y después**:
# - **Preguntas**:

# %%
media_instrumentalness = mediapon_features ('instrumentalness')
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_instrumentalness", data=media_instrumentalness, ax=axs[0])
sns.regplot(x="year", y="mean_pon_instrumentalness", data=media_instrumentalness, ax=axs[1])

# %% [markdown]
# ### >>> liveness

# %%
media_liveness = mediapon_features ('liveness')
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_liveness", data=media_liveness, ax=axs[0])
sns.regplot(x="year", y="mean_pon_liveness", data=media_liveness, ax=axs[1])

# %% [markdown]
# ### >>> loudness

# %%
media_loudness = mediapon_features ('loudness')
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_loudness", data=media_loudness, ax=axs[0])
sns.regplot(x="year", y="mean_pon_loudness", data=media_loudness, ax=axs[1])

# %% [markdown]
# ### >>> speechiness

# %%
media_speechiness = mediapon_features ('speechiness')
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_speechiness", data=media_speechiness, ax=axs[0])
sns.regplot(x="year", y="mean_pon_speechiness", data=media_speechiness, ax=axs[1])

# %% [markdown]
# ### >>> valence

# %%
media_valence = mediapon_features ('valence')
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_valence", data=media_valence, ax=axs[0])
sns.regplot(x="year", y="mean_pon_valence", data=media_valence, ax=axs[1])

# %% [markdown]
# ### >>> tempo

# %%
media_tempo = mediapon_features ('tempo')
fig, axs = plt.subplots(ncols=2)
fig.set_figheight(6)
fig.set_figwidth(17)
sns.barplot(x="year", y="mean_pon_tempo", data=media_tempo, ax=axs[0])
sns.regplot(x="year", y="mean_pon_tempo", data=media_tempo, ax=axs[1])
