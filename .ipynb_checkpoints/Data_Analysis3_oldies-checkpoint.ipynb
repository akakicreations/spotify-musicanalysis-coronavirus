# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Primeras aproximaciones de análisis

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# Configuración Jupyter
pd.set_option('display.max_columns', None)
sns.set_style("darkgrid")

# Cargamos el dataframe final de extracción, donde están todas las canciones, con duplicados (los hemos dejado
# por si utilizamos en algún momento la columna position)
data_ana = pd.read_csv("data_global_final.csv", sep = ',', parse_dates=['release_year'])
print('Tamaño inicial: ',data_ana.shape)
# Out:
# Tamaño inicial:  (1581, 38)

# %% [markdown]
# # Oldies analysis

# %% [markdown]
# ## ¿Ha cambiado la antiguedad de la música que se escucha?, ¿hemos esuchado más clasicos?

# %% [markdown]
# - Poner en columna año.
# - Ver distribución de años.
# - Nueva columna con rangos de años.

# %%
#Ver la distribución, quitando las fechas anteriores a 2014, que son muy pocas
data_old = data_ana.groupby(['year', 'release_year']).sum()
data_old.reset_index(inplace=True)
data_old = data_old[['year', 'release_year', 'Streamstotal']]

fecha_1 = datetime.datetime(1959, 1, 1)
fecha_2 = datetime.datetime(2014, 1, 1)
fecha_3 = datetime.datetime(2020, 1, 1)

data_old_2014_2020 = data_old[data_old.release_year.between(fecha_2, fecha_3)]

sns.factorplot(x='year', y='Streamstotal', hue='release_year', data=data_old_2014_2020, kind='bar')

# %%
# Número de canciones anteriores a 2014 en cada año
data_old_1959_2014 = data_old[data_old.release_year.between(fecha_1, fecha_2)]
sns.factorplot(x='year', y='Streamstotal', hue='release_year', data=data_old_1959_2014, kind='bar')

# %%
# Número de canciones anteriores a 2014 agrupadas en años
data_old_1959_2014 = data_old_1959_2014.groupby('year').sum()
data_old_1959_2014.plot()

# %%
# Para agrupar los años antiguos y sumar sus StreamsTotales, PROBANDO

fecha_1 = datetime.datetime(1959, 1, 1)
fecha_2 = datetime.datetime(2014, 1, 1)
fecha_3 = datetime.datetime(2020, 1, 1)

data_old_2017 = data_old[data_old['year'] == 2017]
data_old_2018 = data_old[data_old['year'] == 2018]
data_old_2019 = data_old[data_old['year'] == 2019]
data_old_2020 = data_old[data_old['year'] == 2020]

data_old_2017[data_old_2017.release_year.between(fecha_1, fecha_2)].sum()
data_old_2017
# Out:
#    year release_year  Streamstotal
# 0  2017   1959-01-01         38999
# 1  2017   1975-01-01         15080
# 2  2017   1987-01-01         19621
# 3  2017   2012-01-01         34703
# 4  2017   2013-01-01       1131383
# 5  2017   2014-01-01        667462
# 6  2017   2015-01-01      19458068
# 7  2017   2016-01-01     198199016
# 8  2017   2017-01-01     203735234

# %%
# Para ver 

fecha_1 = datetime.datetime(1959, 1, 1)
fecha_2 = datetime.datetime(2014, 1, 1)
fecha_3 = datetime.datetime(2020, 1, 1)

data_old = data_ana.groupby(['year', 'release_year']).sum()
data_old.reset_index(inplace=True)
data_old = data_old[['year', 'release_year', 'Streamstotal']]
data_old


data_old_2017 = data_old[data_old['year'] == 2017]
data_old_2017 = data_old_2017[data_old.release_year.between(fecha_2, fecha_3)]

data_old_2018 = data_old[data_old['year'] == 2018]
data_old_2018 = data_old_2018[data_old.release_year.between(fecha_2, fecha_3)]

data_old_2019 = data_old[data_old['year'] == 2019]
data_old_2019 = data_old_2019[data_old.release_year.between(fecha_2, fecha_3)]

data_old_2020 = data_old[data_old['year'] == 2020]
data_old_2020 = data_old_2020[data_old.release_year.between(fecha_2, fecha_3)]


sns.barplot(x="release_year", y="Streamstotal", data=data_old_2017)
sns.barplot(x="release_year", y="Streamstotal", data=data_old_2018)
sns.barplot(x="release_year", y="Streamstotal", data=data_old_2019)
sns.barplot(x="release_year", y="Streamstotal", data=data_old_2020)
# Out:
# <ipython-input-9-d8aaad94fc52>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_old_2017 = data_old_2017[data_old.release_year.between(fecha_2, fecha_3)]
# <ipython-input-9-d8aaad94fc52>:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_old_2018 = data_old_2018[data_old.release_year.between(fecha_2, fecha_3)]
# <ipython-input-9-d8aaad94fc52>:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_old_2019 = data_old_2019[data_old.release_year.between(fecha_2, fecha_3)]
# <ipython-input-9-d8aaad94fc52>:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_old_2020 = data_old_2020[data_old.release_year.between(fecha_2, fecha_3)]

# %%
# ¿Qué canciones antiguas se han escuchado más durante la pandemia y los otros años?
data_songs_old = data_ana[data_ana.release_year.between(fecha_1959, fecha_2014)]
data_songs_old_2020 = data_songs_old[data_songs_old['year'] == 2020]
data_songs_old_2020
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4149093b83e4> in <module>
#       1 # ¿Qué canciones antiguas se han escuchado más durante la pandemia y los otros años?
# ----> 2 data_songs_old = data_ana[data_ana.release_year.between(fecha_1959, fecha_2014)]
#       3 data_songs_old_2020 = data_songs_old[data_songs_old['year'] == 2020]
#       4 data_songs_old_2020
#
# NameError: name 'fecha_1959' is not defined

# %%
# Hago un conteo de las canciones por Release date
data_old = data_ana.groupby(['release_year','year']).count()
data_old.reset_index(inplace=True)
data_old = data_old[['year', 'release_year', 'Track Name']]

#Saco las canciones que se lanzaron entre 1959 y 2014 y que se escucharon en cada año
fecha_1959 = datetime.datetime(1959, 1, 1)
fecha_2014 = datetime.datetime(2014, 1, 1)
data_songs_old = data_ana[data_ana.release_year.between(fecha_1959, fecha_2014)]

# Cuento las canciones antiguas por año
songs_count = data_songs_old.groupby(['year']).count()
songs_count = songs_count['Track Name']
songs_count

'''data_old.loc[data_old.release_year == '1959-01-01', 'Track Name'] = songs_count.iloc[0]
data_old.loc[data_old.release_year == '1959-01-01', 'Track Name'] = songs_count.iloc[0]
data_old.drop(data_old.index[[1,3]])
data_old'''
# Out:
# "data_old.loc[data_old.release_year == '1959-01-01', 'Track Name'] = songs_count.iloc[0]\ndata_old.loc[data_old.release_year == '1959-01-01', 'Track Name'] = songs_count.iloc[0]\ndata_old.drop(data_old.index[[1,3]])\ndata_old"
