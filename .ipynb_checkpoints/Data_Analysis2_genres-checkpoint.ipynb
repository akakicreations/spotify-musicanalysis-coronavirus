# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Cargando dataset y preparación

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# Configuración Jupyter
pd.set_option('display.max_columns', None)
sns.set_style("darkgrid")

# Cargamos el dataframe ya limpio desde el análisis de Features
data_ana_corona = pd.read_csv("data_ana_coronaperiod.csv", sep = ',', parse_dates=['release_date_year'])
data_ana_corona = data_ana_corona.drop(columns=['Unnamed: 0'])

print('Tamaño inicial: ',data_ana_corona.shape)
data_ana_corona.sample(2)
# Out:
# Tamaño inicial:  (1581, 37)
#                            Track Name    Artist  Streams        date  \
# 177  Lo Malo - Operación Triunfo 2017    Aitana    42778  2019-03-13
# 81                           Amarillo  J Balvin   619574  2020-03-20
#
#                  spotify_id  year  Streamstotal  \
# 177  7aJP1XcWcSU9w0eqSvaeZR  2019       2391024
# 81   6zEgnpM0qYmHLDnh8WPejL  2020      17463083
#
#                                 album release_date    length  popularity  \
# 177  Lo Malo (Operación Triunfo 2017)   2018-01-28  0.278917        0.53
# 81                            Colores   2020-03-19  0.214125        0.85
#
#      acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 177         0.648         0.766   0.737           0.00000    0.3490  0.930926
# 81          0.013         0.641   0.857           0.00534    0.0695  0.831156
#
#      speechiness  valence     tempo  time_signature release_date_year  \
# 177     0.058193    0.964  0.217577               4        2018-01-01
# 81      0.402142    0.961  0.402763               5        2020-01-01
#
#         genre1             genre2                genre3 genre4 genre5 genre6  \
# 177  latin pop  latin talent show           spanish pop    NaN    NaN    NaN
# 81       latin          reggaeton  reggaeton colombiano    NaN    NaN    NaN
#
#     genre7 genre8 genre9 genre10                          genres_together  \
# 177    NaN    NaN    NaN     NaN  latin pop,latin talent show,spanish pop
# 81     NaN    NaN    NaN     NaN     latin,reggaeton,reggaeton colombiano
#
#                   artist_id  artist_followers  artist_popularity  \
# 177  7eLcDZDYHXZCebtQmVFL25           1135957           0.767677
# 81   1vyhD5VmyZ7KMfW5gqLgo5          22079880           0.969697
#
#      streamstotal_weights
# 177              0.002564
# 81               0.015587

# %% [markdown]
# # Genres analysis

# %% [markdown]
# De los artistas hemos extraido los géneros en los que están clasificados en Spotify, que no nos dice solo uno, sino hasta 10 diferentes, lo que nos dificulta dsitinguir poeque algunos artistas tienen hasta 5 géneros asignados que pueden coincidir o no con otros artistas. Esto puede desvirtuar el análisis y dificultar la agrupación de estilos, porque si, por ejemplo, una canción puede tener como genre1 un género muy específico (ej. colombian pop) y está como el primero en la lista del artista, en vez de un género más general (ej. pop).
#
# En la extracción hemos metido cada género del artista en una columna para faciilitar los análisis (genre1, genre2, genre3...). Por si acaso, hemos dejado una columna con la lista completa.
#
# ((Fuente externa: Most popular genres:
# 1	☊	pop
# 2	☊	dance pop
# 3	☊	rap
# 4	☊	pop rap
# 5	☊	rock
# 6	☊	post-teen pop
# 7	☊	latin
# 8	☊	hip hop
# 9	☊	trap
# 10	☊	edm
# 11	☊	modern rock
# 12	☊	tropical house
# 13	☊	pop rock
# 14	☊	melodic rap
# 15	☊	reggaeton
# 16	☊	latin pop
# 17	☊	classic rock
# 18	☊	electropop
# 19	☊	mellow gold
# 20	☊	album rock
# http://everynoise.com/everynoise1d.cgi?vector=popularity&scope=all))

# %%
# Echamos un primer vistazo a las columnas
data_ana_corona[data_ana_corona['genre2'] =='latin'].head(3)
# Out:
#               Track Name   Artist  Streams        date  \
# 298  Coronao Now (Remix)  El Alfa    82555  2020-03-13
# 299                   4K  El Alfa    56099  2020-03-13
# 300          Coronao Now  El Alfa    46034  2020-03-13
#
#                  spotify_id  year  Streamstotal                album  \
# 298  047WmwIeerHyIUstFAEz5A  2020       3143292  Coronao Now (Remix)
# 299  4xI3U4sDj1TPmO9Iz5TkYp  2020       4475589                   4K
# 300  7FbKipScVxkjQxQXwTd0gL  2020        446298          Coronao Now
#
#     release_date    length  popularity  acousticness  danceability  energy  \
# 298   2020-02-12  0.451159        0.71         0.255         0.883   0.853
# 299   2020-03-12  0.326357        0.81         0.357         0.925   0.900
# 300   2019-11-07  0.368363        0.70         0.146         0.941   0.729
#
#      instrumentalness  liveness  loudness  speechiness  valence     tempo  \
# 298          0.000723     0.412  0.862410     0.209612    0.695  0.371194
# 299          0.005950     0.124  0.875936     0.174870    0.804  0.384744
# 300          0.004510     0.180  0.770913     0.322525    0.718  0.371348
#
#      time_signature release_date_year  genre1 genre2          genre3  \
# 298               4        2020-01-01  dembow  latin  rap dominicano
# 299               4        2020-01-01  dembow  latin  rap dominicano
# 300               4        2019-01-01  dembow  latin  rap dominicano
#
#         genre4    genre5 genre6 genre7 genre8 genre9 genre10  \
# 298  reggaeton  tropical    NaN    NaN    NaN    NaN     NaN
# 299  reggaeton  tropical    NaN    NaN    NaN    NaN     NaN
# 300  reggaeton  tropical    NaN    NaN    NaN    NaN     NaN
#
#                                     genres_together               artist_id  \
# 298  dembow,latin,rap dominicano,reggaeton,tropical  2oQX8QiMXOyuqbcZEFsZfm
# 299  dembow,latin,rap dominicano,reggaeton,tropical  2oQX8QiMXOyuqbcZEFsZfm
# 300  dembow,latin,rap dominicano,reggaeton,tropical  2oQX8QiMXOyuqbcZEFsZfm
#
#      artist_followers  artist_popularity  streamstotal_weights
# 298           1122213           0.838384              0.002806
# 299           1122213           0.838384              0.003995
# 300           1122213           0.838384              0.000398

# %%
# Vemos los artistas que más veces salen 
data_ana_corona.Artist.value_counts()
# Out:
# Bad Bunny        44
# J Balvin         31
# Ozuna            28
# C. Tangana       25
# Ed Sheeran       22
#                  ..
# Dayvi             1
# Vetusta Morla     1
# Denom             1
# Netta             1
# A R I Z O N A     1
# Name: Artist, Length: 452, dtype: int64

# %%
#Contamos el número de canciones para cada género analizando la columna genre1 y siguientes
number_genres = data_ana_corona.genre1.value_counts()
number_genres.head(60)
# Out:
# latin                        369
# dance pop                    201
# colombian pop                 83
# spanish pop                   65
# pop                           57
# trap espanol                  55
# cantautor                     54
# latin pop                     48
# latin arena pop               34
# big room                      31
# r&b en espanol                28
# canadian contemporary r&b     22
# spanish hip hop               22
# argentine hip hop             21
# canadian hip hop              19
# electropop                    19
# flamenco urbano               18
# reggaeton                     17
# modern rock                   15
# rap espanol                   14
# dominican pop                 13
# eurovision                    13
# dfw rap                       13
# boy band                      12
# conscious hip hop             12
# panamanian pop                11
# garage rock                   11
# champeta                      11
# canadian pop                  11
# trap latino                   10
# latin viral pop                9
# cubaton                        9
# puerto rican pop               9
# emo rap                        9
# bachata                        9
# dembow                         9
# electro latino                 9
# k-pop                          8
# edm                            8
# atl hip hop                    7
# latin talent show              7
# rap                            7
# electro house                  7
# classic rock                   6
# australian dance               6
# art pop                        6
# alternative r&b                6
# carnaval cadiz                 6
# reggaeton flow                 6
# brostep                        5
# colombian hip hop              4
# melodic rap                    4
# hip hop                        4
# pop rap                        4
# funk carioca                   4
# rumba                          3
# danish pop                     3
# rap catala                     3
# reggaeton colombiano           3
# new french touch               3
# Name: genre1, dtype: int64

# %% [markdown]
# Tras analizar los valores principales, vemos que el género "latin" es muy ambiguo y no nos ayuda a grupa, por lo que decido que para depurar el género definitivo, a los que en el genre1 sea "latin", se les asignará el valor en genre2, que es más específico y los que el genre1 no sea latin se les asignara ese genre1. También si en el genre2 es "latin pop", que se seleccione el genre3

# %%
data_ana_nolatinfirst = data_ana_corona[data_ana_corona['genre1'] != 'latin']
data_ana_latinfirst = data_ana_corona[data_ana_corona['genre1'] == 'latin']

data_ana_corona.loc[data_ana_corona.genre1 == 'latin', 'genre_final'] = data_ana_latinfirst['genre2']
data_ana_corona.loc[data_ana_corona.genre2 == 'latin pop', 'genre_final'] = data_ana_latinfirst['genre3']
data_ana_corona.loc[data_ana_corona.genre1 != 'latin', 'genre_final'] = data_ana_nolatinfirst['genre1']

data_ana_corona.shape
# Out:
# (1581, 38)

# %%
# Vemos cómo queda ahora distribuidos los géneros y se ve algo más claro, quitando el "latin"
number_genres_new = data_ana_corona.genre_final.value_counts()
number_genres_new.head(60)
# Out:
# dance pop                    201
# reggaeton                    152
# latin hip hop                 92
# colombian pop                 83
# latin arena pop               76
# spanish pop                   70
# trap espanol                  58
# pop                           57
# cantautor                     54
# latin pop                     48
# puerto rican pop              47
# r&b en espanol                41
# big room                      31
# canadian contemporary r&b     22
# spanish hip hop               22
# argentine hip hop             21
# canadian hip hop              19
# electropop                    19
# flamenco urbano               18
# reggaeton flow                18
# modern rock                   15
# rap espanol                   14
# eurovision                    13
# dfw rap                       13
# dominican pop                 13
# conscious hip hop             12
# boy band                      12
# garage rock                   11
# panamanian pop                11
# champeta                      11
# canadian pop                  11
# latin viral pop               11
# trap latino                   10
# electro latino                 9
# dembow                         9
# cubaton                        9
# emo rap                        9
# bachata                        9
# k-pop                          8
# edm                            8
# pop reggaeton                  8
# latin talent show              7
# electro house                  7
# atl hip hop                    7
# rap                            7
# alternative r&b                6
# carnaval cadiz                 6
# australian dance               6
# classic rock                   6
# art pop                        6
# brostep                        5
# colombian hip hop              4
# rap latina                     4
# melodic rap                    4
# pop venezolano                 4
# hip hop                        4
# funk carioca                   4
# pop rap                        4
# perreo                         3
# reggaeton colombiano           3
# Name: genre_final, dtype: int64

# %% [markdown]
# Tras un análisis por géneros, vemos que es complicado agrupar por elevado número de géneros y porque el primer género del listado de cada artista no distingue bien.
#
# Entonces la idea seria hacer nosotros la agrupación seleccionando los géneros que puedan agrupar mejor y además evitando errores y teniendo en cuenta no sólo el primero género sino los siguientes.
#
# El método para sacar el género final ha sido recoger el genre1 como principal pero obviando otros como latin. Es decir, si hacemos una revisión de genre1 y se encuentra latin, pasamos a seleccionar el género de genre2 y así sucesivamente.
#
# Se ha decidido elegir los siguientes géneros: POP, DANCEPOP, ROCK, RAP, CANTAUTOR Y REGAETTON. Evidentemente este es un agrupamiento subjetivo y teniendo en cuanto los géneros que aparece más en genre1 y que podemos distinguir fácilmente entre ellos. Por ejemplo, "reggaeton" podría entrar tambien en "dance", pero se ha decidido separarlo por el volumen menciones a este géneros y se ha agrupado con similares.

# %%
# Grupos de géneros:
list_genres_pop = 'pop, k-pop, boy band, eurovision, carnaval'
list_genres_dance = 'dance, tropical, edm, electropop, big room'
list_genres_rock = 'rock, indie'
list_genres_reggaeton = 'dembow, reggaeton, champeta, cubaton'
list_genres_rap = "rap, hip hop, funk, trap, r&b"
cantautor = 'cantautor, flamenco'

# %%
print(data_ana_corona.shape)
data_ana_corona.head(2)
# Out:
# (1581, 38)
#   Track Name   Artist  Streams        date              spotify_id  year  \
# 0       Tusa  KAROL G   432730  2020-03-13  7k4t7uLgtOxPwTpFmtJNTY  2020
# 1     Follow  KAROL G   152745  2020-04-02  2w1rq80FIrbxeJy9WYURxw  2020
#
#    Streamstotal   album release_date    length  popularity  acousticness  \
# 0      19082982    Tusa   2019-11-07  0.324972        0.91         0.295
# 1       6900319  Follow   2020-04-01  0.330442        0.78         0.667
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.803   0.715          0.000134    0.0574  0.911425     0.397800
# 1         0.735   0.787          0.000006    0.0721  0.875476     0.198031
#
#    valence     tempo  time_signature release_date_year genre1     genre2  \
# 0    0.574  0.258160               4        2019-01-01  latin  reggaeton
# 1    0.455  0.711901               4        2020-01-01  latin  reggaeton
#
#                  genre3 genre4 genre5 genre6 genre7 genre8 genre9 genre10  \
# 0  reggaeton colombiano    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 1  reggaeton colombiano    NaN    NaN    NaN    NaN    NaN    NaN     NaN
#
#                         genres_together               artist_id  \
# 0  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 1  latin,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
#
#    artist_followers  artist_popularity  streamstotal_weights genre_final
# 0          11614405           0.888889              0.017033   reggaeton
# 1          11614405           0.888889              0.006159   reggaeton

# %%
data_ana_corona['genre_depurated'] = pd.np.where(data_ana_corona.genre_final.str.contains("dance"), 'dance',
                              pd.np.where(data_ana_corona.genre_final.str.contains("tropical"), 'dance',            
                              pd.np.where(data_ana_corona.genre_final.str.contains("edm"), 'dance',
                              pd.np.where(data_ana_corona.genre_final.str.contains("electropop"), 'dance',
                              pd.np.where(data_ana_corona.genre_final.str.contains("big room"), 'dance',
                                          
                              pd.np.where(data_ana_corona.genre_final.str.contains("pop"), 'pop',
                              pd.np.where(data_ana_corona.genre_final.str.contains("k-pop"), 'pop',
                              pd.np.where(data_ana_corona.genre_final.str.contains("carnaval"), 'pop',                      
                              pd.np.where(data_ana_corona.genre_final.str.contains("eurovision"), 'pop',
                              pd.np.where(data_ana_corona.genre_final.str.contains("boy band"), 'pop',
                        
                              pd.np.where(data_ana_corona.genre_final.str.contains("rock"), 'rock',            
                              pd.np.where(data_ana_corona.genre_final.str.contains("indie"), 'rock',
                                          
                              pd.np.where(data_ana_corona.genre_final.str.contains("bachata"), 'reggaeton',                               
                              pd.np.where(data_ana_corona.genre_final.str.contains("dembow"), 'reggaeton',            
                              pd.np.where(data_ana_corona.genre_final.str.contains("reggaeton"), 'reggaeton',            
                              pd.np.where(data_ana_corona.genre_final.str.contains("champeta"), 'reggaeton',
                              pd.np.where(data_ana_corona.genre_final.str.contains("cubaton"), 'reggaeton',
                                          
                              pd.np.where(data_ana_corona.genre_final.str.contains("hip hop"), 'hip hop',            
                              pd.np.where(data_ana_corona.genre_final.str.contains("rap"), 'hip hop',            
                              pd.np.where(data_ana_corona.genre_final.str.contains("funk"), 'hip hop',            
                              pd.np.where(data_ana_corona.genre_final.str.contains("trap"), 'hip hop',            
                              pd.np.where(data_ana_corona.genre_final.str.contains("r&b"), 'hip hop',
                                          
                              pd.np.where(data_ana_corona.genre_final.str.contains("cantautor"), 'cantautor',            
                              pd.np.where(data_ana_corona.genre_final.str.contains("flamenco"), 'cantautor',            
                                    
                                          "other"))))))))))))))))))))))))
data_ana_corona[data_ana_corona['genre_final'] == 'dembow']
# Out:
# <ipython-input-14-803531ff09b6>:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   data_ana_corona['genre_depurated'] = pd.np.where(data_ana_corona.genre_final.str.contains("dance"), 'dance',
# <ipython-input-14-803531ff09b6>:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("tropical"), 'dance',
# <ipython-input-14-803531ff09b6>:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("edm"), 'dance',
# <ipython-input-14-803531ff09b6>:4: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("electropop"), 'dance',
# <ipython-input-14-803531ff09b6>:5: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("big room"), 'dance',
# <ipython-input-14-803531ff09b6>:7: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("pop"), 'pop',
# <ipython-input-14-803531ff09b6>:8: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("k-pop"), 'pop',
# <ipython-input-14-803531ff09b6>:9: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("carnaval"), 'pop',
# <ipython-input-14-803531ff09b6>:10: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("eurovision"), 'pop',
# <ipython-input-14-803531ff09b6>:11: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("boy band"), 'pop',
# <ipython-input-14-803531ff09b6>:13: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("rock"), 'rock',
# <ipython-input-14-803531ff09b6>:14: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("indie"), 'rock',
# <ipython-input-14-803531ff09b6>:16: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("bachata"), 'reggaeton',
# <ipython-input-14-803531ff09b6>:17: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("dembow"), 'reggaeton',
# <ipython-input-14-803531ff09b6>:18: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("reggaeton"), 'reggaeton',
# <ipython-input-14-803531ff09b6>:19: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("champeta"), 'reggaeton',
# <ipython-input-14-803531ff09b6>:20: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("cubaton"), 'reggaeton',
# <ipython-input-14-803531ff09b6>:22: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("hip hop"), 'hip hop',
# <ipython-input-14-803531ff09b6>:23: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("rap"), 'hip hop',
# <ipython-input-14-803531ff09b6>:24: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("funk"), 'hip hop',
# <ipython-input-14-803531ff09b6>:25: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("trap"), 'hip hop',
# <ipython-input-14-803531ff09b6>:26: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("r&b"), 'hip hop',
# <ipython-input-14-803531ff09b6>:28: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("cantautor"), 'cantautor',
# <ipython-input-14-803531ff09b6>:29: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(data_ana_corona.genre_final.str.contains("flamenco"), 'cantautor',
#                Track Name            Artist  Streams        date  \
# 298   Coronao Now (Remix)           El Alfa    82555  2020-03-13
# 299                    4K           El Alfa    56099  2020-03-13
# 300           Coronao Now           El Alfa    46034  2020-03-13
# 380                 Rueda          Chimbala    68669  2020-03-13
# 381         Rueda - Remix          Chimbala    72331  2020-03-20
# 463    La Rubia - Remix 2  La Nueva Escuela    59557  2020-03-13
# 800                 Ellos       Ceky Viciny    34777  2020-03-17
# 801                 Ellos       Ceky Viciny    31018  2019-04-18
# 1072              Mujeres    Mozart La Para    46137  2019-03-13
#
#                   spotify_id  year  Streamstotal                album  \
# 298   047WmwIeerHyIUstFAEz5A  2020       3143292  Coronao Now (Remix)
# 299   4xI3U4sDj1TPmO9Iz5TkYp  2020       4475589                   4K
# 300   7FbKipScVxkjQxQXwTd0gL  2020        446298          Coronao Now
# 380   4NDHYPVJ5zLnR8yYZsMDsu  2020       3886123                Rueda
# 381   3EWxpqOSP0KWgUmRiklqGy  2020       5375648        Rueda (Remix)
# 463   7KKTnv81z6DmfPIGsZWjOW  2020       3262919             La Rubia
# 800   7bDboJVS7UlQBZj8lsvz2g  2020       1262764                Ellos
# 801   1tDUwlIyFFcmfMypYoQ4Ns  2019       1895505                Ellos
# 1072  6xLvYhLOW2oETJoZv8ChU8  2019       1882677              Mujeres
#
#      release_date    length  popularity  acousticness  danceability  energy  \
# 298    2020-02-12  0.451159        0.71         0.255         0.883   0.853
# 299    2020-03-12  0.326357        0.81         0.357         0.925   0.900
# 300    2019-11-07  0.368363        0.70         0.146         0.941   0.729
# 380    2019-07-19  0.349507        0.69         0.165         0.888   0.916
# 381    2020-03-19  0.354069        0.71         0.256         0.864   0.925
# 463    2019-04-19  0.350359        0.68         0.319         0.758   0.717
# 800    2019-07-05  0.258610        0.45         0.124         0.754   0.939
# 801    2019-03-11  0.258610        0.00         0.124         0.754   0.939
# 1072   2018-06-08  0.290882        0.61         0.204         0.835   0.767
#
#       instrumentalness  liveness  loudness  speechiness  valence     tempo  \
# 298           0.000723    0.4120  0.862410     0.209612    0.695  0.371194
# 299           0.005950    0.1240  0.875936     0.174870    0.804  0.384744
# 300           0.004510    0.1800  0.770913     0.322525    0.718  0.371348
# 380           0.000004    0.0519  0.947012     0.099884    0.960  0.451617
# 381           0.000009    0.0648  0.957420     0.072669    0.961  0.451744
# 463           0.000006    0.3780  0.881418     0.156051    0.753  0.316969
# 800           0.002810    0.2930  0.954990     0.022438    0.853  0.397939
# 801           0.002810    0.2930  0.954990     0.022438    0.853  0.397939
# 1072          0.000079    0.2610  0.832009     0.065721    0.710  0.250723
#
#       time_signature release_date_year  genre1         genre2          genre3  \
# 298                4        2020-01-01  dembow          latin  rap dominicano
# 299                4        2020-01-01  dembow          latin  rap dominicano
# 300                4        2019-01-01  dembow          latin  rap dominicano
# 380                4        2019-01-01  dembow  dominican pop           latin
# 381                4        2020-01-01  dembow  dominican pop           latin
# 463                4        2019-01-01  dembow  dominican pop             NaN
# 800                4        2019-01-01  dembow  dominican pop  rap dominicano
# 801                4        2019-01-01  dembow  dominican pop  rap dominicano
# 1072               4        2018-01-01  dembow  dominican pop  rap dominicano
#
#               genre4    genre5 genre6 genre7 genre8 genre9 genre10  \
# 298        reggaeton  tropical    NaN    NaN    NaN    NaN     NaN
# 299        reggaeton  tropical    NaN    NaN    NaN    NaN     NaN
# 300        reggaeton  tropical    NaN    NaN    NaN    NaN     NaN
# 380   rap dominicano       NaN    NaN    NaN    NaN    NaN     NaN
# 381   rap dominicano       NaN    NaN    NaN    NaN    NaN     NaN
# 463              NaN       NaN    NaN    NaN    NaN    NaN     NaN
# 800              NaN       NaN    NaN    NaN    NaN    NaN     NaN
# 801              NaN       NaN    NaN    NaN    NaN    NaN     NaN
# 1072             NaN       NaN    NaN    NaN    NaN    NaN     NaN
#
#                                      genres_together               artist_id  \
# 298   dembow,latin,rap dominicano,reggaeton,tropical  2oQX8QiMXOyuqbcZEFsZfm
# 299   dembow,latin,rap dominicano,reggaeton,tropical  2oQX8QiMXOyuqbcZEFsZfm
# 300   dembow,latin,rap dominicano,reggaeton,tropical  2oQX8QiMXOyuqbcZEFsZfm
# 380        dembow,dominican pop,latin,rap dominicano  4VVEpEhC8NcR7AqNEds42U
# 381        dembow,dominican pop,latin,rap dominicano  4VVEpEhC8NcR7AqNEds42U
# 463                             dembow,dominican pop  7mcJN2bWqCv7jvykgHp4KN
# 800              dembow,dominican pop,rap dominicano  5UopXhshFFqRIMfeZrBclq
# 801              dembow,dominican pop,rap dominicano  5UopXhshFFqRIMfeZrBclq
# 1072             dembow,dominican pop,rap dominicano  0odliLZMTk45CEVzF3Zocl
#
#       artist_followers  artist_popularity  streamstotal_weights genre_final  \
# 298            1122213           0.838384              0.002806      dembow
# 299            1122213           0.838384              0.003995      dembow
# 300            1122213           0.838384              0.000398      dembow
# 380             211273           0.696970              0.003469      dembow
# 381             211273           0.696970              0.004798      dembow
# 463              65164           0.565657              0.002912      dembow
# 800              63569           0.595960              0.001127      dembow
# 801              63569           0.595960              0.002033      dembow
# 1072            258213           0.696970              0.002019      dembow
#
#      genre_depurated
# 298        reggaeton
# 299        reggaeton
# 300        reggaeton
# 380        reggaeton
# 381        reggaeton
# 463        reggaeton
# 800        reggaeton
# 801        reggaeton
# 1072       reggaeton

# %%
prueba_data = data_ana_corona[data_ana_corona['year'] == 2017]
prueba_data['streamstotal_weights'].sum()
# Out:
# 1.0

# %%
number_genres2 = data_ana_corona.genre_depurated.value_counts()
number_genres2.head(60)
# Out:
# pop          507
# hip hop      395
# dance        288
# reggaeton    211
# cantautor     72
# other         68
# rock          40
# Name: genre_depurated, dtype: int64

# %%
#Total reproducciones 
data_group = data_ana_corona.groupby(['genre_depurated', 'year']).agg(['sum', 'count'])
data_group['streamstotal_weights']
#Falta hacerlo por ponderación con reproducciones
# Out:
#                            sum  count
# genre_depurated year
# cantautor       2017  0.012336     15
#                 2018  0.008848     15
#                 2019  0.013609     18
#                 2020  0.045138     24
# dance           2017  0.312284     95
#                 2018  0.196143     88
#                 2019  0.146720     63
#                 2020  0.070127     42
# hip hop         2017  0.169888     72
#                 2018  0.269737    113
#                 2019  0.274787     78
#                 2020  0.249741    132
# other           2017  0.052695     24
#                 2018  0.020286     15
#                 2019  0.037632     16
#                 2020  0.014187     13
# pop             2017  0.307635    126
#                 2018  0.355928    124
#                 2019  0.325328    136
#                 2020  0.297460    121
# reggaeton       2017  0.129028     36
#                 2018  0.143896     32
#                 2019  0.196564     54
#                 2020  0.319103     89
# rock            2017  0.016134     16
#                 2018  0.005163     14
#                 2019  0.005359      7
#                 2020  0.004244      3

# %%
data_group2 = data_group['Streamstotal']
data_group2.reset_index(inplace=True)
data_group2
# Out:
#    genre_depurated  year        sum  count
# 0        cantautor  2017    5221747     15
# 1        cantautor  2018    6227040     15
# 2        cantautor  2019   12690328     18
# 3        cantautor  2020   50571544     24
# 4            dance  2017  132189673     95
# 5            dance  2018  138042823     88
# 6            dance  2019  136817355     63
# 7            dance  2020   78568166     42
# 8          hip hop  2017   71913546     72
# 9          hip hop  2018  189837055    113
# 10         hip hop  2019  256241249     78
# 11         hip hop  2020  279802859    132
# 12           other  2017   22305926     24
# 13           other  2018   14277073     15
# 14           other  2019   35092157     16
# 15           other  2020   15894422     13
# 16             pop  2017  130221668    126
# 17             pop  2018  250497501    124
# 18             pop  2019  303371203    136
# 19             pop  2020  333266397    121
# 20       reggaeton  2017   54617542     36
# 21       reggaeton  2018  101271842     32
# 22       reggaeton  2019  183297902     54
# 23       reggaeton  2020  357515126     89
# 24            rock  2017    6829464     16
# 25            rock  2018    3633433     14
# 26            rock  2019    4997683      7
# 27            rock  2020    4755101      3

# %%
#Cálculo de los streams totales de cada género depurado

data_group = data_ana_corona.groupby(['genre_depurated', 'year']).agg(['sum', 'count'])
data_group2 = data_group['Streamstotal']
data_group2.reset_index(inplace=True)
sns.factorplot(x='year', y='sum', hue='genre_depurated', data=data_group2, kind='bar')
# Out:
# /Users/victormac/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Calculo de porcentajes para comparar por año, PONDERADO
# Habría que calcular el porcentaje respecto al total del año y comparar esos porcentaje entre años


#Para ello hemos creado una función para extraerlo más fácil donde se mete el año y el género:
def extract_percentage(year, genre):
    datos_ano = data_group2[data_group2['year'] == year]
    percentage = 100 * datos_ano[datos_ano['genre_depurated'] == genre].sum()[2]/ data_group2[data_group2['year'] == year].sum()[2]
    return [year, genre, percentage]

#Y otra función para crear el dataframe resultante por año
def create_df_year(year):
    list_genres = ['pop', 'dance', 'rock','reggaeton','hip hop','cantautor']
    data_1 = extract_percentage(year, list_genres[0])
    data_2 = extract_percentage(year, list_genres[1])
    data_3 = extract_percentage(year, list_genres[2])
    data_4 = extract_percentage(year, list_genres[3])
    data_5 = extract_percentage(year, list_genres[4])
    data_6 = extract_percentage(year, list_genres[5])   
    df_new = pd.DataFrame([data_1, data_2,data_3,data_4,data_5,data_6,], columns = ['year', 'genre', 'percentage'])
    return df_new

# Guardamos dataframes
data_genre_2017 = create_df_year(2017)
data_genre_2018 = create_df_year(2018)
data_genre_2019 = create_df_year(2019)
data_genre_2020 = create_df_year(2020)

# Juntar dataframes
data_genre_years = pd.concat([data_genre_2017, data_genre_2018, data_genre_2019, data_genre_2020])


#Hacer comparativa de géneros por años
data_genre_pop = data_years[data_years['genre'] == 'pop']
sns.catplot(x="year", y="percentage", data=data_genre_pop,
                height=6, kind="bar", palette="muted")

data_genre_regga = data_years[data_years['genre'] == 'reggaeton']
sns.catplot(x="year", y="percentage", data=data_genre_regga,
                height=6, kind="bar", palette="muted")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-9c33da058d42> in <module>
#      32
#      33 #Hacer comparativa de géneros por años
# ---> 34 data_genre_pop = data_years[data_years['genre'] == 'pop']
#      35 sns.catplot(x="year", y="percentage", data=data_genre_pop,
#      36                 height=6, kind="bar", palette="muted")
#
# NameError: name 'data_years' is not defined

# %%
#graficos pruebas

a = sns.catplot(x="year", y="percentage", hue="genre", data=data_genre_2017,
                height=6, kind="bar", palette="muted")
b = sns.catplot(x="year", y="percentage", hue="genre", data=data_genre_2018,
                height=6, kind="bar", palette="muted")

sns.set()
data_genre_2018.set_index('genre').T.plot(kind='bar', stacked=True)

# %%
data_group = data_ana_corona.groupby(['genre_depurated', 'year']).agg(['sum', 'count'])
data_group['Streamstotal']
# Out:
#                             sum  count
# genre_depurated year
# cantautor       2017    5221747     15
#                 2018    6227040     15
#                 2019   12690328     18
#                 2020   50571544     24
# dance           2017  132189673     95
#                 2018  138042823     88
#                 2019  136817355     63
#                 2020   78568166     42
# hip hop         2017   71913546     72
#                 2018  189837055    113
#                 2019  256241249     78
#                 2020  279802859    132
# other           2017   22305926     24
#                 2018   14277073     15
#                 2019   35092157     16
#                 2020   15894422     13
# pop             2017  130221668    126
#                 2018  250497501    124
#                 2019  303371203    136
#                 2020  333266397    121
# reggaeton       2017   54617542     36
#                 2018  101271842     32
#                 2019  183297902     54
#                 2020  357515126     89
# rock            2017    6829464     16
#                 2018    3633433     14
#                 2019    4997683      7
#                 2020    4755101      3

# %%
data_group3 = data_ana_corona.groupby(['genre1', 'year']).agg(['sum', 'count'])
data_group3['Streamstotal'].sort_values(by='count', ascending=False)
# Out:
#                                sum  count
# genre1             year
# latin              2020  461853472    120
#                    2019  348582112     98
#                    2018  262015291     78
# dance pop          2017  103763118     75
# latin              2017  111128475     73
# ...                            ...    ...
# danish pop         2019    2439041      1
# dancehall          2017    5726377      1
# czech pop          2018     108262      1
# cumbia             2018    1492895      1
# venezuelan hip hop 2020     764827      1
#
# [242 rows x 2 columns]

# %%
# volver a intentar probando!!!
data_group4 = data_ana_corona.groupby(['genre1', 'year']).agg(['sum', 'count'])
data_group3['Streamstotal'].sort_values(by='count', ascending=False)
# Out:
#                                sum  count
# genre1             year
# latin              2020  461853472    120
#                    2019  348582112     98
#                    2018  262015291     78
# dance pop          2017  103763118     75
# latin              2017  111128475     73
# ...                            ...    ...
# danish pop         2019    2439041      1
# dancehall          2017    5726377      1
# czech pop          2018     108262      1
# cumbia             2018    1492895      1
# venezuelan hip hop 2020     764827      1
#
# [242 rows x 2 columns]
