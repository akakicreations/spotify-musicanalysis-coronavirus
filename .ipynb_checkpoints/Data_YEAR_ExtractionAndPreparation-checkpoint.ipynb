# %% [markdown]
# # Data Extraction and Preparation YEARS ANALYSIS

# %% [markdown]
# IMPORTANTE: Se puede ejecutar todo, pero hay ciertos scripts que está en triples comillas porque solo es necesario ejecutarlo una vez (o que para obtener datos de  los dos periodos se utiliza una variante por fechas del mismo). Algunos scripts de Extracción de canciones tardan su tiempo, por eso en al carpeta raiz he dejado ya los CSV resultantes y un aviso en la celda para tenerlo en cuenta si se quiere ejecutar.
#
# **Todas las celdas que tardan en ejecutarse más tiempo están marcada con el tiempo de ejecución previamente**

# %% [markdown]
# # Extracción de canciones en top200

# %%
# INSTALAR PREVIAMENTE PARA EJECUTAR TODOS LOS NOTEBOOKS:
# !pip install fycharts
# !pip install spotipy
# !pip install altair vega_datasets
# !pip install seaborn

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import altair as alt

# Configuración visual
pd.set_option('display.max_columns', None)
sns.set_style("darkgrid")

# %% [markdown]
# He decidido seleccionar un periodo amplio para extraer todos los datos del top200, y más adelante seleccionado periodos concretos que me interesan, como el periodo pandemia o el periodo normal.

# %%
# Region seleccionada para extraer los datos:
region_select = ["es"]

# Datetimes de año 2017
fecha_inicial_2017= datetime(2017, 6, 3)
fecha_fin_2017 = datetime(2017, 12, 31)
out_file_db_2017 = "sqlite:///data_allyear/top_200_daily_YEAR2_{}.db".format(fecha_inicial_2017.year)
out_file_csv_2017 = "data_allyear/top_200_daily_CSV_YEAR2_{}.csv".format(fecha_inicial_2017.year)

# Datetimes de año 2018
fecha_inicial_2018= datetime(2018, 1, 1)
fecha_fin_2018 = datetime(2018, 12, 31)
out_file_db_2018 = "sqlite:///data_allyear/top_200_daily_YEARGLOBAL_{}.db".format(fecha_inicial_2018.year)
out_file_csv_2018 = "data_allyear/top_200_daily_CSV_YEARGLOBAL_{}.csv".format(fecha_inicial_2018.year)

# Datetimes de año 2019
fecha_inicial_2019= datetime(2019, 1, 1)
fecha_fin_2019 = datetime(2019, 12, 31)
out_file_db_2019 = "sqlite:///data_allyear/top_200_daily_YEARGLOBAL_{}.db".format(fecha_inicial_2019.year)
out_file_csv_2019 = "data_allyear/top_200_daily_CSV_YEARGLOBAL_{}.csv".format(fecha_inicial_2019.year)

# Datetimes de año 2020
fecha_inicial_2020= datetime(2020, 1, 1)
fecha_fin_2020 = datetime(2020, 12, 31)
out_file_db_2020 = "sqlite:///data_allyear/top_200_daily_YEARGLOBAL_{}.db".format(fecha_inicial_2020.year)
out_file_csv_2020 = "data_allyear/top_200_daily_CSV_YEARGLOBAL_{}.csv".format(fecha_inicial_2020.year)

print('Días totales seleccionados 2020:', fecha_fin_2020 - fecha_inicial_2020)
print('Días totales seleccionados 2019:', fecha_fin_2019 - fecha_inicial_2019)
print('Días totales seleccionados 2018:', fecha_fin_2018 - fecha_inicial_2018)
print('Días totales seleccionados 2017:', fecha_fin_2017 - fecha_inicial_2017)
# Out:
# Días totales seleccionados 2020: 365 days, 0:00:00
# Días totales seleccionados 2019: 364 days, 0:00:00
# Días totales seleccionados 2018: 364 days, 0:00:00
# Días totales seleccionados 2017: 211 days, 0:00:00

# %% [markdown]
# Creamos una función para extracción de canciones del top200 de todos los años y la extracción de los datos. No hace falta ejecutarlo porque tarda su tiempo. El resultado de este script son 4 datasets, uno por año, con las canciones y en columnas ciertas features básicas.
#
# Usaremos un paquete que te llama <a href="https://pypi.org/project/fycharts/" target="_blank">fycharts</a> que nos facilita la extracción de estos datos.

# %%
# Función para EXTRACCIÓN, sólo ejecutar una vez
'''

def extraction_tracks(fecha_inicial, fecha_final, region_select, out_file_db, out_file_csv):
    from fycharts.SpotifyCharts import SpotifyCharts
    import sqlalchemy
    
    api = SpotifyCharts()
    connector = sqlalchemy.create_engine(out_file_db, echo=False)
    api.top200Daily(output_file = out_file_csv, output_db = connector, webhook = "https://mywebhookssite.com/post/", 
                start = fecha_inicial, end = fecha_final, region = region_select)

# Extracción de canciones
# SOLO EJECUTAR UNA VEZ INICIAL, NO HACE FALTA VOLVER A EJECUTARLO Y SE GUARDAN LOS DATOS EN CSV EN LA RAÍZ, TARDA 7-10 MINUTOS.


Time1 = datetime.now()


extraction_tracks(fecha_inicial_2017.strftime('%Y-%m-%d'), fecha_fin_2017.strftime('%Y-%m-%d'),
                  region_select, out_file_db_2017, out_file_csv_2017)

                  
Time2 = datetime.now()

print("Tiempo ejecución:", Time2 -Time1)



extraction_tracks(fecha_inicial_2018.strftime('%Y-%m-%d'), fecha_fin_2018.strftime('%Y-%m-%d'),
                  region_select, out_file_db_2018, out_file_csv_2018)
extraction_tracks(fecha_inicial_2019.strftime('%Y-%m-%d'), fecha_fin_2019.strftime('%Y-%m-%d'),
                  region_select, out_file_db_2019, out_file_csv_2019)
extraction_tracks(fecha_inicial_2020.strftime('%Y-%m-%d'), fecha_fin_2020.strftime('%Y-%m-%d'),
                  region_select, out_file_db_2020, out_file_csv_2020)



'''
# Out:
# '\n\ndef extraction_tracks(fecha_inicial, fecha_final, region_select, out_file_db, out_file_csv):\n    from fycharts.SpotifyCharts import SpotifyCharts\n    import sqlalchemy\n    \n    api = SpotifyCharts()\n    connector = sqlalchemy.create_engine(out_file_db, echo=False)\n    api.top200Daily(output_file = out_file_csv, output_db = connector, webhook = "https://mywebhookssite.com/post/", \n                start = fecha_inicial, end = fecha_final, region = region_select)\n\n# Extracción de canciones\n# SOLO EJECUTAR UNA VEZ INICIAL, NO HACE FALTA VOLVER A EJECUTARLO Y SE GUARDAN LOS DATOS EN CSV EN LA RAÍZ, TARDA 7-10 MINUTOS.\n\n\nTime1 = datetime.now()\n\n\nextraction_tracks(fecha_inicial_2017.strftime(\'%Y-%m-%d\'), fecha_fin_2017.strftime(\'%Y-%m-%d\'),\n                  region_select, out_file_db_2017, out_file_csv_2017)\n\n                  \nTime2 = datetime.now()\n\nprint("Tiempo ejecución:", Time2 -Time1)\n\n\n\nextraction_tracks(fecha_inicial_2018.strftime(\'%Y-%m-%d\'), fecha_fin_2018.strftime(\'%Y-%m-%d\'),\n                  region_select, out_file_db_2018, out_file_csv_2018)\nextraction_tracks(fecha_inicial_2019.strftime(\'%Y-%m-%d\'), fecha_fin_2019.strftime(\'%Y-%m-%d\'),\n                  region_select, out_file_db_2019, out_file_csv_2019)\nextraction_tracks(fecha_inicial_2020.strftime(\'%Y-%m-%d\'), fecha_fin_2020.strftime(\'%Y-%m-%d\'),\n                  region_select, out_file_db_2020, out_file_csv_2020)\n\n\n\n'

# %% [markdown]
# ## Importamos los resultados extraídos

# %% [markdown]
# Primer vistazo y comprobaciones. Las columnas son:
# - **Position:** Posición en el Top200 en dicho día (no nos interesa)
# - **Track name:** Nombre de canción
# - **Artist:** Artista
# - **Streams:** Reproducciones que ha tenido ese día dicha canción. ESTE NOS INTERESA MUCHO
# - **date:** Fecha del top200
# - **region:** país del Top200
# - **Spotify_id:** Identificación única de la canción

# %%
# Importamos la tabla con los datos y miramos a ver qué tal están y eliminar valores nulos
data_top200_2017_1= pd.read_csv("data_allyear/top_200_daily_CSV_YEAR1_2017.csv")
data_top200_2017_2 = pd.read_csv("data_allyear/top_200_daily_CSV_YEAR2_2017.csv")
data_top200_2018= pd.read_csv("data_allyear/top_200_daily_CSV_YEAR_2018.csv")
data_top200_2019= pd.read_csv("data_allyear/top_200_daily_CSV_YEAR_2019.csv")
data_top200_2020= pd.read_csv("data_allyear/top_200_daily_CSV_YEAR_2020.csv")

#Juntar los dos CSVs de 2017, porque en Spotify Chart faltaban el 30 y 31 mayo y el 2 de junio
data_top200_2017 = pd.concat([data_top200_2017_1, data_top200_2017_2])
data_top200_2017.to_csv("data_allyear/top_200_daily_CSV_YEAR_2017.csv")


# Revisar si hay valores nulos y tamaños de bases de datos, que deberían ser exactas en tamaño
print(data_top200_2020.isnull().sum())
print('2020:', data_top200_2020.shape)
print('2019:',data_top200_2019.shape)
print('2018:',data_top200_2018.shape)
print('2017:',data_top200_2017.shape)

data_top200_2020.head()
# Out:
# Position      200
# Track Name    203
# Artist        203
# Streams       200
# date            0
# region          0
# spotify_id    201
# dtype: int64
# 2020: (72800, 7)
# 2019: (73000, 7)
# 2018: (73000, 7)
# 2017: (72200, 7)
#    Position                 Track Name           Artist   Streams        date  \
# 0       1.0                       Tusa          KAROL G  344475.0  2020-01-01
# 1       2.0     Alocao (With Bad Gyal)      Omar Montes  253372.0  2020-01-01
# 2       3.0               Dance Monkey      Tones And I  216578.0  2020-01-01
# 3       4.0                      China         Anuel AA  192148.0  2020-01-01
# 4       5.0  RITMO (Bad Boys For Life)  Black Eyed Peas  188835.0  2020-01-01
#
#   region              spotify_id
# 0     es  7k4t7uLgtOxPwTpFmtJNTY
# 1     es  6RyuoOJXNzlVWpfC5xQyeI
# 2     es  1rgnBhdG2JDFTbYkYRZAku
# 3     es  2ksOAxtIxY8yElEWw8RhgK
# 4     es  6cy3ki60hLwimwIje7tALf

# %% [markdown]
# Una vez echado un vistazo, importamos los datos que queremos

# %%
# Importamos con las columnas que nos interesan 
# https://stackoverflow.com/questions/17465045/can-pandas-automatically-recognize-dates#comment74606353_17468012
data_top200_2020 = pd.read_csv("data_allyear/top_200_daily_CSV_YEAR_2020.csv", parse_dates= ["date"],
                               usecols=['Track Name', 'Artist', 'date', 'Streams','spotify_id']).dropna()
data_top200_2019 = pd.read_csv("data_allyear/top_200_daily_CSV_YEAR_2019.csv", parse_dates= ["date"],
                               usecols=['Track Name', 'Artist', 'date', 'Streams', 'spotify_id']).dropna()
data_top200_2018 = pd.read_csv("data_allyear/top_200_daily_CSV_YEAR_2018.csv", parse_dates= ["date"],
                               usecols=['Track Name', 'Artist', 'date', 'Streams', 'spotify_id']).dropna()
data_top200_2017 = pd.read_csv("data_allyear/top_200_daily_CSV_YEAR_2017.csv", parse_dates= ["date"],
                               usecols=['Track Name', 'Artist', 'date', 'Streams', 'spotify_id']).dropna()


#Meto el año, los meses y los días en nuevas columnas que nos servirá más adelante.
data_top200_2020['year'] = pd.DatetimeIndex(data_top200_2020['date']).year
data_top200_2019['year'] = pd.DatetimeIndex(data_top200_2019['date']).year
data_top200_2018['year'] = pd.DatetimeIndex(data_top200_2018['date']).year
data_top200_2017['year'] = pd.DatetimeIndex(data_top200_2017['date']).year
data_top200_2020['month'] = pd.DatetimeIndex(data_top200_2020['date']).month
data_top200_2019['month'] = pd.DatetimeIndex(data_top200_2019['date']).month
data_top200_2018['month'] = pd.DatetimeIndex(data_top200_2018['date']).month
data_top200_2017['month'] = pd.DatetimeIndex(data_top200_2017['date']).month
data_top200_2020['week'] = pd.DatetimeIndex(data_top200_2020['date']).week
data_top200_2019['week'] = pd.DatetimeIndex(data_top200_2019['date']).week
data_top200_2018['week'] = pd.DatetimeIndex(data_top200_2018['date']).week
data_top200_2017['week'] = pd.DatetimeIndex(data_top200_2017['date']).week
data_top200_2020['day'] = pd.DatetimeIndex(data_top200_2020['date']).day
data_top200_2019['day'] = pd.DatetimeIndex(data_top200_2019['date']).day
data_top200_2018['day'] = pd.DatetimeIndex(data_top200_2018['date']).day
data_top200_2017['day'] = pd.DatetimeIndex(data_top200_2017['date']).day
data_top200_2020['year_month'] = pd.to_datetime(data_top200_2020['date']).dt.to_period('M')
data_top200_2019['year_month'] = pd.to_datetime(data_top200_2019['date']).dt.to_period('M')
data_top200_2018['year_month'] = pd.to_datetime(data_top200_2018['date']).dt.to_period('M')
data_top200_2017['year_month'] = pd.to_datetime(data_top200_2017['date']).dt.to_period('M')

#Conertir column a datetime, que había quedado suelta
data_top200_2020['date'] = pd.to_datetime(data_top200_2020['date'])


# Concateno los datos de todos los años
data_top200 = pd.concat([data_top200_2020, data_top200_2019,
                                      data_top200_2018, data_top200_2017], axis=0,)


# data_top200_2020.loc[data_top200_2020['date'] == 'es']
# data_top200_2020['week'].value_counts(ascending=True)
print(data_top200.isnull().sum())
# Out:
# Track Name    0
# Artist        0
# Streams       0
# date          0
# spotify_id    0
# year          0
# month         0
# week          0
# day           0
# year_month    0
# dtype: int64

# %% [markdown]
# Hacemos algunas comprobaciones básicas, pero ojo! No hay mismo número de Track Names e spotify_ID, porque una canción con el mismo nombre puede estar en diferentes albunes y entonces le asignan una spotify_ID diferente, por eso hay más spotify_IDs que Track Names. Por ejemplo puede pasar fácilmente en recopilatorios.

# %%
# Revisión
print(data_top200.shape)
print(data_top200.dtypes)
print(data_top200.nunique())
print(data_top200.groupby(['year']).sum())
data_top200.groupby(['year']).count()
# Out:
# (290755, 10)
# Track Name            object
# Artist                object
# Streams              float64
# date          datetime64[ns]
# spotify_id            object
# year                   int64
# month                  int64
# week                   int64
# day                    int64
# year_month         period[M]
# dtype: object
# Track Name      3888
# Artist           960
# Streams       118987
# date            1454
# spotify_id      4740
# year               4
# month             12
# week              53
# day               31
# year_month        48
# dtype: int64
#            Streams   month     week      day
# year
# 2017  3.656169e+09  471871  1921467  1134544
# 2018  4.687973e+09  476400  1929400  1147600
# 2019  5.715834e+09  476238  1928737  1147141
# 2020  6.399289e+09  469570  1939271  1135337
#       Track Name  Artist  Streams   date  spotify_id  month   week    day  \
# year
# 2017       72185   72185    72185  72185       72185  72185  72185  72185
# 2018       73000   73000    73000  73000       73000  73000  73000  73000
# 2019       72973   72973    72973  72973       72973  72973  72973  72973
# 2020       72597   72597    72597  72597       72597  72597  72597  72597
#
#       year_month
# year
# 2017       72185
# 2018       73000
# 2019       72973
# 2020       72597

# %%
# Vemos una muestra con un Spotify_ID
data_top200.loc[data_top200['spotify_id'] == '6NfrH0ANGmgBXyxgV2PeXt']
# Out:
#        Track Name     Artist   Streams       date              spotify_id  \
# 11801  La Difícil  Bad Bunny  517415.0 2020-02-29  6NfrH0ANGmgBXyxgV2PeXt
# 12001  La Difícil  Bad Bunny  424370.0 2020-03-01  6NfrH0ANGmgBXyxgV2PeXt
# 12200  La Difícil  Bad Bunny  516946.0 2020-03-02  6NfrH0ANGmgBXyxgV2PeXt
# 12400  La Difícil  Bad Bunny  508726.0 2020-03-03  6NfrH0ANGmgBXyxgV2PeXt
# 12600  La Difícil  Bad Bunny  506732.0 2020-03-04  6NfrH0ANGmgBXyxgV2PeXt
# ...           ...        ...       ...        ...                     ...
# 68995  La Difícil  Bad Bunny   35880.0 2020-12-10  6NfrH0ANGmgBXyxgV2PeXt
# 69394  La Difícil  Bad Bunny   40098.0 2020-12-12  6NfrH0ANGmgBXyxgV2PeXt
# 69599  La Difícil  Bad Bunny   34140.0 2020-12-13  6NfrH0ANGmgBXyxgV2PeXt
# 70998  La Difícil  Bad Bunny   35430.0 2020-12-20  6NfrH0ANGmgBXyxgV2PeXt
# 72194  La Difícil  Bad Bunny   36060.0 2020-12-26  6NfrH0ANGmgBXyxgV2PeXt
#
#        year  month  week  day year_month
# 11801  2020      2     9   29    2020-02
# 12001  2020      3     9    1    2020-03
# 12200  2020      3    10    2    2020-03
# 12400  2020      3    10    3    2020-03
# 12600  2020      3    10    4    2020-03
# ...     ...    ...   ...  ...        ...
# 68995  2020     12    50   10    2020-12
# 69394  2020     12    50   12    2020-12
# 69599  2020     12    50   13    2020-12
# 70998  2020     12    51   20    2020-12
# 72194  2020     12    52   26    2020-12
#
# [283 rows x 10 columns]

# %% [markdown]
# ## Calcular Streamstotales de canción en los años, meses y días

# %% [markdown]
# Por otro lado nos interesan más los Streams totales de cada canción en todo el periodo por año, más que los de cada Top200, entonces los vamos a sumar y añadir en una nueva columna. Después hacemos un merge para juntar el dataframe inicial con el nuevo con los StreamsTotal y vemos cómo queda.

# %%
# POR MES Y AÑO
# Agrupar sumas y convertir en Dataframe
data_top200_sumastreams_month = data_top200.groupby('year_month')['Streams'].sum()
data_top200_sumastreams_month = pd.DataFrame({'year_month':data_top200_sumastreams_month.index, 'Streams':data_top200_sumastreams_month.values})
# Después de muchos intentos, encontré una forma superfácil de hacerlo
data_top200_merged_month = pd.merge(data_top200, data_top200_sumastreams_month, on=['year_month'], how='inner')
data_top200_merged_month.rename(columns = {'Streams_y': 'streams_month', 'Streams_x': 'streams_song_day'}, inplace = True)

# POR AÑO
data_top200_sumastreams_year = data_top200_merged_month.groupby('year')['streams_song_day'].sum()
data_top200_sumastreams_year = pd.DataFrame({'year':data_top200_sumastreams_year.index, 'streams_song_day':data_top200_sumastreams_year.values})
# Después de muchos intentos, encontré una forma superfácil de hacerlo
data_top200_merged_year = pd.merge(data_top200_merged_month, data_top200_sumastreams_year, on=['year'], how='inner')
data_top200_merged_year.rename(columns = {'streams_song_day_y': 'streams_year', 'streams_song_day_x': 'streams_song_day'}, inplace = True)

#POR DÍA
data_top200_sumastreams_days = data_top200_merged_year.groupby('date')['streams_song_day'].sum()
data_top200_sumastreams_days = pd.DataFrame({'date':data_top200_sumastreams_days.index, 'streams_song_day':data_top200_sumastreams_days.values})

# Después de muchos intentos, encontré una forma superfácil de hacerlo
data_top200_merged_final = pd.merge(data_top200_merged_year, data_top200_sumastreams_days, on=['date'], how='inner')
data_top200_merged_final.rename(columns = {'streams_song_day_y': 'streams_day', 'streams_song_day_x': 'streams_song_day'}, inplace = True)


data_top200_merged_final.to_csv("data_allyear/data_ana_timeseries_streamsongs.csv", sep = ',')
data_top200_merged_final.dtypes
# Out:
# Track Name                  object
# Artist                      object
# streams_song_day           float64
# date                datetime64[ns]
# spotify_id                  object
# year                         int64
# month                        int64
# week                         int64
# day                          int64
# year_month               period[M]
# streams_month              float64
# streams_year               float64
# streams_day                float64
# dtype: object

# %% [markdown]
# ## Seleccionar cantidad de canciones a extraer

# %% [markdown]
# Echamos un vistazo al dataframe para ver cuantas canciones totales hay y meter en formato lista todas las canciones. También cogemos una muestra para analizar solo con algunos datos inicialmente. Más adelante se ve para que hacemos esto.

# %%
#Sacar lista de CANCIONES TOTALES (con repetición) para luego sacar las Features
list_ids = data_top200_merged_final['spotify_id'].tolist()
print('id de ejemplo', list_ids[0])
print('Canciones totales:', len(list_ids))

# Quitar duplicados, QUEDARNOS CON CANCIONES ÚNICAS
list_ids = list(set(list_ids))
print('Canciones totales únicas:' ,len(list_ids))

# Quitar una canción identificada que jode la extracción
list_ids.remove('3uMIfxV8q5tPTWzJh8s6Mk')

# Lista final a extraer
test_list = list_ids[0:5000]
len(test_list)
# Out:
# id de ejemplo 7k4t7uLgtOxPwTpFmtJNTY
# Canciones totales: 290755
# Canciones totales únicas: 4740
# 1

# %% [markdown]
# Echamos un vistazo al dataframe para ver cuantos artistas totales hay y meter en formato lista todos los artistas. También cogemos una muestra para analizar solo con algunos datos inicialmente.

# %%
#Sacar lista de ARTISTAS TOTALES
list_artist = data_top200_merged_final['Artist'].tolist()
print('nombre de ejemplo:', list_artist[0])
print('Artistas totales:', len(list_artist))

# Quitar duplicados, QUEDARNOS CON ARTISTAS ÚNICOS
list_artist = list(set(list_artist))
print('Artistas totales únicos:' ,len(list_artist))

# Lista final a extraer
test_list_artist = list_artist[0:1000]
len(test_list_artist)
# Out:
# nombre de ejemplo: KAROL G
# Artistas totales: 290755
# Artistas totales únicos: 960
# 960

# %% [markdown]
# # Extracción FEATURES desde API SPOTIFY

# %% [markdown]
# Ahora vamos a extraer las features de cada canción que nos van a dar algunos valores interesantes como, por ejemplo, en qué escala del 0 al 1 es una canción más o menos "bailable". Más adelante entraremos en profundidad en los significados de los features.
#
# Para ello utilizaremos <a href="https://spotipy.readthedocs.io/en/2.16.0/" target="_blank">Spotipy</a>, que es un paquete de python que facilita la extracción de información de la API de Spotify.
#
#
#
# Los features que nos interesan son los siguientes:
# - 'length'
# - 'popularity'
# - 'acousticness'
# - 'danceability'
# - 'energy'
# - 'instrumentalness'
# - 'liveness'
# - 'loudness'
# - 'speechiness'
# - 'valence'
# - 'tempo'

# %%
#Preparación de Spotipy
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time 

# IMPORTANTE INTRODUCIR OTRAS CREDENCIALES, LAS USADAS ESTÁN CAMBIADAS.
passw = pd.read_csv("pass_spotify.txt", sep = ',', encoding="utf-8")
client_id = passw.columns[0]
client_secret = passw.columns[1]

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Hacemos una prueba para ver las features que hay de una canción concreta por su ID
track_ids = sp.user_playlist_tracks(playlist_id='1ebwiiN18Gmhfj6e24pT3X', fields='items(track(id))')
sp.audio_features(track_ids['items'][5]['track']['id'])
# Out:
# [{'danceability': 0.669,
#   'energy': 0.829,
#   'key': 1,
#   'loudness': -3.801,
#   'mode': 1,
#   'speechiness': 0.49,
#   'acousticness': 0.179,
#   'instrumentalness': 0,
#   'liveness': 0.241,
#   'valence': 0.61,
#   'tempo': 118.934,
#   'type': 'audio_features',
#   'id': '2eOuL8KesslTLQERQPu11D',
#   'uri': 'spotify:track:2eOuL8KesslTLQERQPu11D',
#   'track_href': 'https://api.spotify.com/v1/tracks/2eOuL8KesslTLQERQPu11D',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2eOuL8KesslTLQERQPu11D',
#   'duration_ms': 253067,
#   'time_signature': 4}]

# %%
# FUNCIÓN COMPLETA PARA EXTRACCIÓN DE FEATURES DE LISTA DE CANCIONES
##### Función para sacar las features de canciones que me interesan desde la id
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  valence = features[0]['valence']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']
  id = features[0]['id']

  track = [name, album, artist, release_date, length, popularity,
           acousticness, danceability, energy, instrumentalness,
           liveness, loudness, speechiness, valence, tempo, time_signature, id]
  return track


##### Loop para sacar features de todas las canciones de una lista, devuelve un dataframe
def extract_songs(list_toextract):
    import time
    tracks = []
    num_song = 0
    for i in range(len(list_toextract)):
        time.sleep(.5)
        track = getTrackFeatures(list_toextract[i])
        tracks.append(track)
        print("Song extracted:", num_song)
        num_song += 1

    # Metemos la info en Dataframe
    data_features = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date',
                                                 'length', 'popularity','acousticness', 'danceability', 'energy',
                                                 'instrumentalness', 'liveness', 'loudness',
                                                 'speechiness', 'valence','tempo', 'time_signature', 'id'])

    data_features_final = data_features [['name','artist','album','release_date','length', 'popularity',
                                                 'acousticness', 'danceability', 'energy',
                                                 'instrumentalness', 'liveness', 'loudness',
                                                 'speechiness', 'valence','tempo', 'time_signature', 'id']]

    data_features_final = data_features_final.rename(columns = {'id':'spotify_id'})

    # Finalmente meto el año de Release date (lanzamiento de la canción) en un nueva columna que me va a vernir en uno de los análisis
    data_features_final['release_date_year'] = pd.to_datetime(data_features_final['release_date'])
    data_features_final['release_date_year'] = pd.DatetimeIndex(data_features_final['release_date']).year
    print(data_features_final.shape)
    data_features_final.head(4)

    #Normalizamos features
    features_to_normalize = ['length', 'popularity', 'loudness', 'tempo', 'speechiness']

    data_features_final[features_to_normalize] = data_features_final[features_to_normalize].apply(lambda x:(x-x.min()) / (x.max()-x.min()))

    return data_features_final

# %%
# Extracción de datos, OJO!!!! la extracción tarda 45 minutos

'''Time1 = datetime.now()
dataframe_extraction_timeseries = extract_songs(test_list)
Time2 = datetime.now()

# Exportamos
dataframe_extraction_timeseries.to_csv("data_allyear/data_ana_timeseries.csv", sep = ',')

print("Tiempo ejecución extracción:", Time2 -Time1)
dataframe_extraction_timeseries.shape
'''
# Out:
# Song extracted: 0
# Song extracted: 1
# Song extracted: 2
# Song extracted: 3
# Song extracted: 4
# Song extracted: 5
# Song extracted: 6
# Song extracted: 7
# Song extracted: 8
# Song extracted: 9
# Song extracted: 10
# Song extracted: 11
# Song extracted: 12
# Song extracted: 13
# Song extracted: 14
# Song extracted: 15
# Song extracted: 16
# Song extracted: 17
# Song extracted: 18
# Song extracted: 19
# Song extracted: 20
# Song extracted: 21
# Song extracted: 22
# Song extracted: 23
# Song extracted: 24
# Song extracted: 25
# Song extracted: 26
# Song extracted: 27
# Song extracted: 28
# Song extracted: 29
# Song extracted: 30
# Song extracted: 31
# Song extracted: 32
# Song extracted: 33
# Song extracted: 34
# Song extracted: 35
# Song extracted: 36
# Song extracted: 37
# Song extracted: 38
# Song extracted: 39
# Song extracted: 40
# Song extracted: 41
# Song extracted: 42
# Song extracted: 43
# Song extracted: 44
# Song extracted: 45
# Song extracted: 46
# Song extracted: 47
# Song extracted: 48
# Song extracted: 49
# Song extracted: 50
# Song extracted: 51
# Song extracted: 52
# Song extracted: 53
# Song extracted: 54
# Song extracted: 55
# Song extracted: 56
# Song extracted: 57
# Song extracted: 58
# Song extracted: 59
# Song extracted: 60
# Song extracted: 61
# Song extracted: 62
# Song extracted: 63
# Song extracted: 64
# Song extracted: 65
# Song extracted: 66
# Song extracted: 67
# Song extracted: 68
# Song extracted: 69
# Song extracted: 70
# Song extracted: 71
# Song extracted: 72
# Song extracted: 73
# Song extracted: 74
# Song extracted: 75
# Song extracted: 76
# Song extracted: 77
# Song extracted: 78
# Song extracted: 79
# Song extracted: 80
# Song extracted: 81
# Song extracted: 82
# Song extracted: 83
# Song extracted: 84
# Song extracted: 85
# Song extracted: 86
# Song extracted: 87
# Song extracted: 88
# Song extracted: 89
# Song extracted: 90
# Song extracted: 91
# Song extracted: 92
# Song extracted: 93
# Song extracted: 94
# Song extracted: 95
# Song extracted: 96
# Song extracted: 97
# Song extracted: 98
# Song extracted: 99
# Song extracted: 100
# Song extracted: 101
# Song extracted: 102
# Song extracted: 103
# Song extracted: 104
# Song extracted: 105
# Song extracted: 106
# Song extracted: 107
# Song extracted: 108
# Song extracted: 109
# Song extracted: 110
# Song extracted: 111
# Song extracted: 112
# Song extracted: 113
# Song extracted: 114
# Song extracted: 115
# Song extracted: 116
# Song extracted: 117
# Song extracted: 118
# Song extracted: 119
# Song extracted: 120
# Song extracted: 121
# Song extracted: 122
# Song extracted: 123
# Song extracted: 124
# Song extracted: 125
# Song extracted: 126
# Song extracted: 127
# Song extracted: 128
# Song extracted: 129
# Song extracted: 130
# Song extracted: 131
# Song extracted: 132
# Song extracted: 133
# Song extracted: 134
# Song extracted: 135
# Song extracted: 136
# Song extracted: 137
# Song extracted: 138
# Song extracted: 139
# Song extracted: 140
# Song extracted: 141
# Song extracted: 142
# Song extracted: 143
# Song extracted: 144
# Song extracted: 145
# Song extracted: 146
# Song extracted: 147
# Song extracted: 148
# Song extracted: 149
# Song extracted: 150
# Song extracted: 151
# Song extracted: 152
# Song extracted: 153
# Song extracted: 154
# Song extracted: 155
# Song extracted: 156
# Song extracted: 157
# Song extracted: 158
# Song extracted: 159
# Song extracted: 160
# Song extracted: 161
# Song extracted: 162
# Song extracted: 163
# Song extracted: 164
# Song extracted: 165
# Song extracted: 166
# Song extracted: 167
# Song extracted: 168
# Song extracted: 169
# Song extracted: 170
# Song extracted: 171
# Song extracted: 172
# Song extracted: 173
# Song extracted: 174
# Song extracted: 175
# Song extracted: 176
# Song extracted: 177
# Song extracted: 178
# Song extracted: 179
# Song extracted: 180
# Song extracted: 181
# Song extracted: 182
# Song extracted: 183
# Song extracted: 184
# Song extracted: 185
# Song extracted: 186
# Song extracted: 187
# Song extracted: 188
# Song extracted: 189
# Song extracted: 190
# Song extracted: 191
# Song extracted: 192
# Song extracted: 193
# Song extracted: 194
# Song extracted: 195
# Song extracted: 196
# Song extracted: 197
# Song extracted: 198
# Song extracted: 199
# Song extracted: 200
# Song extracted: 201
# Song extracted: 202
# Song extracted: 203
# Song extracted: 204
# Song extracted: 205
# Song extracted: 206
# Song extracted: 207
# Song extracted: 208
# Song extracted: 209
# Song extracted: 210
# Song extracted: 211
# Song extracted: 212
# Song extracted: 213
# Song extracted: 214
# Song extracted: 215
# Song extracted: 216
# Song extracted: 217
# Song extracted: 218
# Song extracted: 219
# Song extracted: 220
# Song extracted: 221
# Song extracted: 222
# Song extracted: 223
# Song extracted: 224
# Song extracted: 225
# Song extracted: 226
# Song extracted: 227
# Song extracted: 228
# Song extracted: 229
# Song extracted: 230
# Song extracted: 231
# Song extracted: 232
# Song extracted: 233
# Song extracted: 234
# Song extracted: 235
# Song extracted: 236
# Song extracted: 237
# Song extracted: 238
# Song extracted: 239
# Song extracted: 240
# Song extracted: 241
# Song extracted: 242
# Song extracted: 243
# Song extracted: 244
# Song extracted: 245
# Song extracted: 246
# Song extracted: 247
# Song extracted: 248
# Song extracted: 249
# Song extracted: 250
# Song extracted: 251
# Song extracted: 252
# Song extracted: 253
# Song extracted: 254
# Song extracted: 255
# Song extracted: 256
# Song extracted: 257
# Song extracted: 258
# Song extracted: 259
# Song extracted: 260
# Song extracted: 261
# Song extracted: 262
# Song extracted: 263
# Song extracted: 264
# Song extracted: 265
# Song extracted: 266
# Song extracted: 267
# Song extracted: 268
# Song extracted: 269
# Song extracted: 270
# Song extracted: 271
# Song extracted: 272
# Song extracted: 273
# Song extracted: 274
# Song extracted: 275
# Song extracted: 276
# Song extracted: 277
# Song extracted: 278
# Song extracted: 279
# Song extracted: 280
# Song extracted: 281
# Song extracted: 282
# Song extracted: 283
# Song extracted: 284
# Song extracted: 285
# Song extracted: 286
# Song extracted: 287
# Song extracted: 288
# Song extracted: 289
# Song extracted: 290
# Song extracted: 291
# Song extracted: 292
# Song extracted: 293
# Song extracted: 294
# Song extracted: 295
# Song extracted: 296
# Song extracted: 297
# Song extracted: 298
# Song extracted: 299
# Song extracted: 300
# Song extracted: 301
# Song extracted: 302
# Song extracted: 303
# Song extracted: 304
# Song extracted: 305
# Song extracted: 306
# Song extracted: 307
# Song extracted: 308
# Song extracted: 309
# Song extracted: 310
# Song extracted: 311
# Song extracted: 312
# Song extracted: 313
# Song extracted: 314
# Song extracted: 315
# Song extracted: 316
# Song extracted: 317
# Song extracted: 318
# Song extracted: 319
# Song extracted: 320
# Song extracted: 321
# Song extracted: 322
# Song extracted: 323
# Song extracted: 324
# Song extracted: 325
# Song extracted: 326
# Song extracted: 327
# Song extracted: 328
# Song extracted: 329
# Song extracted: 330
# Song extracted: 331
# Song extracted: 332
# Song extracted: 333
# Song extracted: 334
# Song extracted: 335
# Song extracted: 336
# Song extracted: 337
# Song extracted: 338
# Song extracted: 339
# Song extracted: 340
# Song extracted: 341
# Song extracted: 342
# Song extracted: 343
# Song extracted: 344
# Song extracted: 345
# Song extracted: 346
# Song extracted: 347
# Song extracted: 348
# Song extracted: 349
# Song extracted: 350
# Song extracted: 351
# Song extracted: 352
# Song extracted: 353
# Song extracted: 354
# Song extracted: 355
# Song extracted: 356
# Song extracted: 357
# Song extracted: 358
# Song extracted: 359
# Song extracted: 360
# Song extracted: 361
# Song extracted: 362
# Song extracted: 363
# Song extracted: 364
# Song extracted: 365
# Song extracted: 366
# Song extracted: 367
# Song extracted: 368
# Song extracted: 369
# Song extracted: 370
# Song extracted: 371
# Song extracted: 372
# Song extracted: 373
# Song extracted: 374
# Song extracted: 375
# Song extracted: 376
# Song extracted: 377
# Song extracted: 378
# Song extracted: 379
# Song extracted: 380
# Song extracted: 381
# Song extracted: 382
# Song extracted: 383
# Song extracted: 384
# Song extracted: 385
# Song extracted: 386
# Song extracted: 387
# Song extracted: 388
# Song extracted: 389
# Song extracted: 390
# Song extracted: 391
# Song extracted: 392
# Song extracted: 393
# Song extracted: 394
# Song extracted: 395
# Song extracted: 396
# Song extracted: 397
# Song extracted: 398
# Song extracted: 399
# Song extracted: 400
# Song extracted: 401
# Song extracted: 402
# Song extracted: 403
# Song extracted: 404
# Song extracted: 405
# Song extracted: 406
# Song extracted: 407
# Song extracted: 408
# Song extracted: 409
# Song extracted: 410
# Song extracted: 411
# Song extracted: 412
# Song extracted: 413
# Song extracted: 414
# Song extracted: 415
# Song extracted: 416
# Song extracted: 417
# Song extracted: 418
# Song extracted: 419
# Song extracted: 420
# Song extracted: 421
# Song extracted: 422
# Song extracted: 423
# Song extracted: 424
# Song extracted: 425
# Song extracted: 426
# Song extracted: 427
# Song extracted: 428
# Song extracted: 429
# Song extracted: 430
# Song extracted: 431
# Song extracted: 432
# Song extracted: 433
# Song extracted: 434
# Song extracted: 435
# Song extracted: 436
# Song extracted: 437
# Song extracted: 438
# Song extracted: 439
# Song extracted: 440
# Song extracted: 441
# Song extracted: 442
# Song extracted: 443
# Song extracted: 444
# Song extracted: 445
# Song extracted: 446
# Song extracted: 447
# Song extracted: 448
# Song extracted: 449
# Song extracted: 450
# Song extracted: 451
# Song extracted: 452
# Song extracted: 453
# Song extracted: 454
# Song extracted: 455
# Song extracted: 456
# Song extracted: 457
# Song extracted: 458
# Song extracted: 459
# Song extracted: 460
# Song extracted: 461
# Song extracted: 462
# Song extracted: 463
# Song extracted: 464
# Song extracted: 465
# Song extracted: 466
# Song extracted: 467
# Song extracted: 468
# Song extracted: 469
# Song extracted: 470
# Song extracted: 471
# Song extracted: 472
# Song extracted: 473
# Song extracted: 474
# Song extracted: 475
# Song extracted: 476
# Song extracted: 477
# Song extracted: 478
# Song extracted: 479
# Song extracted: 480
# Song extracted: 481
# Song extracted: 482
# Song extracted: 483
# Song extracted: 484
# Song extracted: 485
# Song extracted: 486
# Song extracted: 487
# Song extracted: 488
# Song extracted: 489
# Song extracted: 490
# Song extracted: 491
# Song extracted: 492
# Song extracted: 493
# Song extracted: 494
# Song extracted: 495
# Song extracted: 496
# Song extracted: 497
# Song extracted: 498
# Song extracted: 499
# Song extracted: 500
# Song extracted: 501
# Song extracted: 502
# Song extracted: 503
# Song extracted: 504
# Song extracted: 505
# Song extracted: 506
# Song extracted: 507
# Song extracted: 508
# Song extracted: 509
# Song extracted: 510
# Song extracted: 511
# Song extracted: 512
# Song extracted: 513
# Song extracted: 514
# Song extracted: 515
# Song extracted: 516
# Song extracted: 517
# Song extracted: 518
# Song extracted: 519
# Song extracted: 520
# Song extracted: 521
# Song extracted: 522
# Song extracted: 523
# Song extracted: 524
# Song extracted: 525
# Song extracted: 526
# Song extracted: 527
# Song extracted: 528
# Song extracted: 529
# Song extracted: 530
# Song extracted: 531
# Song extracted: 532
# Song extracted: 533
# Song extracted: 534
# Song extracted: 535
# Song extracted: 536
# Song extracted: 537
# Song extracted: 538
# Song extracted: 539
# Song extracted: 540
# Song extracted: 541
# Song extracted: 542
# Song extracted: 543
# Song extracted: 544
# Song extracted: 545
# Song extracted: 546
# Song extracted: 547
# Song extracted: 548
# Song extracted: 549
# Song extracted: 550
# Song extracted: 551
# Song extracted: 552
# Song extracted: 553
# Song extracted: 554
# Song extracted: 555
# Song extracted: 556
# Song extracted: 557
# Song extracted: 558
# Song extracted: 559
# Song extracted: 560
# Song extracted: 561
# Song extracted: 562
# Song extracted: 563
# Song extracted: 564
# Song extracted: 565
# Song extracted: 566
# Song extracted: 567
# Song extracted: 568
# Song extracted: 569
# Song extracted: 570
# Song extracted: 571
# Song extracted: 572
# Song extracted: 573
# Song extracted: 574
# Song extracted: 575
# Song extracted: 576
# Song extracted: 577
# Song extracted: 578
# Song extracted: 579
# Song extracted: 580
# Song extracted: 581
# Song extracted: 582
# Song extracted: 583
# Song extracted: 584
# Song extracted: 585
# Song extracted: 586
# Song extracted: 587
# Song extracted: 588
# Song extracted: 589
# Song extracted: 590
# Song extracted: 591
# Song extracted: 592
# Song extracted: 593
# Song extracted: 594
# Song extracted: 595
# Song extracted: 596
# Song extracted: 597
# Song extracted: 598
# Song extracted: 599
# Song extracted: 600
# Song extracted: 601
# Song extracted: 602
# Song extracted: 603
# Song extracted: 604
# Song extracted: 605
# Song extracted: 606
# Song extracted: 607
# Song extracted: 608
# Song extracted: 609
# Song extracted: 610
# Song extracted: 611
# Song extracted: 612
# Song extracted: 613
# Song extracted: 614
# Song extracted: 615
# Song extracted: 616
# Song extracted: 617
# Song extracted: 618
# Song extracted: 619
# Song extracted: 620
# Song extracted: 621
# Song extracted: 622
# Song extracted: 623
# Song extracted: 624
# Song extracted: 625
# Song extracted: 626
# Song extracted: 627
# Song extracted: 628
# Song extracted: 629
# Song extracted: 630
# Song extracted: 631
# Song extracted: 632
# Song extracted: 633
# Song extracted: 634
# Song extracted: 635
# Song extracted: 636
# Song extracted: 637
# Song extracted: 638
# Song extracted: 639
# Song extracted: 640
# Song extracted: 641
# Song extracted: 642
# Song extracted: 643
# Song extracted: 644
# Song extracted: 645
# Song extracted: 646
# Song extracted: 647
# Song extracted: 648
# Song extracted: 649
# Song extracted: 650
# Song extracted: 651
# Song extracted: 652
# Song extracted: 653
# Song extracted: 654
# Song extracted: 655
# Song extracted: 656
# Song extracted: 657
# Song extracted: 658
# Song extracted: 659
# Song extracted: 660
# Song extracted: 661
# Song extracted: 662
# Song extracted: 663
# Song extracted: 664
# Song extracted: 665
# Song extracted: 666
# Song extracted: 667
# Song extracted: 668
# Song extracted: 669
# Song extracted: 670
# Song extracted: 671
# Song extracted: 672
# Song extracted: 673
# Song extracted: 674
# Song extracted: 675
# Song extracted: 676
# Song extracted: 677
# Song extracted: 678
# Song extracted: 679
# Song extracted: 680
# Song extracted: 681
# Song extracted: 682
# Song extracted: 683
# Song extracted: 684
# Song extracted: 685
# Song extracted: 686
# Song extracted: 687
# Song extracted: 688
# Song extracted: 689
# Song extracted: 690
# Song extracted: 691
# Song extracted: 692
# Song extracted: 693
# Song extracted: 694
# Song extracted: 695
# Song extracted: 696
# Song extracted: 697
# Song extracted: 698
# Song extracted: 699
# Song extracted: 700
# Song extracted: 701
# Song extracted: 702
# Song extracted: 703
# Song extracted: 704
# Song extracted: 705
# Song extracted: 706
# Song extracted: 707
# Song extracted: 708
# Song extracted: 709
# Song extracted: 710
# Song extracted: 711
# Song extracted: 712
# Song extracted: 713
# Song extracted: 714
# Song extracted: 715
# Song extracted: 716
# Song extracted: 717
# Song extracted: 718
# Song extracted: 719
# Song extracted: 720
# Song extracted: 721
# Song extracted: 722
# Song extracted: 723
# Song extracted: 724
# Song extracted: 725
# Song extracted: 726
# Song extracted: 727
# Song extracted: 728
# Song extracted: 729
# Song extracted: 730
# Song extracted: 731
# Song extracted: 732
# Song extracted: 733
# Song extracted: 734
# Song extracted: 735
# Song extracted: 736
# Song extracted: 737
# Song extracted: 738
# Song extracted: 739
# Song extracted: 740
# Song extracted: 741
# Song extracted: 742
# Song extracted: 743
# Song extracted: 744
# Song extracted: 745
# Song extracted: 746
# Song extracted: 747
# Song extracted: 748
# Song extracted: 749
# Song extracted: 750
# Song extracted: 751
# Song extracted: 752
# Song extracted: 753
# Song extracted: 754
# Song extracted: 755
# Song extracted: 756
# Song extracted: 757
# Song extracted: 758
# Song extracted: 759
# Song extracted: 760
# Song extracted: 761
# Song extracted: 762
# Song extracted: 763
# Song extracted: 764
# Song extracted: 765
# Song extracted: 766
# Song extracted: 767
# Song extracted: 768
# Song extracted: 769
# Song extracted: 770
# Song extracted: 771
# Song extracted: 772
# Song extracted: 773
# Song extracted: 774
# Song extracted: 775
# Song extracted: 776
# Song extracted: 777
# Song extracted: 778
# Song extracted: 779
# Song extracted: 780
# Song extracted: 781
# Song extracted: 782
# Song extracted: 783
# Song extracted: 784
# Song extracted: 785
# Song extracted: 786
# Song extracted: 787
# Song extracted: 788
# Song extracted: 789
# Song extracted: 790
# Song extracted: 791
# Song extracted: 792
# Song extracted: 793
# Song extracted: 794
# Song extracted: 795
# Song extracted: 796
# Song extracted: 797
# Song extracted: 798
# Song extracted: 799
# Song extracted: 800
# Song extracted: 801
# Song extracted: 802
# Song extracted: 803
# Song extracted: 804
# Song extracted: 805
# Song extracted: 806
# Song extracted: 807
# Song extracted: 808
# Song extracted: 809
# Song extracted: 810
# Song extracted: 811
# Song extracted: 812
# Song extracted: 813
# Song extracted: 814
# Song extracted: 815
# Song extracted: 816
# Song extracted: 817
# Song extracted: 818
# Song extracted: 819
# Song extracted: 820
# Song extracted: 821
# Song extracted: 822
# Song extracted: 823
# Song extracted: 824
# Song extracted: 825
# Song extracted: 826
# Song extracted: 827
# Song extracted: 828
# Song extracted: 829
# Song extracted: 830
# Song extracted: 831
# Song extracted: 832
# Song extracted: 833
# Song extracted: 834
# Song extracted: 835
# Song extracted: 836
# Song extracted: 837
# Song extracted: 838
# Song extracted: 839
# Song extracted: 840
# Song extracted: 841
# Song extracted: 842
# Song extracted: 843
# Song extracted: 844
# Song extracted: 845
# Song extracted: 846
# Song extracted: 847
# Song extracted: 848
# Song extracted: 849
# Song extracted: 850
# Song extracted: 851
# Song extracted: 852
# Song extracted: 853
# Song extracted: 854
# Song extracted: 855
# Song extracted: 856
# Song extracted: 857
# Song extracted: 858
# Song extracted: 859
# Song extracted: 860
# Song extracted: 861
# Song extracted: 862
# Song extracted: 863
# Song extracted: 864
# Song extracted: 865
# Song extracted: 866
# Song extracted: 867
# Song extracted: 868
# Song extracted: 869
# Song extracted: 870
# Song extracted: 871
# Song extracted: 872
# Song extracted: 873
# Song extracted: 874
# Song extracted: 875
# Song extracted: 876
# Song extracted: 877
# Song extracted: 878
# Song extracted: 879
# Song extracted: 880
# Song extracted: 881
# Song extracted: 882
# Song extracted: 883
# Song extracted: 884
# Song extracted: 885
# Song extracted: 886
# Song extracted: 887
# Song extracted: 888
# Song extracted: 889
# Song extracted: 890
# Song extracted: 891
# Song extracted: 892
# Song extracted: 893
# Song extracted: 894
# Song extracted: 895
# Song extracted: 896
# Song extracted: 897
# Song extracted: 898
# Song extracted: 899
# Song extracted: 900
# Song extracted: 901
# Song extracted: 902
# Song extracted: 903
# Song extracted: 904
# Song extracted: 905
# Song extracted: 906
# Song extracted: 907
# Song extracted: 908
# Song extracted: 909
# Song extracted: 910
# Song extracted: 911
# Song extracted: 912
# Song extracted: 913
# Song extracted: 914
# Song extracted: 915
# Song extracted: 916
# Song extracted: 917
# Song extracted: 918
# Song extracted: 919
# Song extracted: 920
# Song extracted: 921
# Song extracted: 922
# Song extracted: 923
# Song extracted: 924
# Song extracted: 925
# Song extracted: 926
# Song extracted: 927
# Song extracted: 928
# Song extracted: 929
# Song extracted: 930
# Song extracted: 931
# Song extracted: 932
# Song extracted: 933
# Song extracted: 934
# Song extracted: 935
# Song extracted: 936
# Song extracted: 937
# Song extracted: 938
# Song extracted: 939
# Song extracted: 940
# Song extracted: 941
# Song extracted: 942
# Song extracted: 943
# Song extracted: 944
# Song extracted: 945
# Song extracted: 946
# Song extracted: 947
# Song extracted: 948
# Song extracted: 949
# Song extracted: 950
# Song extracted: 951
# Song extracted: 952
# Song extracted: 953
# Song extracted: 954
# Song extracted: 955
# Song extracted: 956
# Song extracted: 957
# Song extracted: 958
# Song extracted: 959
# Song extracted: 960
# Song extracted: 961
# Song extracted: 962
# Song extracted: 963
# Song extracted: 964
# Song extracted: 965
# Song extracted: 966
# Song extracted: 967
# Song extracted: 968
# Song extracted: 969
# Song extracted: 970
# Song extracted: 971
# Song extracted: 972
# Song extracted: 973
# Song extracted: 974
# Song extracted: 975
# Song extracted: 976
# Song extracted: 977
# Song extracted: 978
# Song extracted: 979
# Song extracted: 980
# Song extracted: 981
# Song extracted: 982
# Song extracted: 983
# Song extracted: 984
# Song extracted: 985
# Song extracted: 986
# Song extracted: 987
# Song extracted: 988
# Song extracted: 989
# Song extracted: 990
# Song extracted: 991
# Song extracted: 992
# Song extracted: 993
# Song extracted: 994
# Song extracted: 995
# Song extracted: 996
# Song extracted: 997
# Song extracted: 998
# Song extracted: 999
# Song extracted: 1000
# Song extracted: 1001
# Song extracted: 1002
# Song extracted: 1003
# Song extracted: 1004
# Song extracted: 1005
# Song extracted: 1006
# Song extracted: 1007
# Song extracted: 1008
# Song extracted: 1009
# Song extracted: 1010
# Song extracted: 1011
# Song extracted: 1012
# Song extracted: 1013
# Song extracted: 1014
# Song extracted: 1015
# Song extracted: 1016
# Song extracted: 1017
# Song extracted: 1018
# Song extracted: 1019
# Song extracted: 1020
# Song extracted: 1021
# Song extracted: 1022
# Song extracted: 1023
# Song extracted: 1024
# Song extracted: 1025
# Song extracted: 1026
# Song extracted: 1027
# Song extracted: 1028
# Song extracted: 1029
# Song extracted: 1030
# Song extracted: 1031
# Song extracted: 1032
# Song extracted: 1033
# Song extracted: 1034
# Song extracted: 1035
# Song extracted: 1036
# Song extracted: 1037
# Song extracted: 1038
# Song extracted: 1039
# Song extracted: 1040
# Song extracted: 1041
# Song extracted: 1042
# Song extracted: 1043
# Song extracted: 1044
# Song extracted: 1045
# Song extracted: 1046
# Song extracted: 1047
# Song extracted: 1048
# Song extracted: 1049
# Song extracted: 1050
# Song extracted: 1051
# Song extracted: 1052
# Song extracted: 1053
# Song extracted: 1054
# Song extracted: 1055
# Song extracted: 1056
# Song extracted: 1057
# Song extracted: 1058
# Song extracted: 1059
# Song extracted: 1060
# Song extracted: 1061
# Song extracted: 1062
# Song extracted: 1063
# Song extracted: 1064
# Song extracted: 1065
# Song extracted: 1066
# Song extracted: 1067
# Song extracted: 1068
# Song extracted: 1069
# Song extracted: 1070
# Song extracted: 1071
# Song extracted: 1072
# Song extracted: 1073
# Song extracted: 1074
# Song extracted: 1075
# Song extracted: 1076
# Song extracted: 1077
# Song extracted: 1078
# Song extracted: 1079
# Song extracted: 1080
# Song extracted: 1081
# Song extracted: 1082
# Song extracted: 1083
# Song extracted: 1084
# Song extracted: 1085
# Song extracted: 1086
# Song extracted: 1087
# Song extracted: 1088
# Song extracted: 1089
# Song extracted: 1090
# Song extracted: 1091
# Song extracted: 1092
# Song extracted: 1093
# Song extracted: 1094
# Song extracted: 1095
# Song extracted: 1096
# Song extracted: 1097
# Song extracted: 1098
# Song extracted: 1099
# Song extracted: 1100
# Song extracted: 1101
# Song extracted: 1102
# Song extracted: 1103
# Song extracted: 1104
# Song extracted: 1105
# Song extracted: 1106
# Song extracted: 1107
# Song extracted: 1108
# Song extracted: 1109
# Song extracted: 1110
# Song extracted: 1111
# Song extracted: 1112
# Song extracted: 1113
# Song extracted: 1114
# Song extracted: 1115
# Song extracted: 1116
# Song extracted: 1117
# Song extracted: 1118
# Song extracted: 1119
# Song extracted: 1120
# Song extracted: 1121
# Song extracted: 1122
# Song extracted: 1123
# Song extracted: 1124
# Song extracted: 1125
# Song extracted: 1126
# Song extracted: 1127
# Song extracted: 1128
# Song extracted: 1129
# Song extracted: 1130
# Song extracted: 1131
# Song extracted: 1132
# Song extracted: 1133
# Song extracted: 1134
# Song extracted: 1135
# Song extracted: 1136
# Song extracted: 1137
# Song extracted: 1138
# Song extracted: 1139
# Song extracted: 1140
# Song extracted: 1141
# Song extracted: 1142
# Song extracted: 1143
# Song extracted: 1144
# Song extracted: 1145
# Song extracted: 1146
# Song extracted: 1147
# Song extracted: 1148
# Song extracted: 1149
# Song extracted: 1150
# Song extracted: 1151
# Song extracted: 1152
# Song extracted: 1153
# Song extracted: 1154
# Song extracted: 1155
# Song extracted: 1156
# Song extracted: 1157
# Song extracted: 1158
# Song extracted: 1159
# Song extracted: 1160
# Song extracted: 1161
# Song extracted: 1162
# Song extracted: 1163
# Song extracted: 1164
# Song extracted: 1165
# Song extracted: 1166
# Song extracted: 1167
# Song extracted: 1168
# Song extracted: 1169
# Song extracted: 1170
# Song extracted: 1171
# Song extracted: 1172
# Song extracted: 1173
# Song extracted: 1174
# Song extracted: 1175
# Song extracted: 1176
# Song extracted: 1177
# Song extracted: 1178
# Song extracted: 1179
# Song extracted: 1180
# Song extracted: 1181
# Song extracted: 1182
# Song extracted: 1183
# Song extracted: 1184
# Song extracted: 1185
# Song extracted: 1186
# Song extracted: 1187
# Song extracted: 1188
# Song extracted: 1189
# Song extracted: 1190
# Song extracted: 1191
# Song extracted: 1192
# Song extracted: 1193
# Song extracted: 1194
# Song extracted: 1195
# Song extracted: 1196
# Song extracted: 1197
# Song extracted: 1198
# Song extracted: 1199
# Song extracted: 1200
# Song extracted: 1201
# Song extracted: 1202
# Song extracted: 1203
# Song extracted: 1204
# Song extracted: 1205
# Song extracted: 1206
# Song extracted: 1207
# Song extracted: 1208
# Song extracted: 1209
# Song extracted: 1210
# Song extracted: 1211
# Song extracted: 1212
# Song extracted: 1213
# Song extracted: 1214
# Song extracted: 1215
# Song extracted: 1216
# Song extracted: 1217
# Song extracted: 1218
# Song extracted: 1219
# Song extracted: 1220
# Song extracted: 1221
# Song extracted: 1222
# Song extracted: 1223
# Song extracted: 1224
# Song extracted: 1225
# Song extracted: 1226
# Song extracted: 1227
# Song extracted: 1228
# Song extracted: 1229
# Song extracted: 1230
# Song extracted: 1231
# Song extracted: 1232
# Song extracted: 1233
# Song extracted: 1234
# Song extracted: 1235
# Song extracted: 1236
# Song extracted: 1237
# Song extracted: 1238
# Song extracted: 1239
# Song extracted: 1240
# Song extracted: 1241
# Song extracted: 1242
# Song extracted: 1243
# Song extracted: 1244
# Song extracted: 1245
# Song extracted: 1246
# Song extracted: 1247
# Song extracted: 1248
# Song extracted: 1249
# Song extracted: 1250
# Song extracted: 1251
# Song extracted: 1252
# Song extracted: 1253
# Song extracted: 1254
# Song extracted: 1255
# Song extracted: 1256
# Song extracted: 1257
# Song extracted: 1258
# Song extracted: 1259
# Song extracted: 1260
# Song extracted: 1261
# Song extracted: 1262
# Song extracted: 1263
# Song extracted: 1264
# Song extracted: 1265
# Song extracted: 1266
# Song extracted: 1267
# Song extracted: 1268
# Song extracted: 1269
# Song extracted: 1270
# Song extracted: 1271
# Song extracted: 1272
# Song extracted: 1273
# Song extracted: 1274
# Song extracted: 1275
# Song extracted: 1276
# Song extracted: 1277
# Song extracted: 1278
# Song extracted: 1279
# Song extracted: 1280
# Song extracted: 1281
# Song extracted: 1282
# Song extracted: 1283
# Song extracted: 1284
# Song extracted: 1285
# Song extracted: 1286
# Song extracted: 1287
# Song extracted: 1288
# Song extracted: 1289
# Song extracted: 1290
# Song extracted: 1291
# Song extracted: 1292
# Song extracted: 1293
# Song extracted: 1294
# Song extracted: 1295
# Song extracted: 1296
# Song extracted: 1297
# Song extracted: 1298
# Song extracted: 1299
# Song extracted: 1300
# Song extracted: 1301
# Song extracted: 1302
# Song extracted: 1303
# Song extracted: 1304
# Song extracted: 1305
# Song extracted: 1306
# Song extracted: 1307
# Song extracted: 1308
# Song extracted: 1309
# Song extracted: 1310
# Song extracted: 1311
# Song extracted: 1312
# Song extracted: 1313
# Song extracted: 1314
# Song extracted: 1315
# Song extracted: 1316
# Song extracted: 1317
# Song extracted: 1318
# Song extracted: 1319
# Song extracted: 1320
# Song extracted: 1321
# Song extracted: 1322
# Song extracted: 1323
# Song extracted: 1324
# Song extracted: 1325
# Song extracted: 1326
# Song extracted: 1327
# Song extracted: 1328
# Song extracted: 1329
# Song extracted: 1330
# Song extracted: 1331
# Song extracted: 1332
# Song extracted: 1333
# Song extracted: 1334
# Song extracted: 1335
# Song extracted: 1336
# Song extracted: 1337
# Song extracted: 1338
# Song extracted: 1339
# Song extracted: 1340
# Song extracted: 1341
# Song extracted: 1342
# Song extracted: 1343
# Song extracted: 1344
# Song extracted: 1345
# Song extracted: 1346
# Song extracted: 1347
# Song extracted: 1348
# Song extracted: 1349
# Song extracted: 1350
# Song extracted: 1351
# Song extracted: 1352
# Song extracted: 1353
# Song extracted: 1354
# Song extracted: 1355
# Song extracted: 1356
# Song extracted: 1357
# Song extracted: 1358
# Song extracted: 1359
# Song extracted: 1360
# Song extracted: 1361
# Song extracted: 1362
# Song extracted: 1363
# Song extracted: 1364
# Song extracted: 1365
# Song extracted: 1366
# Song extracted: 1367
# Song extracted: 1368
# Song extracted: 1369
# Song extracted: 1370
# Song extracted: 1371
# Song extracted: 1372
# Song extracted: 1373
# Song extracted: 1374
# Song extracted: 1375
# Song extracted: 1376
# Song extracted: 1377
# Song extracted: 1378
# Song extracted: 1379
# Song extracted: 1380
# Song extracted: 1381
# Song extracted: 1382
# Song extracted: 1383
# Song extracted: 1384
# Song extracted: 1385
# Song extracted: 1386
# Song extracted: 1387
# Song extracted: 1388
# Song extracted: 1389
# Song extracted: 1390
# Song extracted: 1391
# Song extracted: 1392
# Song extracted: 1393
# Song extracted: 1394
# Song extracted: 1395
# Song extracted: 1396
# Song extracted: 1397
# Song extracted: 1398
# Song extracted: 1399
# Song extracted: 1400
# Song extracted: 1401
# Song extracted: 1402
# Song extracted: 1403
# Song extracted: 1404
# Song extracted: 1405
# Song extracted: 1406
# Song extracted: 1407
# Song extracted: 1408
# Song extracted: 1409
# Song extracted: 1410
# Song extracted: 1411
# Song extracted: 1412
# Song extracted: 1413
# Song extracted: 1414
# Song extracted: 1415
# Song extracted: 1416
# Song extracted: 1417
# Song extracted: 1418
# Song extracted: 1419
# Song extracted: 1420
# Song extracted: 1421
# Song extracted: 1422
# Song extracted: 1423
# Song extracted: 1424
# Song extracted: 1425
# Song extracted: 1426
# Song extracted: 1427
# Song extracted: 1428
# Song extracted: 1429
# Song extracted: 1430
# Song extracted: 1431
# Song extracted: 1432
# Song extracted: 1433
# Song extracted: 1434
# Song extracted: 1435
# Song extracted: 1436
# Song extracted: 1437
# Song extracted: 1438
# Song extracted: 1439
# Song extracted: 1440
# Song extracted: 1441
# Song extracted: 1442
# Song extracted: 1443
# Song extracted: 1444
# Song extracted: 1445
# Song extracted: 1446
# Song extracted: 1447
# Song extracted: 1448
# Song extracted: 1449
# Song extracted: 1450
# Song extracted: 1451
# Song extracted: 1452
# Song extracted: 1453
# Song extracted: 1454
# Song extracted: 1455
# Song extracted: 1456
# Song extracted: 1457
# Song extracted: 1458
# Song extracted: 1459
# Song extracted: 1460
# Song extracted: 1461
# Song extracted: 1462
# Song extracted: 1463
# Song extracted: 1464
# Song extracted: 1465
# Song extracted: 1466
# Song extracted: 1467
# Song extracted: 1468
# Song extracted: 1469
# Song extracted: 1470
# Song extracted: 1471
# Song extracted: 1472
# Song extracted: 1473
# Song extracted: 1474
# Song extracted: 1475
# Song extracted: 1476
# Song extracted: 1477
# Song extracted: 1478
# Song extracted: 1479
# Song extracted: 1480
# Song extracted: 1481
# Song extracted: 1482
# Song extracted: 1483
# Song extracted: 1484
# Song extracted: 1485
# Song extracted: 1486
# Song extracted: 1487
# Song extracted: 1488
# Song extracted: 1489
# Song extracted: 1490
# Song extracted: 1491
# Song extracted: 1492
# Song extracted: 1493
# Song extracted: 1494
# Song extracted: 1495
# Song extracted: 1496
# Song extracted: 1497
# Song extracted: 1498
# Song extracted: 1499
# Song extracted: 1500
# Song extracted: 1501
# Song extracted: 1502
# Song extracted: 1503
# Song extracted: 1504
# Song extracted: 1505
# Song extracted: 1506
# Song extracted: 1507
# Song extracted: 1508
# Song extracted: 1509
# Song extracted: 1510
# Song extracted: 1511
# Song extracted: 1512
# Song extracted: 1513
# Song extracted: 1514
# Song extracted: 1515
# Song extracted: 1516
# Song extracted: 1517
# Song extracted: 1518
# Song extracted: 1519
# Song extracted: 1520
# Song extracted: 1521
# Song extracted: 1522
# Song extracted: 1523
# Song extracted: 1524
# Song extracted: 1525
# Song extracted: 1526
# Song extracted: 1527
# Song extracted: 1528
# Song extracted: 1529
# Song extracted: 1530
# Song extracted: 1531
# Song extracted: 1532
# Song extracted: 1533
# Song extracted: 1534
# Song extracted: 1535
# Song extracted: 1536
# Song extracted: 1537
# Song extracted: 1538
# Song extracted: 1539
# Song extracted: 1540
# Song extracted: 1541
# Song extracted: 1542
# Song extracted: 1543
# Song extracted: 1544
# Song extracted: 1545
# Song extracted: 1546
# Song extracted: 1547
# Song extracted: 1548
# Song extracted: 1549
# Song extracted: 1550
# Song extracted: 1551
# Song extracted: 1552
# Song extracted: 1553
# Song extracted: 1554
# Song extracted: 1555
# Song extracted: 1556
# Song extracted: 1557
# Song extracted: 1558
# Song extracted: 1559
# Song extracted: 1560
# Song extracted: 1561
# Song extracted: 1562
# Song extracted: 1563
# Song extracted: 1564
# Song extracted: 1565
# Song extracted: 1566
# Song extracted: 1567
# Song extracted: 1568
# Song extracted: 1569
# Song extracted: 1570
# Song extracted: 1571
# Song extracted: 1572
# Song extracted: 1573
# Song extracted: 1574
# Song extracted: 1575
# Song extracted: 1576
# Song extracted: 1577
# Song extracted: 1578
# Song extracted: 1579
# Song extracted: 1580
# Song extracted: 1581
# Song extracted: 1582
# Song extracted: 1583
# Song extracted: 1584
# Song extracted: 1585
# Song extracted: 1586
# Song extracted: 1587
# Song extracted: 1588
# Song extracted: 1589
# Song extracted: 1590
# Song extracted: 1591
# Song extracted: 1592
# Song extracted: 1593
# Song extracted: 1594
# Song extracted: 1595
# Song extracted: 1596
# Song extracted: 1597
# Song extracted: 1598
# Song extracted: 1599
# Song extracted: 1600
# Song extracted: 1601
# Song extracted: 1602
# Song extracted: 1603
# Song extracted: 1604
# Song extracted: 1605
# Song extracted: 1606
# Song extracted: 1607
# Song extracted: 1608
# Song extracted: 1609
# Song extracted: 1610
# Song extracted: 1611
# Song extracted: 1612
# Song extracted: 1613
# Song extracted: 1614
# Song extracted: 1615
# Song extracted: 1616
# Song extracted: 1617
# Song extracted: 1618
# Song extracted: 1619
# Song extracted: 1620
# Song extracted: 1621
# Song extracted: 1622
# Song extracted: 1623
# Song extracted: 1624
# Song extracted: 1625
# Song extracted: 1626
# Song extracted: 1627
# Song extracted: 1628
# Song extracted: 1629
# Song extracted: 1630
# Song extracted: 1631
# Song extracted: 1632
# Song extracted: 1633
# Song extracted: 1634
# Song extracted: 1635
# Song extracted: 1636
# Song extracted: 1637
# Song extracted: 1638
# Song extracted: 1639
# Song extracted: 1640
# Song extracted: 1641
# Song extracted: 1642
# Song extracted: 1643
# Song extracted: 1644
# Song extracted: 1645
# Song extracted: 1646
# Song extracted: 1647
# Song extracted: 1648
# Song extracted: 1649
# Song extracted: 1650
# Song extracted: 1651
# Song extracted: 1652
# Song extracted: 1653
# Song extracted: 1654
# Song extracted: 1655
# Song extracted: 1656
# Song extracted: 1657
# Song extracted: 1658
# Song extracted: 1659
# Song extracted: 1660
# Song extracted: 1661
# Song extracted: 1662
# Song extracted: 1663
# Song extracted: 1664
# Song extracted: 1665
# Song extracted: 1666
# Song extracted: 1667
# Song extracted: 1668
# Song extracted: 1669
# Song extracted: 1670
# Song extracted: 1671
# Song extracted: 1672
# Song extracted: 1673
# Song extracted: 1674
# Song extracted: 1675
# Song extracted: 1676
# Song extracted: 1677
# Song extracted: 1678
# Song extracted: 1679
# Song extracted: 1680
# Song extracted: 1681
# Song extracted: 1682
# Song extracted: 1683
# Song extracted: 1684
# Song extracted: 1685
# Song extracted: 1686
# Song extracted: 1687
# Song extracted: 1688
# Song extracted: 1689
# Song extracted: 1690
# Song extracted: 1691
# Song extracted: 1692
# Song extracted: 1693
# Song extracted: 1694
# Song extracted: 1695
# Song extracted: 1696
# Song extracted: 1697
# Song extracted: 1698
# Song extracted: 1699
# Song extracted: 1700
# Song extracted: 1701
# Song extracted: 1702
# Song extracted: 1703
# Song extracted: 1704
# Song extracted: 1705
# Song extracted: 1706
# Song extracted: 1707
# Song extracted: 1708
# Song extracted: 1709
# Song extracted: 1710
# Song extracted: 1711
# Song extracted: 1712
# Song extracted: 1713
# Song extracted: 1714
# Song extracted: 1715
# Song extracted: 1716
# Song extracted: 1717
# Song extracted: 1718
# Song extracted: 1719
# Song extracted: 1720
# Song extracted: 1721
# Song extracted: 1722
# Song extracted: 1723
# Song extracted: 1724
# Song extracted: 1725
# Song extracted: 1726
# Song extracted: 1727
# Song extracted: 1728
# Song extracted: 1729
# Song extracted: 1730
# Song extracted: 1731
# Song extracted: 1732
# Song extracted: 1733
# Song extracted: 1734
# Song extracted: 1735
# Song extracted: 1736
# Song extracted: 1737
# Song extracted: 1738
# Song extracted: 1739
# Song extracted: 1740
# Song extracted: 1741
# Song extracted: 1742
# Song extracted: 1743
# Song extracted: 1744
# Song extracted: 1745
# Song extracted: 1746
# Song extracted: 1747
# Song extracted: 1748
# Song extracted: 1749
# Song extracted: 1750
# Song extracted: 1751
# Song extracted: 1752
# Song extracted: 1753
# Song extracted: 1754
# Song extracted: 1755
# Song extracted: 1756
# Song extracted: 1757
# Song extracted: 1758
# Song extracted: 1759
# Song extracted: 1760
# Song extracted: 1761
# Song extracted: 1762
# Song extracted: 1763
# Song extracted: 1764
# Song extracted: 1765
# Song extracted: 1766
# Song extracted: 1767
# Song extracted: 1768
# Song extracted: 1769
# Song extracted: 1770
# Song extracted: 1771
# Song extracted: 1772
# Song extracted: 1773
# Song extracted: 1774
# Song extracted: 1775
# Song extracted: 1776
# Song extracted: 1777
# Song extracted: 1778
# Song extracted: 1779
# Song extracted: 1780
# Song extracted: 1781
# Song extracted: 1782
# Song extracted: 1783
# Song extracted: 1784
# Song extracted: 1785
# Song extracted: 1786
# Song extracted: 1787
# Song extracted: 1788
# Song extracted: 1789
# Song extracted: 1790
# Song extracted: 1791
# Song extracted: 1792
# Song extracted: 1793
# Song extracted: 1794
# Song extracted: 1795
# Song extracted: 1796
# Song extracted: 1797
# Song extracted: 1798
# Song extracted: 1799
# Song extracted: 1800
# Song extracted: 1801
# Song extracted: 1802
# Song extracted: 1803
# Song extracted: 1804
# Song extracted: 1805
# Song extracted: 1806
# Song extracted: 1807
# Song extracted: 1808
# Song extracted: 1809
# Song extracted: 1810
# Song extracted: 1811
# Song extracted: 1812
# Song extracted: 1813
# Song extracted: 1814
# Song extracted: 1815
# Song extracted: 1816
# Song extracted: 1817
# Song extracted: 1818
# Song extracted: 1819
# Song extracted: 1820
# Song extracted: 1821
# Song extracted: 1822
# Song extracted: 1823
# Song extracted: 1824
# Song extracted: 1825
# Song extracted: 1826
# Song extracted: 1827
# Song extracted: 1828
# Song extracted: 1829
# Song extracted: 1830
# Song extracted: 1831
# Song extracted: 1832
# Song extracted: 1833
# Song extracted: 1834
# Song extracted: 1835
# Song extracted: 1836
# Song extracted: 1837
# Song extracted: 1838
# Song extracted: 1839
# Song extracted: 1840
# Song extracted: 1841
# Song extracted: 1842
# Song extracted: 1843
# Song extracted: 1844
# Song extracted: 1845
# Song extracted: 1846
# Song extracted: 1847
# Song extracted: 1848
# Song extracted: 1849
# Song extracted: 1850
# Song extracted: 1851
# Song extracted: 1852
# Song extracted: 1853
# Song extracted: 1854
# Song extracted: 1855
# Song extracted: 1856
# Song extracted: 1857
# Song extracted: 1858
# Song extracted: 1859
# Song extracted: 1860
# Song extracted: 1861
# Song extracted: 1862
# Song extracted: 1863
# Song extracted: 1864
# Song extracted: 1865
# Song extracted: 1866
# Song extracted: 1867
# Song extracted: 1868
# Song extracted: 1869
# Song extracted: 1870
# Song extracted: 1871
# Song extracted: 1872
# Song extracted: 1873
# Song extracted: 1874
# Song extracted: 1875
# Song extracted: 1876
# Song extracted: 1877
# Song extracted: 1878
# Song extracted: 1879
# Song extracted: 1880
# Song extracted: 1881
# Song extracted: 1882
# Song extracted: 1883
# Song extracted: 1884
# Song extracted: 1885
# Song extracted: 1886
# Song extracted: 1887
# Song extracted: 1888
# Song extracted: 1889
# Song extracted: 1890
# Song extracted: 1891
# Song extracted: 1892
# Song extracted: 1893
# Song extracted: 1894
# Song extracted: 1895
# Song extracted: 1896
# Song extracted: 1897
# Song extracted: 1898
# Song extracted: 1899
# Song extracted: 1900
# Song extracted: 1901
# Song extracted: 1902
# Song extracted: 1903
# Song extracted: 1904
# Song extracted: 1905
# Song extracted: 1906
# Song extracted: 1907
# Song extracted: 1908
# Song extracted: 1909
# Song extracted: 1910
# Song extracted: 1911
# Song extracted: 1912
# Song extracted: 1913
# Song extracted: 1914
# Song extracted: 1915
# Song extracted: 1916
# Song extracted: 1917
# Song extracted: 1918
# Song extracted: 1919
# Song extracted: 1920
# Song extracted: 1921
# Song extracted: 1922
# Song extracted: 1923
# Song extracted: 1924
# Song extracted: 1925
# Song extracted: 1926
# Song extracted: 1927
# Song extracted: 1928
# Song extracted: 1929
# Song extracted: 1930
# Song extracted: 1931
# Song extracted: 1932
# Song extracted: 1933
# Song extracted: 1934
# Song extracted: 1935
# Song extracted: 1936
# Song extracted: 1937
# Song extracted: 1938
# Song extracted: 1939
# Song extracted: 1940
# Song extracted: 1941
# Song extracted: 1942
# Song extracted: 1943
# Song extracted: 1944
# Song extracted: 1945
# Song extracted: 1946
# Song extracted: 1947
# Song extracted: 1948
# Song extracted: 1949
# Song extracted: 1950
# Song extracted: 1951
# Song extracted: 1952
# Song extracted: 1953
# Song extracted: 1954
# Song extracted: 1955
# Song extracted: 1956
# Song extracted: 1957
# Song extracted: 1958
# Song extracted: 1959
# Song extracted: 1960
# Song extracted: 1961
# Song extracted: 1962
# Song extracted: 1963
# Song extracted: 1964
# Song extracted: 1965
# Song extracted: 1966
# Song extracted: 1967
# Song extracted: 1968
# Song extracted: 1969
# Song extracted: 1970
# Song extracted: 1971
# Song extracted: 1972
# Song extracted: 1973
# Song extracted: 1974
# Song extracted: 1975
# Song extracted: 1976
# Song extracted: 1977
# Song extracted: 1978
# Song extracted: 1979
# Song extracted: 1980
# Song extracted: 1981
# Song extracted: 1982
# Song extracted: 1983
# Song extracted: 1984
# Song extracted: 1985
# Song extracted: 1986
# Song extracted: 1987
# Song extracted: 1988
# Song extracted: 1989
# Song extracted: 1990
# Song extracted: 1991
# Song extracted: 1992
# Song extracted: 1993
# Song extracted: 1994
# Song extracted: 1995
# Song extracted: 1996
# Song extracted: 1997
# Song extracted: 1998
# Song extracted: 1999
# Song extracted: 2000
# Song extracted: 2001
# Song extracted: 2002
# Song extracted: 2003
# Song extracted: 2004
# Song extracted: 2005
# Song extracted: 2006
# Song extracted: 2007
# Song extracted: 2008
# Song extracted: 2009
# Song extracted: 2010
# Song extracted: 2011
# Song extracted: 2012
# Song extracted: 2013
# Song extracted: 2014
# Song extracted: 2015
# Song extracted: 2016
# Song extracted: 2017
# Song extracted: 2018
# Song extracted: 2019
# Song extracted: 2020
# Song extracted: 2021
# Song extracted: 2022
# Song extracted: 2023
# Song extracted: 2024
# Song extracted: 2025
# Song extracted: 2026
# Song extracted: 2027
# Song extracted: 2028
# Song extracted: 2029
# Song extracted: 2030
# Song extracted: 2031
# Song extracted: 2032
# Song extracted: 2033
# Song extracted: 2034
# Song extracted: 2035
# Song extracted: 2036
# Song extracted: 2037
# Song extracted: 2038
# Song extracted: 2039
# Song extracted: 2040
# Song extracted: 2041
# Song extracted: 2042
# Song extracted: 2043
# Song extracted: 2044
# Song extracted: 2045
# Song extracted: 2046
# Song extracted: 2047
# Song extracted: 2048
# Song extracted: 2049
# Song extracted: 2050
# Song extracted: 2051
# Song extracted: 2052
# Song extracted: 2053
# Song extracted: 2054
# Song extracted: 2055
# Song extracted: 2056
# Song extracted: 2057
# Song extracted: 2058
# Song extracted: 2059
# Song extracted: 2060
# Song extracted: 2061
# Song extracted: 2062
# Song extracted: 2063
# Song extracted: 2064
# Song extracted: 2065
# Song extracted: 2066
# Song extracted: 2067
# Song extracted: 2068
# Song extracted: 2069
# Song extracted: 2070
# Song extracted: 2071
# Song extracted: 2072
# Song extracted: 2073
# Song extracted: 2074
# Song extracted: 2075
# Song extracted: 2076
# Song extracted: 2077
# Song extracted: 2078
# Song extracted: 2079
# Song extracted: 2080
# Song extracted: 2081
# Song extracted: 2082
# Song extracted: 2083
# Song extracted: 2084
# Song extracted: 2085
# Song extracted: 2086
# Song extracted: 2087
# Song extracted: 2088
# Song extracted: 2089
# Song extracted: 2090
# Song extracted: 2091
# Song extracted: 2092
# Song extracted: 2093
# Song extracted: 2094
# Song extracted: 2095
# Song extracted: 2096
# Song extracted: 2097
# Song extracted: 2098
# Song extracted: 2099
# Song extracted: 2100
# Song extracted: 2101
# Song extracted: 2102
# Song extracted: 2103
# Song extracted: 2104
# Song extracted: 2105
# Song extracted: 2106
# Song extracted: 2107
# Song extracted: 2108
# Song extracted: 2109
# Song extracted: 2110
# Song extracted: 2111
# Song extracted: 2112
# Song extracted: 2113
# Song extracted: 2114
# Song extracted: 2115
# Song extracted: 2116
# Song extracted: 2117
# Song extracted: 2118
# Song extracted: 2119
# Song extracted: 2120
# Song extracted: 2121
# Song extracted: 2122
# Song extracted: 2123
# Song extracted: 2124
# Song extracted: 2125
# Song extracted: 2126
# Song extracted: 2127
# Song extracted: 2128
# Song extracted: 2129
# Song extracted: 2130
# Song extracted: 2131
# Song extracted: 2132
# Song extracted: 2133
# Song extracted: 2134
# Song extracted: 2135
# Song extracted: 2136
# Song extracted: 2137
# Song extracted: 2138
# Song extracted: 2139
# Song extracted: 2140
# Song extracted: 2141
# Song extracted: 2142
# Song extracted: 2143
# Song extracted: 2144
# Song extracted: 2145
# Song extracted: 2146
# Song extracted: 2147
# Song extracted: 2148
# Song extracted: 2149
# Song extracted: 2150
# Song extracted: 2151
# Song extracted: 2152
# Song extracted: 2153
# Song extracted: 2154
# Song extracted: 2155
# Song extracted: 2156
# Song extracted: 2157
# Song extracted: 2158
# Song extracted: 2159
# Song extracted: 2160
# Song extracted: 2161
# Song extracted: 2162
# Song extracted: 2163
# Song extracted: 2164
# Song extracted: 2165
# Song extracted: 2166
# Song extracted: 2167
# Song extracted: 2168
# Song extracted: 2169
# Song extracted: 2170
# Song extracted: 2171
# Song extracted: 2172
# Song extracted: 2173
# Song extracted: 2174
# Song extracted: 2175
# Song extracted: 2176
# Song extracted: 2177
# Song extracted: 2178
# Song extracted: 2179
# Song extracted: 2180
# Song extracted: 2181
# Song extracted: 2182
# Song extracted: 2183
# Song extracted: 2184
# Song extracted: 2185
# Song extracted: 2186
# Song extracted: 2187
# Song extracted: 2188
# Song extracted: 2189
# Song extracted: 2190
# Song extracted: 2191
# Song extracted: 2192
# Song extracted: 2193
# Song extracted: 2194
# Song extracted: 2195
# Song extracted: 2196
# Song extracted: 2197
# Song extracted: 2198
# Song extracted: 2199
# Song extracted: 2200
# Song extracted: 2201
# Song extracted: 2202
# Song extracted: 2203
# Song extracted: 2204
# Song extracted: 2205
# Song extracted: 2206
# Song extracted: 2207
# Song extracted: 2208
# Song extracted: 2209
# Song extracted: 2210
# Song extracted: 2211
# Song extracted: 2212
# Song extracted: 2213
# Song extracted: 2214
# Song extracted: 2215
# Song extracted: 2216
# Song extracted: 2217
# Song extracted: 2218
# Song extracted: 2219
# Song extracted: 2220
# Song extracted: 2221
# Song extracted: 2222
# Song extracted: 2223
# Song extracted: 2224
# Song extracted: 2225
# Song extracted: 2226
# Song extracted: 2227
# Song extracted: 2228
# Song extracted: 2229
# Song extracted: 2230
# Song extracted: 2231
# Song extracted: 2232
# Song extracted: 2233
# Song extracted: 2234
# Song extracted: 2235
# Song extracted: 2236
# Song extracted: 2237
# Song extracted: 2238
# Song extracted: 2239
# Song extracted: 2240
# Song extracted: 2241
# Song extracted: 2242
# Song extracted: 2243
# Song extracted: 2244
# Song extracted: 2245
# Song extracted: 2246
# Song extracted: 2247
# Song extracted: 2248
# Song extracted: 2249
# Song extracted: 2250
# Song extracted: 2251
# Song extracted: 2252
# Song extracted: 2253
# Song extracted: 2254
# Song extracted: 2255
# Song extracted: 2256
# Song extracted: 2257
# Song extracted: 2258
# Song extracted: 2259
# Song extracted: 2260
# Song extracted: 2261
# Song extracted: 2262
# Song extracted: 2263
# Song extracted: 2264
# Song extracted: 2265
# Song extracted: 2266
# Song extracted: 2267
# Song extracted: 2268
# Song extracted: 2269
# Song extracted: 2270
# Song extracted: 2271
# Song extracted: 2272
# Song extracted: 2273
# Song extracted: 2274
# Song extracted: 2275
# Song extracted: 2276
# Song extracted: 2277
# Song extracted: 2278
# Song extracted: 2279
# Song extracted: 2280
# Song extracted: 2281
# Song extracted: 2282
# Song extracted: 2283
# Song extracted: 2284
# Song extracted: 2285
# Song extracted: 2286
# Song extracted: 2287
# Song extracted: 2288
# Song extracted: 2289
# Song extracted: 2290
# Song extracted: 2291
# Song extracted: 2292
# Song extracted: 2293
# Song extracted: 2294
# Song extracted: 2295
# Song extracted: 2296
# Song extracted: 2297
# Song extracted: 2298
# Song extracted: 2299
# Song extracted: 2300
# Song extracted: 2301
# Song extracted: 2302
# Song extracted: 2303
# Song extracted: 2304
# Song extracted: 2305
# Song extracted: 2306
# Song extracted: 2307
# Song extracted: 2308
# Song extracted: 2309
# Song extracted: 2310
# Song extracted: 2311
# Song extracted: 2312
# Song extracted: 2313
# Song extracted: 2314
# Song extracted: 2315
# Song extracted: 2316
# Song extracted: 2317
# Song extracted: 2318
# Song extracted: 2319
# Song extracted: 2320
# Song extracted: 2321
# Song extracted: 2322
# Song extracted: 2323
# Song extracted: 2324
# Song extracted: 2325
# Song extracted: 2326
# Song extracted: 2327
# Song extracted: 2328
# Song extracted: 2329
# Song extracted: 2330
# Song extracted: 2331
# Song extracted: 2332
# Song extracted: 2333
# Song extracted: 2334
# Song extracted: 2335
# Song extracted: 2336
# Song extracted: 2337
# ...
# Song extracted: 4176
# Song extracted: 4177
# Song extracted: 4178
# Song extracted: 4179
# Song extracted: 4180
# Song extracted: 4181
# Song extracted: 4182
# Song extracted: 4183
# Song extracted: 4184
# Song extracted: 4185
# Song extracted: 4186
# Song extracted: 4187
# Song extracted: 4188
# Song extracted: 4189
# Song extracted: 4190
# Song extracted: 4191
# Song extracted: 4192
# Song extracted: 4193
# Song extracted: 4194
# Song extracted: 4195
# Song extracted: 4196
# Song extracted: 4197
# Song extracted: 4198
# Song extracted: 4199
# Song extracted: 4200
# Song extracted: 4201
# Song extracted: 4202
# Song extracted: 4203
# Song extracted: 4204
# Song extracted: 4205
# Song extracted: 4206
# Song extracted: 4207
# Song extracted: 4208
# Song extracted: 4209
# Song extracted: 4210
# Song extracted: 4211
# Song extracted: 4212
# Song extracted: 4213
# Song extracted: 4214
# Song extracted: 4215
# Song extracted: 4216
# Song extracted: 4217
# Song extracted: 4218
# Song extracted: 4219
# Song extracted: 4220
# Song extracted: 4221
# Song extracted: 4222
# Song extracted: 4223
# Song extracted: 4224
# Song extracted: 4225
# Song extracted: 4226
# Song extracted: 4227
# Song extracted: 4228
# Song extracted: 4229
# Song extracted: 4230
# Song extracted: 4231
# Song extracted: 4232
# Song extracted: 4233
# Song extracted: 4234
# Song extracted: 4235
# Song extracted: 4236
# Song extracted: 4237
# Song extracted: 4238
# Song extracted: 4239
# Song extracted: 4240
# Song extracted: 4241
# Song extracted: 4242
# Song extracted: 4243
# Song extracted: 4244
# Song extracted: 4245
# Song extracted: 4246
# Song extracted: 4247
# Song extracted: 4248
# Song extracted: 4249
# Song extracted: 4250
# Song extracted: 4251
# Song extracted: 4252
# Song extracted: 4253
# Song extracted: 4254
# Song extracted: 4255
# Song extracted: 4256
# Song extracted: 4257
# Song extracted: 4258
# Song extracted: 4259
# Song extracted: 4260
# Song extracted: 4261
# Song extracted: 4262
# Song extracted: 4263
# Song extracted: 4264
# Song extracted: 4265
# Song extracted: 4266
# Song extracted: 4267
# Song extracted: 4268
# Song extracted: 4269
# Song extracted: 4270
# Song extracted: 4271
# Song extracted: 4272
# Song extracted: 4273
# Song extracted: 4274
# Song extracted: 4275
# Song extracted: 4276
# Song extracted: 4277
# Song extracted: 4278
# Song extracted: 4279
# Song extracted: 4280
# Song extracted: 4281
# Song extracted: 4282
# Song extracted: 4283
# Song extracted: 4284
# Song extracted: 4285
# Song extracted: 4286
# Song extracted: 4287
# Song extracted: 4288
# Song extracted: 4289
# Song extracted: 4290
# Song extracted: 4291
# Song extracted: 4292
# Song extracted: 4293
# Song extracted: 4294
# Song extracted: 4295
# Song extracted: 4296
# Song extracted: 4297
# Song extracted: 4298
# Song extracted: 4299
# Song extracted: 4300
# Song extracted: 4301
# Song extracted: 4302
# Song extracted: 4303
# Song extracted: 4304
# Song extracted: 4305
# Song extracted: 4306
# Song extracted: 4307
# Song extracted: 4308
# Song extracted: 4309
# Song extracted: 4310
# Song extracted: 4311
# Song extracted: 4312
# Song extracted: 4313
# Song extracted: 4314
# Song extracted: 4315
# Song extracted: 4316
# Song extracted: 4317
# Song extracted: 4318
# Song extracted: 4319
# Song extracted: 4320
# Song extracted: 4321
# Song extracted: 4322
# Song extracted: 4323
# Song extracted: 4324
# Song extracted: 4325
# Song extracted: 4326
# Song extracted: 4327
# Song extracted: 4328
# Song extracted: 4329
# Song extracted: 4330
# Song extracted: 4331
# Song extracted: 4332
# Song extracted: 4333
# Song extracted: 4334
# Song extracted: 4335
# Song extracted: 4336
# Song extracted: 4337
# Song extracted: 4338
# Song extracted: 4339
# Song extracted: 4340
# Song extracted: 4341
# Song extracted: 4342
# Song extracted: 4343
# Song extracted: 4344
# Song extracted: 4345
# Song extracted: 4346
# Song extracted: 4347
# Song extracted: 4348
# Song extracted: 4349
# Song extracted: 4350
# Song extracted: 4351
# Song extracted: 4352
# Song extracted: 4353
# Song extracted: 4354
# Song extracted: 4355
# Song extracted: 4356
# Song extracted: 4357
# Song extracted: 4358
# Song extracted: 4359
# Song extracted: 4360
# Song extracted: 4361
# Song extracted: 4362
# Song extracted: 4363
# Song extracted: 4364
# Song extracted: 4365
# Song extracted: 4366
# Song extracted: 4367
# Song extracted: 4368
# Song extracted: 4369
# Song extracted: 4370
# Song extracted: 4371
# Song extracted: 4372
# Song extracted: 4373
# Song extracted: 4374
# Song extracted: 4375
# Song extracted: 4376
# Song extracted: 4377
# Song extracted: 4378
# Song extracted: 4379
# Song extracted: 4380
# Song extracted: 4381
# Song extracted: 4382
# Song extracted: 4383
# Song extracted: 4384
# Song extracted: 4385
# Song extracted: 4386
# Song extracted: 4387
# Song extracted: 4388
# Song extracted: 4389
# Song extracted: 4390
# Song extracted: 4391
# Song extracted: 4392
# Song extracted: 4393
# Song extracted: 4394
# Song extracted: 4395
# Song extracted: 4396
# Song extracted: 4397
# Song extracted: 4398
# Song extracted: 4399
# Song extracted: 4400
# Song extracted: 4401
# Song extracted: 4402
# Song extracted: 4403
# Song extracted: 4404
# Song extracted: 4405
# Song extracted: 4406
# Song extracted: 4407
# Song extracted: 4408
# Song extracted: 4409
# Song extracted: 4410
# Song extracted: 4411
# Song extracted: 4412
# Song extracted: 4413
# Song extracted: 4414
# Song extracted: 4415
# Song extracted: 4416
# Song extracted: 4417
# Song extracted: 4418
# Song extracted: 4419
# Song extracted: 4420
# Song extracted: 4421
# Song extracted: 4422
# Song extracted: 4423
# Song extracted: 4424
# Song extracted: 4425
# Song extracted: 4426
# Song extracted: 4427
# Song extracted: 4428
# Song extracted: 4429
# Song extracted: 4430
# Song extracted: 4431
# Song extracted: 4432
# Song extracted: 4433
# Song extracted: 4434
# Song extracted: 4435
# Song extracted: 4436
# Song extracted: 4437
# Song extracted: 4438
# Song extracted: 4439
# Song extracted: 4440
# Song extracted: 4441
# Song extracted: 4442
# Song extracted: 4443
# Song extracted: 4444
# Song extracted: 4445
# Song extracted: 4446
# Song extracted: 4447
# Song extracted: 4448
# Song extracted: 4449
# Song extracted: 4450
# Song extracted: 4451
# Song extracted: 4452
# Song extracted: 4453
# Song extracted: 4454
# Song extracted: 4455
# Song extracted: 4456
# Song extracted: 4457
# Song extracted: 4458
# Song extracted: 4459
# Song extracted: 4460
# Song extracted: 4461
# Song extracted: 4462
# Song extracted: 4463
# Song extracted: 4464
# Song extracted: 4465
# Song extracted: 4466
# Song extracted: 4467
# Song extracted: 4468
# Song extracted: 4469
# Song extracted: 4470
# Song extracted: 4471
# Song extracted: 4472
# Song extracted: 4473
# Song extracted: 4474
# Song extracted: 4475
# Song extracted: 4476
# Song extracted: 4477
# Song extracted: 4478
# Song extracted: 4479
# Song extracted: 4480
# Song extracted: 4481
# Song extracted: 4482
# Song extracted: 4483
# Song extracted: 4484
# Song extracted: 4485
# Song extracted: 4486
# Song extracted: 4487
# Song extracted: 4488
# Song extracted: 4489
# Song extracted: 4490
# Song extracted: 4491
# Song extracted: 4492
# Song extracted: 4493
# Song extracted: 4494
# Song extracted: 4495
# Song extracted: 4496
# Song extracted: 4497
# Song extracted: 4498
# Song extracted: 4499
# Song extracted: 4500
# Song extracted: 4501
# Song extracted: 4502
# Song extracted: 4503
# Song extracted: 4504
# Song extracted: 4505
# Song extracted: 4506
# Song extracted: 4507
# Song extracted: 4508
# Song extracted: 4509
# Song extracted: 4510
# Song extracted: 4511
# Song extracted: 4512
# Song extracted: 4513
# Song extracted: 4514
# Song extracted: 4515
# Song extracted: 4516
# Song extracted: 4517
# Song extracted: 4518
# Song extracted: 4519
# Song extracted: 4520
# Song extracted: 4521
# Song extracted: 4522
# Song extracted: 4523
# Song extracted: 4524
# Song extracted: 4525
# Song extracted: 4526
# Song extracted: 4527
# Song extracted: 4528
# Song extracted: 4529
# Song extracted: 4530
# Song extracted: 4531
# Song extracted: 4532
# Song extracted: 4533
# Song extracted: 4534
# Song extracted: 4535
# Song extracted: 4536
# Song extracted: 4537
# Song extracted: 4538
# Song extracted: 4539
# Song extracted: 4540
# Song extracted: 4541
# Song extracted: 4542
# Song extracted: 4543
# Song extracted: 4544
# Song extracted: 4545
# Song extracted: 4546
# Song extracted: 4547
# Song extracted: 4548
# Song extracted: 4549
# Song extracted: 4550
# Song extracted: 4551
# Song extracted: 4552
# Song extracted: 4553
# Song extracted: 4554
# Song extracted: 4555
# Song extracted: 4556
# Song extracted: 4557
# Song extracted: 4558
# Song extracted: 4559
# Song extracted: 4560
# Song extracted: 4561
# Song extracted: 4562
# Song extracted: 4563
# Song extracted: 4564
# Song extracted: 4565
# Song extracted: 4566
# Song extracted: 4567
# Song extracted: 4568
# Song extracted: 4569
# Song extracted: 4570
# Song extracted: 4571
# Song extracted: 4572
# Song extracted: 4573
# Song extracted: 4574
# Song extracted: 4575
# Song extracted: 4576
# Song extracted: 4577
# Song extracted: 4578
# Song extracted: 4579
# Song extracted: 4580
# Song extracted: 4581
# Song extracted: 4582
# Song extracted: 4583
# Song extracted: 4584
# Song extracted: 4585
# Song extracted: 4586
# Song extracted: 4587
# Song extracted: 4588
# Song extracted: 4589
# Song extracted: 4590
# Song extracted: 4591
# Song extracted: 4592
# Song extracted: 4593
# Song extracted: 4594
# Song extracted: 4595
# Song extracted: 4596
# Song extracted: 4597
# Song extracted: 4598
# Song extracted: 4599
# Song extracted: 4600
# Song extracted: 4601
# Song extracted: 4602
# Song extracted: 4603
# Song extracted: 4604
# Song extracted: 4605
# Song extracted: 4606
# Song extracted: 4607
# Song extracted: 4608
# Song extracted: 4609
# Song extracted: 4610
# Song extracted: 4611
# Song extracted: 4612
# Song extracted: 4613
# Song extracted: 4614
# Song extracted: 4615
# Song extracted: 4616
# Song extracted: 4617
# Song extracted: 4618
# Song extracted: 4619
# Song extracted: 4620
# Song extracted: 4621
# Song extracted: 4622
# Song extracted: 4623
# Song extracted: 4624
# Song extracted: 4625
# Song extracted: 4626
# Song extracted: 4627
# Song extracted: 4628
# Song extracted: 4629
# Song extracted: 4630
# Song extracted: 4631
# Song extracted: 4632
# Song extracted: 4633
# Song extracted: 4634
# Song extracted: 4635
# Song extracted: 4636
# Song extracted: 4637
# Song extracted: 4638
# Song extracted: 4639
# Song extracted: 4640
# Song extracted: 4641
# Song extracted: 4642
# Song extracted: 4643
# Song extracted: 4644
# Song extracted: 4645
# Song extracted: 4646
# Song extracted: 4647
# Song extracted: 4648
# Song extracted: 4649
# Song extracted: 4650
# Song extracted: 4651
# Song extracted: 4652
# Song extracted: 4653
# Song extracted: 4654
# Song extracted: 4655
# Song extracted: 4656
# Song extracted: 4657
# Song extracted: 4658
# Song extracted: 4659
# Song extracted: 4660
# Song extracted: 4661
# Song extracted: 4662
# Song extracted: 4663
# Song extracted: 4664
# Song extracted: 4665
# Song extracted: 4666
# Song extracted: 4667
# Song extracted: 4668
# Song extracted: 4669
# Song extracted: 4670
# Song extracted: 4671
# Song extracted: 4672
# Song extracted: 4673
# Song extracted: 4674
# Song extracted: 4675
# Song extracted: 4676
# Song extracted: 4677
# Song extracted: 4678
# Song extracted: 4679
# Song extracted: 4680
# Song extracted: 4681
# Song extracted: 4682
# Song extracted: 4683
# Song extracted: 4684
# Song extracted: 4685
# Song extracted: 4686
# Song extracted: 4687
# Song extracted: 4688
# Song extracted: 4689
# Song extracted: 4690
# Song extracted: 4691
# Song extracted: 4692
# Song extracted: 4693
# Song extracted: 4694
# Song extracted: 4695
# Song extracted: 4696
# Song extracted: 4697
# Song extracted: 4698
# Song extracted: 4699
# Song extracted: 4700
# Song extracted: 4701
# Song extracted: 4702
# Song extracted: 4703
# Song extracted: 4704
# Song extracted: 4705
# Song extracted: 4706
# Song extracted: 4707
# Song extracted: 4708
# Song extracted: 4709
# Song extracted: 4710
# Song extracted: 4711
# Song extracted: 4712
# Song extracted: 4713
# Song extracted: 4714
# Song extracted: 4715
# Song extracted: 4716
# Song extracted: 4717
# Song extracted: 4718
# Song extracted: 4719
# Song extracted: 4720
# Song extracted: 4721
# Song extracted: 4722
# Song extracted: 4723
# Song extracted: 4724
# Song extracted: 4725
# Song extracted: 4726
# Song extracted: 4727
# Song extracted: 4728
# Song extracted: 4729
# Song extracted: 4730
# Song extracted: 4731
# Song extracted: 4732
# Song extracted: 4733
# Song extracted: 4734
# Song extracted: 4735
# Song extracted: 4736
# Song extracted: 4737
# Song extracted: 4738
# (4739, 18)
# Tiempo ejecución extracción: 0:45:53.043049
#                                            name         artist  \
# 0                                    Solo Dance  Martin Jensen
# 1                                  Duro y Suave   Leslie Grace
# 2           The Greatest (feat. Kendrick Lamar)            Sia
# 3                           Puesto Pa' Guerrial      Bad Bunny
# 4                                   Ojalá Amiga      El Barrio
# ...                                         ...            ...
# 4734                                  Waterfall       Stargate
# 4735                           Caza de pañuelos         Rayden
# 4736                                 La Cintura   Alvaro Soler
# 4737  Tú Y Yo (feat. Nicky Jam & Justin Quiles)      Valentino
# 4738                                 Gucci Gang       Lil Pump
#
#                                           album release_date    length  \
# 0                                    Solo Dance   2016-11-04  0.304505
# 1                                  Duro y Suave   2018-01-19  0.377225
# 2               This Is Acting (Deluxe Version)   2016-10-21  0.382783
# 3                                      YHLQMDLG   2020-02-28  0.338382
# 4                         Las Costuras del Alma   2017-10-27  0.466059
# ...                                         ...          ...       ...
# 4734                                  Waterfall   2017-03-10  0.360167
# 4735                           Caza de pañuelos   2018-09-28  0.296368
# 4736                             Mar de Colores   2018-09-07  0.370438
# 4737  Tú Y Yo (feat. Nicky Jam & Justin Quiles)   2018-07-27  0.360308
# 4738                                   Lil Pump   2017-10-06  0.191662
#
#       popularity  acousticness  danceability  energy  instrumentalness  \
# 0       0.010526        0.0435         0.744   0.836          0.000000
# 1       0.663158        0.1110         0.769   0.721          0.000059
# 2       0.747368        0.0102         0.668   0.725          0.000479
# 3       0.694737        0.3110         0.867   0.686          0.000000
# 4       0.000000        0.0658         0.559   0.929          0.000000
# ...          ...           ...           ...     ...               ...
# 4734    0.610526        0.0987         0.372   0.919          0.000000
# 4735    0.263158        0.3090         0.502   0.615          0.000097
# 4736    0.000000        0.0201         0.706   0.845          0.000000
# 4737    0.610526        0.1990         0.805   0.786          0.000000
# 4738    0.715789        0.2390         0.936   0.523          0.000000
#
#       liveness  loudness  speechiness  valence     tempo  time_signature  \
# 0       0.1940  0.899742     0.070711    0.360  0.541989               4
# 1       0.0505  0.834192     0.213389    0.618  0.447762               4
# 2       0.0561  0.782555     0.370990    0.729  0.904897               4
# 3       0.1000  0.807212     0.308229    0.658  0.659862               4
# 4       0.3380  0.799045     0.068759    0.795  0.796829               4
# ...        ...       ...          ...      ...       ...             ...
# 4734    0.2340  0.922231     0.418410    0.419  0.861718               4
# 4735    0.2070  0.719203     0.285914    0.388  0.867040               4
# 4736    0.3580  0.846159     0.096513    0.742  0.471509               4
# 4737    0.1970  0.836233     0.050767    0.751  0.447786               4
# 4738    0.1170  0.764244     0.083264    0.699  0.565202               4
#
#                   spotify_id  release_date_year
# 0     6HUnnBwYZqcED1eQztxMBN               2016
# 1     31M5m42C3EGlbydf9XB5to               2018
# 2     7xHWNBFm6ObGEQPaUxHuKO               2016
# 3     5gCg2qMPzKkW4jS4dBKdDs               2020
# 4     6kBngWUWIstgn9LtIYPsvA               2017
# ...                      ...                ...
# 4734  7pYFPMeK0TnaTGdS6qOtEr               2017
# 4735  0nsVV5fBpNAcrVB7Ki8DGd               2018
# 4736  3I7tLVbxJlrRUum7JdPJvH               2018
# 4737  58smOywZbVu8AjWutppiQA               2018
# 4738  43ZyHQITOjhciSUUNPVRHc               2017
#
# [4739 rows x 18 columns]

# %%
dataframe_extraction_timeseries
# Out:
#                                            name         artist  \
# 0                                    Solo Dance  Martin Jensen
# 1                                  Duro y Suave   Leslie Grace
# 2           The Greatest (feat. Kendrick Lamar)            Sia
# 3                           Puesto Pa' Guerrial      Bad Bunny
# 4                                   Ojalá Amiga      El Barrio
# ...                                         ...            ...
# 4734                                  Waterfall       Stargate
# 4735                           Caza de pañuelos         Rayden
# 4736                                 La Cintura   Alvaro Soler
# 4737  Tú Y Yo (feat. Nicky Jam & Justin Quiles)      Valentino
# 4738                                 Gucci Gang       Lil Pump
#
#                                           album release_date    length  \
# 0                                    Solo Dance   2016-11-04  0.304505
# 1                                  Duro y Suave   2018-01-19  0.377225
# 2               This Is Acting (Deluxe Version)   2016-10-21  0.382783
# 3                                      YHLQMDLG   2020-02-28  0.338382
# 4                         Las Costuras del Alma   2017-10-27  0.466059
# ...                                         ...          ...       ...
# 4734                                  Waterfall   2017-03-10  0.360167
# 4735                           Caza de pañuelos   2018-09-28  0.296368
# 4736                             Mar de Colores   2018-09-07  0.370438
# 4737  Tú Y Yo (feat. Nicky Jam & Justin Quiles)   2018-07-27  0.360308
# 4738                                   Lil Pump   2017-10-06  0.191662
#
#       popularity  acousticness  danceability  energy  instrumentalness  \
# 0       0.010526        0.0435         0.744   0.836          0.000000
# 1       0.663158        0.1110         0.769   0.721          0.000059
# 2       0.747368        0.0102         0.668   0.725          0.000479
# 3       0.694737        0.3110         0.867   0.686          0.000000
# 4       0.000000        0.0658         0.559   0.929          0.000000
# ...          ...           ...           ...     ...               ...
# 4734    0.610526        0.0987         0.372   0.919          0.000000
# 4735    0.263158        0.3090         0.502   0.615          0.000097
# 4736    0.000000        0.0201         0.706   0.845          0.000000
# 4737    0.610526        0.1990         0.805   0.786          0.000000
# 4738    0.715789        0.2390         0.936   0.523          0.000000
#
#       liveness  loudness  speechiness  valence     tempo  time_signature  \
# 0       0.1940  0.899742     0.070711    0.360  0.541989               4
# 1       0.0505  0.834192     0.213389    0.618  0.447762               4
# 2       0.0561  0.782555     0.370990    0.729  0.904897               4
# 3       0.1000  0.807212     0.308229    0.658  0.659862               4
# 4       0.3380  0.799045     0.068759    0.795  0.796829               4
# ...        ...       ...          ...      ...       ...             ...
# 4734    0.2340  0.922231     0.418410    0.419  0.861718               4
# 4735    0.2070  0.719203     0.285914    0.388  0.867040               4
# 4736    0.3580  0.846159     0.096513    0.742  0.471509               4
# 4737    0.1970  0.836233     0.050767    0.751  0.447786               4
# 4738    0.1170  0.764244     0.083264    0.699  0.565202               4
#
#                   spotify_id  release_date_year
# 0     6HUnnBwYZqcED1eQztxMBN               2016
# 1     31M5m42C3EGlbydf9XB5to               2018
# 2     7xHWNBFm6ObGEQPaUxHuKO               2016
# 3     5gCg2qMPzKkW4jS4dBKdDs               2020
# 4     6kBngWUWIstgn9LtIYPsvA               2017
# ...                      ...                ...
# 4734  7pYFPMeK0TnaTGdS6qOtEr               2017
# 4735  0nsVV5fBpNAcrVB7Ki8DGd               2018
# 4736  3I7tLVbxJlrRUum7JdPJvH               2018
# 4737  58smOywZbVu8AjWutppiQA               2018
# 4738  43ZyHQITOjhciSUUNPVRHc               2017
#
# [4739 rows x 18 columns]

# %% [markdown]
# # Extracción GÉNEROS desde API SPOTIFY

# %% [markdown]
# Para identificar cada canción con un género se plantearon incialmente dos formas:
# 1. Crear un modelo de clasificación, que por sus features, clasificara todas las canciones en grupos que luego identifciariamos. En internet encontré mucha documentación y trabajos que hacen esto, y en la mayoría no subían de un score de 70-80, por lo que era difícil una buena clasificación por las features. Aún así, hice algunas pruebas y no conseguí buenos resultados, como esperaba. Hay que tener en cuenata además que nos géneros es un constructo humano y que hay muchos actualmente.
# 2. De la API de Spotify sacar directamente los géneros del artistas y con un análisis previo de los datos, crear grupos generalizables teniendo en cuenta los nombres de los géneros. Por ejemplo, si una canción estaba clasificada como "trap espanol", se le agrupaba en el género hiphop, por considerar yo mismo que entra dentro de este grupo por su parecido. Evidemente esto supuso también escuchar muchos géneros que ni conocía y el nombre no daba pistas para clasificarlos.
#
# **Elegí el segundo camino.**
#
# El problema del segundo camino era que el género no se puede sacar por la información de las canciones con la API de Spotify, el género es una etiqueta/feature que solo está asignada a los artistas. Por lo tanto no me quedaba otra que extraer esta información de los artistas y luego unirla al dataframe de las canciones.
#
# Elaboramos el script para extraer los géneros de cada artista.

# %%
# IMPORTANTE!!! Esta celda tarda en ejecutarse

# Selecciono la lista final a extraer completa
list_toextract_artist = test_list_artist

# Función para extraerlos, en lotes de 50 porque es el máximo que te deja la API de Spotify
def extract_artist(artist_list):
    count_artist= 0
    data = ['test11111111', 'tes111111', 'test111111', 0, 0]
    df_final = pd.DataFrame([data], columns=["id", "name", "genres", 'followers', 'popularity'])
    
    API_LIMIT = 50
    search_list = []

    for artist in artist_list:
        count_artist += 1
        search_results = sp.search(q = 'artist:"{}"'.format(artist), type="artist",  limit=API_LIMIT)
        
        count_oneartist= 0 # Se añade un contador par quedarnos sólo con la primera búsqueda que he comprobado que siempre es la buena.
        for t in search_results['artists']['items']:
            count_oneartist += 1
            if count_oneartist ==2:
                break
            else:
                search_list += [[t["id"], t["name"], t["genres"], t['followers']['total'], t['popularity']]]
        
        df_search = pd.DataFrame(search_list, columns=["id", "name", "genres", 'followers', 'popularity'])
        
        df_final = df_final.append(df_search) # El problema de esto es que crea duplicados pero no nos afecta en lo que necesitamos
    print('Artist count:', count_artist)  
    return df_final

# Extracción de los datos
Time1 = datetime.now()
df_genres = extract_artist(list_toextract_artist)
Time2 = datetime.now()

# Exportamos
df_genres.to_csv("data_allyear/data_ana_genres.csv", sep = ',')

print("Tiempo ejecución:", Time2 -Time1)
print(df_genres.shape)
df_genres.head(6)
# Out:
# Artist count: 960
# Tiempo ejecución: 0:01:34.312848
# (457318, 5)
#                        id            name  \
# 0            test11111111       tes111111
# 0  6g0Wah2YFtb1rFgKhUktlo  Raphael Saadiq
# 0  6g0Wah2YFtb1rFgKhUktlo  Raphael Saadiq
# 1  5sK8BsvyDl4TFA6KaBf8or    Charly Black
# 0  6g0Wah2YFtb1rFgKhUktlo  Raphael Saadiq
# 1  5sK8BsvyDl4TFA6KaBf8or    Charly Black
#
#                                               genres  followers  popularity
# 0                                         test111111          0           0
# 0  [funk, indie soul, neo soul, r&b, soul, urban ...     416832          59
# 0  [funk, indie soul, neo soul, r&b, soul, urban ...     416832          59
# 1                                        [dancehall]     223113          64
# 0  [funk, indie soul, neo soul, r&b, soul, urban ...     416832          59
# 1                                        [dancehall]     223113          64

# %%
# IMPORTANTE!! Tarda en ejecutarse dependiendo del número de artistas

# Creamos una copia de la columna genres para mantenerla y la trasnformo a strings
df_genres['genres_together'] = df_genres['genres'].copy()
df_genres['genres_together'] = [','.join(i) if isinstance(i, list) else i for i in df_genres['genres_together']]

# Como la columna genres es una lista con los diferentes géneros, he preferido separarlo en columnas y mantener ciertas columnas sólo
df_genres2 = pd.concat([df_genres['genres'].apply(pd.Series), df_genres[['genres_together',
                                                                         'id',
                                                                         "name",
                                                                         'followers',
                                                                         'popularity']]], axis = 1)
# Quitamos los artistas duplicados
df_genres3 = df_genres2.drop_duplicates(df_genres2.columns[~df_genres2.columns.isin(['id'])])

#Renombramos columnas por nuestra salud de luego entenderlo mejor
df_genres4 = df_genres3.rename(columns={0:'genre1',
                   1:'genre2',
                   2:'genre3',
                   3:'genre4',
                   4:'genre5',
                   5:'genre6',
                   6:'genre7',
                   7:'genre8',
                   8:'genre9',
                   9:'genre10',
                   'genres_together':'genres_together',
                   'id':'artist_id',
                   'name':'Artist',
                   'followers':'artist_followers',
                   'popularity':'artist_popularity'}).copy()
print(df_genres4.shape)
print(len(df_genres4['Artist'].unique()))
df_genres4.head(20)
# Out:
# (939, 16)
# 939
#                        genre1              genre2                   genre3  \
# 0                  test111111                 NaN                      NaN
# 0                        funk          indie soul                 neo soul
# 1                   dancehall                 NaN                      NaN
# 2                  eurovision       norwegian pop                      NaN
# 3             icelandic indie      icelandic rock  modern alternative rock
# 4            australian psych     neo-psychedelic                      NaN
# 5                british soul          indie soul      uk contemporary r&b
# 6                 rap espanol         spanish pop                      NaN
# 7                       latin           latin pop             modern salsa
# 8                modern salsa                 NaN                      NaN
# 9               pop argentino         trap latino                      NaN
# 10                        NaN                 NaN                      NaN
# 11           canadian hip hop                 pop                      NaN
# 12  canadian contemporary r&b        canadian pop                dance pop
# 13                  dance pop      electro latino                    latin
# 14          argentine hip hop           reggaeton           trap argentino
# 15                  dance pop                 edm               electropop
# 16            adult standards  brill building pop                   motown
# 17                      banda             corrido                  norteno
# 18                  dance pop                 pop                pop dance
#
#                      genre4            genre5              genre6  \
# 0                       NaN               NaN                 NaN
# 0                       r&b              soul  urban contemporary
# 1                       NaN               NaN                 NaN
# 2                       NaN               NaN                 NaN
# 3                       NaN               NaN                 NaN
# 4                       NaN               NaN                 NaN
# 5                       NaN               NaN                 NaN
# 6                       NaN               NaN                 NaN
# 7                     salsa          tropical                 NaN
# 8                       NaN               NaN                 NaN
# 9                       NaN               NaN                 NaN
# 10                      NaN               NaN                 NaN
# 11                      NaN               NaN                 NaN
# 12               electropop               pop           pop dance
# 13                latin pop         reggaeton         trap latino
# 14              trap latino               NaN                 NaN
# 15                      pop         pop dance      tropical house
# 16                      NaN               NaN                 NaN
# 17  nuevo regional mexicano  regional mexican            sierreno
# 18            post-teen pop    tropical house              uk pop
#
#            genre7 genre8 genre9 genre10   10  \
# 0             NaN    NaN    NaN     NaN  NaN
# 0             NaN    NaN    NaN     NaN  NaN
# 1             NaN    NaN    NaN     NaN  NaN
# 2             NaN    NaN    NaN     NaN  NaN
# 3             NaN    NaN    NaN     NaN  NaN
# 4             NaN    NaN    NaN     NaN  NaN
# 5             NaN    NaN    NaN     NaN  NaN
# 6             NaN    NaN    NaN     NaN  NaN
# 7             NaN    NaN    NaN     NaN  NaN
# 8             NaN    NaN    NaN     NaN  NaN
# 9             NaN    NaN    NaN     NaN  NaN
# 10            NaN    NaN    NaN     NaN  NaN
# 11            NaN    NaN    NaN     NaN  NaN
# 12  post-teen pop    NaN    NaN     NaN  NaN
# 13       tropical    NaN    NaN     NaN  NaN
# 14            NaN    NaN    NaN     NaN  NaN
# 15            NaN    NaN    NaN     NaN  NaN
# 16            NaN    NaN    NaN     NaN  NaN
# 17            NaN    NaN    NaN     NaN  NaN
# 18            NaN    NaN    NaN     NaN  NaN
#
#                                       genres_together               artist_id  \
# 0                                          test111111            test11111111
# 0   funk,indie soul,neo soul,r&b,soul,urban contem...  6g0Wah2YFtb1rFgKhUktlo
# 1                                           dancehall  5sK8BsvyDl4TFA6KaBf8or
# 2                            eurovision,norwegian pop  0chh7dlaUzEreDTulHiOlm
# 3   icelandic indie,icelandic rock,modern alternat...  7jdFEYD2LTYjfwxOdlVjmc
# 4                    australian psych,neo-psychedelic  5INjqkS1o8h1imAzPqGZBb
# 5         british soul,indie soul,uk contemporary r&b  1Q2mS59tFYLm2KGFoCgWN4
# 6                             rap espanol,spanish pop  4ckWVaYN8j0EZrNFRHmxZx
# 7         latin,latin pop,modern salsa,salsa,tropical  4wLXwxDeWQ8mtUIRPxGiD6
# 8                                        modern salsa  2ap4aQTG8zcKmzRjqlVmMd
# 9                           pop argentino,trap latino  1DxLCyH42yaHKGK3cl5bvG
# 10                                                     5MLIxVYkY4Fc2dwdaYSS8G
# 11                               canadian hip hop,pop  4rTv3Ejc7hKMtmoBOK1B4T
# 12  canadian contemporary r&b,canadian pop,dance p...  2wUjUUtkb5lvLKcGKsKqsR
# 13  dance pop,electro latino,latin,latin pop,regga...  1ackd5XprZEkH3McKbQD51
# 14  argentine hip hop,reggaeton,trap argentino,tra...  3vQ0GE3mI0dAaxIMYe5g7z
# 15  dance pop,edm,electropop,pop,pop dance,tropica...  69GGBxA162lTqCwzJG5jLp
# 16          adult standards,brill building pop,motown  391oLRVmoTkumiN79HkTWu
# 17  banda,corrido,norteno,nuevo regional mexicano,...  4J13m9IZh03PEhoxAxRhXO
# 18  dance pop,pop,pop dance,post-teen pop,tropical...  1zNqDE7qDGCsyzJwohVaoX
#
#               Artist  artist_followers  artist_popularity
# 0          tes111111                 0                  0
# 0     Raphael Saadiq            416832                 59
# 1       Charly Black            223113                 64
# 2             KEiiNO             27592                 56
# 3              KALEO           1144882                 73
# 4        Tame Impala           4607070                 83
# 5       Samm Henshaw            180319                 60
# 6              Marmi              7114                 58
# 7       Marc Anthony           5064701                 81
# 8             Lafame              1859                 39
# 9      Maria Becerra            549788                 76
# 10       Suriel Hess             52062                 47
# 11         Ali Gatie           1548112                 78
# 12      Alessia Cara           8309325                 82
# 13        Juan Magán           1541185                 75
# 14      Paulo Londra          11981560                 79
# 15  The Chainsmokers          17337159                 85
# 16      Darlene Love             36744                 64
# 17     Gerardo Ortiz           4576976                 76
# 18        Anne-Marie           7044243                 83

# %%
number_genres = df_genres4.genre1.value_counts()
number_genres.head(20)
# Out:
# dance pop            102
# latin                 89
# eurovision            25
# latin talent show     23
# cantautor             22
# colombian pop         21
# rap espanol           21
# adult standards       21
# flamenco urbano       17
# reggaeton             16
# latin viral pop       13
# spanish pop           13
# pop                   12
# latin pop             12
# villancicos           11
# urbano espanol        10
# argentine hip hop     10
# pop rap               10
# latin arena pop        9
# edm                    9
# Name: genre1, dtype: int64

# %%
# Hacemos una prueba con un artista
df_genres4[df_genres4['Artist'] == 'Lafame']
# Out:
#          genre1 genre2 genre3 genre4 genre5 genre6 genre7 genre8 genre9  \
# 8  modern salsa    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   genre10   10 genres_together               artist_id  Artist  \
# 8     NaN  NaN    modern salsa  2ap4aQTG8zcKmzRjqlVmMd  Lafame
#
#    artist_followers  artist_popularity
# 8              1859                 39

# %%
# Decido aprovechar y normalizar también el artist popularity por si lo uso posteriormente
features_to_normalize2 = ['artist_popularity']
df_genres4[features_to_normalize2] = df_genres4[features_to_normalize2].apply(lambda x:(x-x.min()) / (x.max()-x.min()))

# Reseteo index y quito fila y columnas sobrantes
df_genres5 = df_genres4.reset_index()
df_genres6 = df_genres5.drop(['index'], axis=1)
df_genres7 = df_genres6.drop(df_genres6.index[0])

# Lo vemos
print(df_genres7.shape)
df_genres7.head(4)

# Exportamos
df_genres7.to_csv("data_allyear/data_ana_timeseries_genres.csv", sep = ',')
# Out:
# (938, 16)

# %% [markdown]
# ## Agrupación de géneros

# %% [markdown]
# De los artistas hemos extraido los géneros en los que están clasificados en Spotify, que no nos dice solo uno, sino hasta 10 diferentes, lo que nos dificulta el análisis. Algunos artistas tienen hasta 7 géneros asignados que pueden coincidir o no con otros artistas. Esto puede desvirtuar el análisis y dificultar la agrupación de estilos, porque si, por ejemplo, una canción puede tener como género 1 un género muy específico (ej. colombian pop) y está como el primero en la lista del artista, en vez de un género más general (ej. pop).
#
# Tras analizar los valores principales, vemos que el género "latin" es muy ambiguo y no nos ayuda a distinguir, por lo que decido que el siguiente proceso para depurar el género: a los que en el genre1 sea "latin", se les asignará el valor en genre2, que es más específico y los que el genre1 no sea latin se les asignara ese genre1. También si en el genre2 es "latin pop", que se quede con el genre3

# %%
# De nuevo cargo los CSVs
df_genres = pd.read_csv("data_allyear/data_ana_timeseries_genres.csv", sep = ',')
df_features = pd.read_csv("data_allyear/data_ana_timeseries.csv", sep = ',', parse_dates=['release_date_year'])
df_streamsongs = pd.read_csv("data_allyear/data_ana_timeseries_streamsongs.csv", sep = ',', parse_dates=['date','year_month'])
print('Tamaño inicial: ',df_genres.shape)
# Out:
# Tamaño inicial:  (938, 17)

# %%
df_genre_initial = pd.value_counts(df_genres.genre1)
df_genre_initial.head(60)
# df_genre_initial.count()
# Out:
# dance pop                    102
# latin                         89
# eurovision                    25
# latin talent show             23
# cantautor                     22
# rap espanol                   21
# adult standards               21
# colombian pop                 21
# flamenco urbano               17
# reggaeton                     16
# latin viral pop               13
# spanish pop                   13
# latin pop                     12
# pop                           12
# villancicos                   11
# urbano espanol                10
# pop rap                       10
# argentine hip hop             10
# edm                            9
# trap latino                    9
# latin arena pop                9
# dominican pop                  8
# electropop                     8
# cubaton                        7
# album rock                     7
# dembow                         7
# boy band                       7
# pop flamenco                   6
# australian pop                 6
# melodic rap                    6
# alternative metal              6
# modern rock                    6
# spanish hip hop                6
# hip hop                        6
# reggaeton flow                 5
# atl hip hop                    5
# alternative dance              4
# canadian hip hop               4
# r&b en espanol                 4
# canadian contemporary r&b      4
# hollywood                      4
# contemporary country           4
# neo mellow                     4
# bachata                        4
# rap                            4
# electro latino                 4
# emo rap                        4
# perreo                         3
# funk carioca                   3
# irish rock                     3
# electro house                  3
# musica para ninos              3
# british soul                   3
# dance rock                     3
# french indie pop               3
# spanish indie pop              3
# musical advocacy               3
# italian adult pop              3
# corrido                        3
# big room                       3
# Name: genre1, dtype: int64

# %%
'''# Aplicación de agrupación 1
data_ana_nolatinfirst = df_genres[df_genres['genre1'] != 'latin']
data_ana_latinfirst = df_genres[df_genres['genre1'] == 'latin']


df_genres.loc[df_genres.genre1 == 'latin', 'genre_depurated'] = data_ana_nolatinfirst['genre2']
df_genres.loc[df_genres.genre2 == 'latin', 'genre_depurated'] = data_ana_nolatinfirst['genre3']
df_genres.loc[df_genres.genre1 != 'latin', 'genre_depurated'] = data_ana_nolatinfirst['genre1']

df_genres[df_genres['genre1'] == 'latin alternative']
'''
# Out:
#      Unnamed: 0             genre1         genre2           genre3  \
# 58           59  latin alternative     latin rock  rock en espanol
# 383         384  latin alternative    spanish pop              NaN
# 552         553  latin alternative  latin hip hop       rap latina
#
#               genre4 genre5 genre6 genre7 genre8 genre9 genre10   10  \
# 58               NaN    NaN    NaN    NaN    NaN    NaN     NaN  NaN
# 383              NaN    NaN    NaN    NaN    NaN    NaN     NaN  NaN
# 552  spanish hip hop    NaN    NaN    NaN    NaN    NaN     NaN  NaN
#
#                                        genres_together  \
# 58        latin alternative,latin rock,rock en espanol
# 383                      latin alternative,spanish pop
# 552  latin alternative,latin hip hop,rap latina,spa...
#
#                   artist_id          Artist  artist_followers  \
# 58   4uqzzJg3ww5eH7IgGV7DMT         Bunbury           1625351
# 383  7mUBMaZW1MXGswaneb0JTT          Macaco            366848
# 552  3Ces1OJeGOVGcUB0wPaPXJ  Mala Rodríguez            390717
#
#      artist_popularity    genre_depurated
# 58                0.73  latin alternative
# 383               0.63  latin alternative
# 552               0.63  latin alternative

# %%
# Aplicación de agrupación

#Quitamis un warning deprecated que nos sale
import warnings
warnings.filterwarnings('ignore')

data_ana_corona = df_genres

# Grupos de géneros:
list_genres_pop = 'pop, k-pop, boy band, eurovision, carnaval'
list_genres_dance = 'dance, tropical, edm, electropop, big room'
list_genres_rock = 'rock, indie'
list_genres_reggaeton = 'dembow, reggaeton, champeta, cubaton'
list_genres_rap = "rap, hip hop, funk, trap, r&b"
cantautor = 'cantautor, flamenco'

# Reglas de categorización (busqué formas de hacerlo más nuevas, pero no cosneguí que funcionara)
data_ana_corona['genre_depurated_final'] = pd.np.where(data_ana_corona.genre1.str.contains("dance"), 'dance, electro and ambient',
                              pd.np.where(data_ana_corona.genre1.str.contains("tropical"), 'dance, electro and ambient',            
                              pd.np.where(data_ana_corona.genre1.str.contains("edm"), 'dance, electro and ambient',
                              pd.np.where(data_ana_corona.genre1.str.contains("electropop"), 'dance, electro and ambient',
                              pd.np.where(data_ana_corona.genre1.str.contains("big room"), 'dance, electro and ambient',
                              pd.np.where(data_ana_corona.genre1.str.contains("new french"), 'dance, electro and ambient',
                              pd.np.where(data_ana_corona.genre1.str.contains("house"), 'dance, electro and ambient',
                                          
                              pd.np.where(data_ana_corona.genre1.str.contains("pop"), 'pop, new age and standards',
                              pd.np.where(data_ana_corona.genre1.str.contains("k-pop"), 'pop, new age and standards',
                              pd.np.where(data_ana_corona.genre1.str.contains("carnaval"), 'pop, new age and standards',                      
                              pd.np.where(data_ana_corona.genre1.str.contains("eurovision"), 'pop, new age and standards',
                              pd.np.where(data_ana_corona.genre1.str.contains("boy band"), 'pop, new age and standards',
                              pd.np.where(data_ana_corona.genre1.str.contains("electropop"), 'pop, new age and standards',
                              pd.np.where(data_ana_corona.genre1.str.contains("neo mellow"), 'pop, new age and standards',
                              pd.np.where(data_ana_corona.genre1.str.contains("hollywood"), 'pop, new age and standards',
                              pd.np.where(data_ana_corona.genre1.str.contains("adult standards"), 'pop, new age and standards',
                        
                              pd.np.where(data_ana_corona.genre1.str.contains("rock"), 'rock, country and indie',
                              pd.np.where(data_ana_corona.genre1.str.contains("metal"), 'rock, country and indie', 
                              pd.np.where(data_ana_corona.genre1.str.contains("indie"), 'rock, country and indie',
                              pd.np.where(data_ana_corona.genre1.str.contains("country"), 'rock, country and indie',
                              pd.np.where(data_ana_corona.genre1.str.contains("cantautor"), 'rock, country and indie',
                              pd.np.where(data_ana_corona.genre1.str.contains("punk"), 'rock, country and indie',
                                          
                              pd.np.where(data_ana_corona.genre1.str.contains("latin"), 'latin and reggaeton',
                              pd.np.where(data_ana_corona.genre1.str.contains("latino"), 'latin and reggaeton',
                              pd.np.where(data_ana_corona.genre1.str.contains("bachata"), 'latin and reggaeton',                               
                              pd.np.where(data_ana_corona.genre1.str.contains("dembow"), 'latin and reggaeton',            
                              pd.np.where(data_ana_corona.genre1.str.contains("reggaeton"), 'latin and reggaeton',            
                              pd.np.where(data_ana_corona.genre1.str.contains("champeta"), 'latin and reggaeton',
                              pd.np.where(data_ana_corona.genre1.str.contains("cubaton"), 'latin and reggaeton',
                              pd.np.where(data_ana_corona.genre1.str.contains("rumba"), 'latin and reggaeton',
                              pd.np.where(data_ana_corona.genre1.str.contains("perreo"), 'latin and reggaeton',
                              pd.np.where(data_ana_corona.genre1.str.contains("flamenco"), 'latin and reggaeton',
                              pd.np.where(data_ana_corona.genre1.str.contains("salsa"), 'latin and reggaeton',
                              pd.np.where(data_ana_corona.genre1.str.contains("villancicos"), 'latin and reggaeton',
                              pd.np.where(data_ana_corona.genre1.str.contains("urbano espanol"), 'latin and reggaeton',            
                              pd.np.where(data_ana_corona.genre1.str.contains("corrido"), 'latin and reggaeton',
                              pd.np.where(data_ana_corona.genre1.str.contains("bolero"), 'latin and reggaeton',
                                          
                              pd.np.where(data_ana_corona.genre1.str.contains("hip hop"), 'hip hop, r&b and soul',            
                              pd.np.where(data_ana_corona.genre1.str.contains("rap"), 'hip hop, r&b and soul',            
                              pd.np.where(data_ana_corona.genre1.str.contains("funk"), 'hip hop, r&b and soul',            
                              pd.np.where(data_ana_corona.genre1.str.contains("trap"), 'hip hop, r&b and soul',            
                              pd.np.where(data_ana_corona.genre1.str.contains("r&b"), 'hip hop, r&b and soul',
                              pd.np.where(data_ana_corona.genre1.str.contains("soul"), 'hip hop, r&b and soul',
                                          
                                                    
                                    
                                          "other")))))))))))))))))))))))))))))))))))))))))))

# Vemos unas pruebas
# data_ana_corona[data_ana_corona['genre_depurated'] == 'dembow']
# data_ana_corona[data_ana_corona['genre_depurated'] == 'new french touch']
df_genre_final = pd.value_counts(df_genres.genre_depurated_final)
df_genre_final.head(50)
# Out:
# pop, new age and standards    237
# latin and reggaeton           223
# dance, electro and ambient    215
# hip hop, r&b and soul         132
# rock, country and indie        73
# other                          58
# Name: genre_depurated_final, dtype: int64

# %%
# FALTA AGRUPAR MÁS DE OTHER y GRUAPR MEJOR DE ROCK Y OTROS.
other = data_ana_corona[data_ana_corona['genre_depurated_final'] == 'other']
df_genre_other = pd.value_counts(other.genre1)
df_genre_other.head(60)
# df_genre_initial.count()
# Out:
# musical advocacy            3
# brostep                     3
# musica para ninos           3
# broadway                    2
# musica catalana             2
# classical performance       2
# show tunes                  2
# cancion melodica            2
# aussietronica               2
# basshall                    2
# francoton                   2
# drill espanol               2
# australian psych            1
# banda                       1
# irish pub song              1
# jawaiian                    1
# afrofuturismo brasileiro    1
# electro bailando            1
# gruperas inmortales         1
# video game music            1
# dark clubbing               1
# stomp and holler            1
# spanish new wave            1
# copla                       1
# musica jibara               1
# australian indigenous       1
# calming instrumental        1
# ska                         1
# neo-singer-songwriter       1
# cumbia                      1
# gospel                      1
# german soundtrack           1
# chilean hardcore            1
# brooklyn drill              1
# afroswing                   1
# vapor twitch                1
# circuit                     1
# permanent wave              1
# complextro                  1
# deep talent show            1
# downtempo                   1
# sleep                       1
# disco                       1
# Name: genre1, dtype: int64

# %%
number_genres_new = data_ana_corona.genre_depurated_final.value_counts()
plt.figure(figsize=(10,5)) 
number_genres_new.plot.bar()
plt.show()

# %% [markdown]
# # Juntamos dataframes de extracción canciones + extracción features + géneros

# %%
# Juntar con dataframe inicial

data_mix = pd.merge(df_streamsongs, df_features, on=['spotify_id'], how='inner')
#data_mix.rename(columns = {'Artist': 'artist'}, inplace = True)
data_mix2 = pd.merge(data_mix, data_ana_corona, on=['Artist'], how='inner')
data_mix2 = data_mix2.drop(columns=['Unnamed: 0_x', 'Unnamed: 0_y'])

# Exportar a CSV
data_mix2.to_csv("data_allyear/data_ana_timeseries_final.csv", sep = ',')
data_mix2
# Out:
#                               Track Name                   Artist  \
# 0                                   Tusa                  KAROL G
# 1                                   Tusa                  KAROL G
# 2                                   Tusa                  KAROL G
# 3                                   Tusa                  KAROL G
# 4                                   Tusa                  KAROL G
# ...                                  ...                      ...
# 285736                    One More Sleep              Leona Lewis
# 285737                    One More Sleep              Leona Lewis
# 285738     Ain't No Mountain High Enough              Marvin Gaye
# 285739  Can't Hold Us - feat. Ray Dalton  Macklemore & Ryan Lewis
# 285740                         Ave María                   Lafame
#
#         streams_song_day       date              spotify_id  year  month  \
# 0               344475.0 2020-01-01  7k4t7uLgtOxPwTpFmtJNTY  2020      1
# 1               436442.0 2020-01-02  7k4t7uLgtOxPwTpFmtJNTY  2020      1
# 2               447837.0 2020-01-03  7k4t7uLgtOxPwTpFmtJNTY  2020      1
# 3               442161.0 2020-01-04  7k4t7uLgtOxPwTpFmtJNTY  2020      1
# 4               419754.0 2020-01-05  7k4t7uLgtOxPwTpFmtJNTY  2020      1
# ...                  ...        ...                     ...   ...    ...
# 285736           26720.0 2017-12-24  78pn8k7RogKo2oxl0DyX6d  2017     12
# 285737           15876.0 2017-12-25  78pn8k7RogKo2oxl0DyX6d  2017     12
# 285738           31874.0 2017-12-31  2H3ZUSE54pST4ubRd5FzFR  2017     12
# 285739           26632.0 2017-12-31  3bidbhpOYeV4knp8AIu8Xn  2017     12
# 285740           23826.0 2017-12-31  4ESTxp7HLpplDNA2n1jhFn  2017     12
#
#         week  day year_month  streams_month  streams_year  streams_day  \
# 0          1    1 2020-01-01    472515212.0  6.399289e+09   11238605.0
# 1          1    2 2020-01-01    472515212.0  6.399289e+09   14874893.0
# 2          1    3 2020-01-01    472515212.0  6.399289e+09   15369224.0
# 3          1    4 2020-01-01    472515212.0  6.399289e+09   14592459.0
# 4          1    5 2020-01-01    472515212.0  6.399289e+09   13511143.0
# ...      ...  ...        ...            ...           ...          ...
# 285736    51   24 2017-12-01    323234736.0  3.656169e+09   13012108.0
# 285737    52   25 2017-12-01    323234736.0  3.656169e+09    8216323.0
# 285738    52   31 2017-12-01    323234736.0  3.656169e+09   13527896.0
# 285739    52   31 2017-12-01    323234736.0  3.656169e+09   13527896.0
# 285740    52   31 2017-12-01    323234736.0  3.656169e+09   13527896.0
#
#                                     name                   artist  \
# 0                                   Tusa                  KAROL G
# 1                                   Tusa                  KAROL G
# 2                                   Tusa                  KAROL G
# 3                                   Tusa                  KAROL G
# 4                                   Tusa                  KAROL G
# ...                                  ...                      ...
# 285736                    One More Sleep              Leona Lewis
# 285737                    One More Sleep              Leona Lewis
# 285738     Ain't No Mountain High Enough              Marvin Gaye
# 285739  Can't Hold Us - feat. Ray Dalton  Macklemore & Ryan Lewis
# 285740                         Ave María                   Lafame
#
#                           album release_date    length  popularity  \
# 0                          Tusa   2019-11-07  0.362231    0.905263
# 1                          Tusa   2019-11-07  0.362231    0.905263
# 2                          Tusa   2019-11-07  0.362231    0.905263
# 3                          Tusa   2019-11-07  0.362231    0.905263
# 4                          Tusa   2019-11-07  0.362231    0.905263
# ...                         ...          ...       ...         ...
# 285736     Christmas, With Love   2013-12-02  0.447901    0.726316
# 285737     Christmas, With Love   2013-12-02  0.447901    0.726316
# 285738                   United   1967-08-29  0.252901    0.000000
# 285739                The Heist   2012-10-09  0.489500    0.852632
# 285740  The Sauce (Los Remixes)   2017-12-15  0.325591    0.000000
#
#         acousticness  danceability  energy  instrumentalness  liveness  \
# 0             0.2950         0.803   0.715          0.000134    0.0574
# 1             0.2950         0.803   0.715          0.000134    0.0574
# 2             0.2950         0.803   0.715          0.000134    0.0574
# 3             0.2950         0.803   0.715          0.000134    0.0574
# 4             0.2950         0.803   0.715          0.000134    0.0574
# ...              ...           ...     ...               ...       ...
# 285736        0.4640         0.638   0.813          0.000000    0.3440
# 285737        0.4640         0.638   0.813          0.000000    0.3440
# 285738        0.4820         0.669   0.616          0.000000    0.1790
# 285739        0.0291         0.641   0.922          0.000000    0.0862
# 285740        0.1580         0.743   0.936          0.000000    0.0690
#
#         loudness  speechiness  valence     tempo  time_signature  \
# 0       0.871977     0.415621    0.574  0.476553               4
# 1       0.871977     0.415621    0.574  0.476553               4
# 2       0.871977     0.415621    0.574  0.476553               4
# 3       0.871977     0.415621    0.574  0.476553               4
# 4       0.871977     0.415621    0.574  0.476553               4
# ...          ...          ...      ...       ...             ...
# 285736  0.854105     0.050488    0.754  0.532659               4
# 285737  0.854105     0.050488    0.754  0.532659               4
# 285738  0.636535     0.046025    0.818  0.613044               4
# 285739  0.835008     0.109623    0.847  0.688667               4
# 285740  0.863277     0.110181    0.703  0.447720               4
#
#        release_date_year  Unnamed: 0        genre1     genre2  \
# 0             2019-01-01         624         latin  reggaeton
# 1             2019-01-01         624         latin  reggaeton
# 2             2019-01-01         624         latin  reggaeton
# 3             2019-01-01         624         latin  reggaeton
# 4             2019-01-01         624         latin  reggaeton
# ...                  ...         ...           ...        ...
# 285736        2013-01-01          64  british soul  dance pop
# 285737        2013-01-01          64  british soul  dance pop
# 285738        1967-01-01         207  classic soul       funk
# 285739        2012-01-01         602     dance pop        pop
# 285740        2017-01-01           9  modern salsa        NaN
#
#                       genre3         genre4           genre5         genre6  \
# 0       reggaeton colombiano    trap latino              NaN            NaN
# 1       reggaeton colombiano    trap latino              NaN            NaN
# 2       reggaeton colombiano    trap latino              NaN            NaN
# 3       reggaeton colombiano    trap latino              NaN            NaN
# 4       reggaeton colombiano    trap latino              NaN            NaN
# ...                      ...            ...              ...            ...
# 285736               europop            pop        pop dance  post-teen pop
# 285737               europop            pop        pop dance  post-teen pop
# 285738                motown  northern soul      quiet storm           soul
# 285739             pop dance        pop rap  seattle hip hop            NaN
# 285740                   NaN            NaN              NaN            NaN
#
#              genre7              genre8 genre9 genre10   10  \
# 0               NaN                 NaN    NaN     NaN  NaN
# 1               NaN                 NaN    NaN     NaN  NaN
# 2               NaN                 NaN    NaN     NaN  NaN
# 3               NaN                 NaN    NaN     NaN  NaN
# 4               NaN                 NaN    NaN     NaN  NaN
# ...             ...                 ...    ...     ...  ...
# 285736  talent show  urban contemporary    NaN     NaN  NaN
# 285737  talent show  urban contemporary    NaN     NaN  NaN
# 285738          NaN                 NaN    NaN     NaN  NaN
# 285739          NaN                 NaN    NaN     NaN  NaN
# 285740          NaN                 NaN    NaN     NaN  NaN
#
#                                           genres_together  \
# 0        latin,reggaeton,reggaeton colombiano,trap latino
# 1        latin,reggaeton,reggaeton colombiano,trap latino
# 2        latin,reggaeton,reggaeton colombiano,trap latino
# 3        latin,reggaeton,reggaeton colombiano,trap latino
# 4        latin,reggaeton,reggaeton colombiano,trap latino
# ...                                                   ...
# 285736  british soul,dance pop,europop,pop,pop dance,p...
# 285737  british soul,dance pop,europop,pop,pop dance,p...
# 285738  classic soul,funk,motown,northern soul,quiet s...
# 285739    dance pop,pop,pop dance,pop rap,seattle hip hop
# 285740                                       modern salsa
#
#                      artist_id  artist_followers  artist_popularity  \
# 0       790FomKkXshlbRYZFtlgla          14621954               0.90
# 1       790FomKkXshlbRYZFtlgla          14621954               0.90
# 2       790FomKkXshlbRYZFtlgla          14621954               0.90
# 3       790FomKkXshlbRYZFtlgla          14621954               0.90
# 4       790FomKkXshlbRYZFtlgla          14621954               0.90
# ...                        ...               ...                ...
# 285736  5lKZWd6HiSCLfnDGrq9RAm           2622267               0.73
# 285737  5lKZWd6HiSCLfnDGrq9RAm           2622267               0.73
# 285738  3koiLjNrgRTNbOwViDipeA           3813977               0.77
# 285739  5BcAKTbp20cv7tC5VqPFoC           2551450               0.79
# 285740  2ap4aQTG8zcKmzRjqlVmMd              1859               0.39
#
#              genre_depurated_final
# 0              latin and reggaeton
# 1              latin and reggaeton
# 2              latin and reggaeton
# 3              latin and reggaeton
# 4              latin and reggaeton
# ...                            ...
# 285736       hip hop, r&b and soul
# 285737       hip hop, r&b and soul
# 285738       hip hop, r&b and soul
# 285739  dance, electro and ambient
# 285740         latin and reggaeton
#
# [285741 rows x 47 columns]

# %% [markdown]
# ### Curiosidad ¿Cuántas artistas únicos y sus streams tenemos?

# %% [markdown]
# Echamos un vistazo a ver ¿Cuántos artistas únicos hay realmente? Y obtenemos una lista de los artistas que más veces han estado en el top200: en dicho periodo que seleccionamos inicialmente y en los cuatro años analizados. Vaya, parece que el "conejo malo" está a tope...

# %%
artist_unique = dataframe_extraction_timeseries.groupby('artist')['spotify_id'].nunique()
print(artist_unique.shape)
artist_unique.sort_values(ascending=False).head(20)
# Out:
# (20,)
# artist
# Vanesa Martín      1
# Stay Homas         1
# Brytiago           1
# C. Tangana         1
# Cruz Cafuné        1
# Ed Sheeran         1
# Famous Oberogo     1
# J Balvin           1
# Jonas Brothers     1
# Kidd Keo           1
# Maldita Nerea      1
# Maluma             1
# Morat              1
# Myke Towers        1
# Nio Garcia         1
# Pablo López        1
# Post Malone        1
# Sebastian Yatra    1
# Sia                1
# Alexis y Fido      1
# Name: spotify_id, dtype: int64

# %% [markdown]
# Si hacemos lo mismo con los StreamsTotal, vemos que la lista no es igual, pero Bad Bunny se mantiene y con muchos más streams. Recordamos que esto es para los años 2017-2020, juntos.

# %%
artist_streams = data_features.groupby('Artist')['Streamstotal'].sum()
print(artist_streams.shape)
artist_streams.sort_values(ascending=False).head(20)
# Out:
# (468,)
# Artist
# Bad Bunny           9700441269
# J Balvin            6934872473
# Ed Sheeran          6154283789
# Daddy Yankee        5587907352
# Ozuna               4757602534
# Luis Fonsi          4177813491
# Anuel AA            3896677449
# Nicky Jam           3626907663
# ROSALÍA             3442201554
# Maluma              3083713880
# Danny Ocean         2942923399
# Myke Towers         2739822328
# Reik                2659998345
# Rauw Alejandro      2590432117
# Sebastian Yatra     2567436006
# Don Patricio        2376027505
# Morat               2317973373
# Lunay               2274981448
# Beret               2146978341
# Enrique Iglesias    2132734096
# Name: Streamstotal, dtype: int64

# %% [markdown]
# # Primer vistazo a los datos

# %% [markdown]
# ## Correlaciones

# %% [markdown]
# Analizamos las correlaciones y parece que tienen lógica- Oor ejemplo las features Energy y Loudness tienen una correlación alta: generalmente canciones muy enérgicas suelen ser también ruidosas.

# %%
#Para ver si existen variables con corelación entre ellas.
corr_metrics = data_glo.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col2 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col4 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col5 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col6 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col7 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col8 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col9 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col10 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col11 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col12 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col13 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col14 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col15 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col16 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col17 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row0_col18 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col2 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col3 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col5 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col6 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col7 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col8 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col9 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col10 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col11 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col12 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col13 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col14 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col15 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col16 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col17 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row1_col18 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col0 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col1 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col3 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col4 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col5 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col6 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col7 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col8 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col9 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col10 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col11 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col12 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col13 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col14 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col15 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col16 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col17 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row2_col18 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row3_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row3_col1 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_4ba6280e_fa87_11ea_811d_acde48001122row3_col2 {
#             background-color:  #c2cbe2;

# %%
#ver correlación concreta entre loudness y energy
data_glo2 = data_glo.loc[:, ['loudness', 'energy']]
corr_metrics2 = data_glo2.corr()
corr_metrics2.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_d9407cfa_fa87_11ea_811d_acde48001122row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d9407cfa_fa87_11ea_811d_acde48001122row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d9407cfa_fa87_11ea_811d_acde48001122row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d9407cfa_fa87_11ea_811d_acde48001122row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_d9407cfa_fa87_11ea_811d_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >loudness</th>        <th class="col_heading level0 col1" >energy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d9407cfa_fa87_11ea_811d_acde48001122level0_row0" class="row_heading level0 row0" >loudness</th>
#                         <td id="T_d9407cfa_fa87_11ea_811d_acde48001122row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_d9407cfa_fa87_11ea_811d_acde48001122row0_col1" class="data row0 col1" >0.729552</td>
#             </tr>
#             <tr>
#                         <th id="T_d9407cfa_fa87_11ea_811d_acde48001122level0_row1" class="row_heading level0 row1" >energy</th>
#                         <td id="T_d9407cfa_fa87_11ea_811d_acde48001122row1_col0" class="data row1 col0" >0.729552</td>
#                         <td id="T_d9407cfa_fa87_11ea_811d_acde48001122row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Comparar FEATURES de cada año (sin ponderar)

# %% [markdown]
# Ploteamos en gráfico para ver la cantidad de canciones con los valores de determinadas features

# %%
data_glo_2020 = data_glo[data_glo['year'] == 2020]
data_glo_2019 = data_glo[data_glo['year'] == 2019]
data_glo_2018 = data_glo[data_glo['year'] == 2018]
data_glo_2017 = data_glo[data_glo['year'] == 2017]

feature_list = ['length','popularity', 'acousticness', 'danceability','energy', 'instrumentalness', 'liveness',
                'loudness', 'speechiness', 'valence', 'tempo']

features_2020 = data_glo_2020[feature_list]
features_2019 = data_glo_2019[feature_list]
features_2018 = data_glo_2018[feature_list]
features_2017 = data_glo_2017[feature_list]

fig, (ax1) = plt.subplots(ncols=1, figsize=(10, 8))
ax1.set_title('Comparativa Danceability 2018, 2019 y 2020')
sns.kdeplot(features_2020['danceability'], ax=ax1, color = 'blue', Label='danceability_2020')
sns.kdeplot(features_2019['danceability'], ax=ax1, color = 'black', Label='danceability_2019')
sns.kdeplot(features_2018['danceability'], ax=ax1, color = 'red', Label='danceability_2018')
sns.kdeplot(features_2017['danceability'], ax=ax1, color = 'green', Label='danceability_2017')

fig, (ax1) = plt.subplots(ncols=1, figsize=(10, 8))
ax1.set_title('Comparativa Valence 2018, 2019 y 2020')
sns.kdeplot(features_2020['valence'], ax=ax1, color = 'blue', Label='valence_2020')
sns.kdeplot(features_2019['valence'], ax=ax1, color = 'black', Label='valence_2019')
sns.kdeplot(features_2018['valence'], ax=ax1, color = 'red', Label='valence_2018')
sns.kdeplot(features_2017['valence'], ax=ax1, color = 'green', Label='valence_2017')

# %% [markdown]
# Hacemos lo mismo pero viendo las medias (ojo! sin ponderar, eso lo hacemos en el análisis mejor)

# %%
data_mean_dance_2020 = features_2020['danceability'].mean()
data_mean_dance_2019 = features_2019['danceability'].mean()
data_mean_dance_2018 = features_2018['danceability'].mean()
data_mean_dance_2017 = features_2017['danceability'].mean()
index_dance = ['danceability']

data_mean_valen_2020 = features_2020['valence'].mean()
data_mean_valen_2019 = features_2019['valence'].mean()
data_mean_valen_2018 = features_2018['valence'].mean()
data_mean_valen_2017 = features_2017['valence'].mean()
index_valen = ['valence']

df_dance = pd.DataFrame({'2017': data_mean_dance_2017,'2018': data_mean_dance_2018,'2019': data_mean_dance_2019, '2020': data_mean_dance_2020}, index=index_dance)
ax = df_dance.plot.bar(rot=0)

df_valen = pd.DataFrame({'2017': data_mean_valen_2017, '2018': data_mean_valen_2018,'2019': data_mean_valen_2019, '2020': data_mean_valen_2020}, index=index_valen)
ax = df_valen.plot.bar(rot=0)

# %% [markdown]
# Hacemos lo mismo pero probando a quitar artistas duplicados, es decir para que no se repitan muchos unos mismos artistas por canciones, auqnue vemos que es muy parecido

# %%
# 
data_glo2 = data_glo.drop_duplicates(subset=['Track Name'])
print(data_glo.shape)
print(data_glo2.shape)

data_glo2_2020 = data_glo2[data_glo2['year'] == 2020]
data_glo2_2019 = data_glo2[data_glo2['year'] == 2019]
data_glo2_2018 = data_glo2[data_glo2['year'] == 2018]
data_glo2_2017 = data_glo2[data_glo2['year'] == 2017]

feature_list2 = ['length','popularity', 'acousticness', 'danceability','energy', 'instrumentalness', 'liveness',
                'loudness', 'speechiness', 'valence', 'tempo']

features2_2020 = data_glo2_2020[feature_list2]
features2_2019 = data_glo2_2019[feature_list2]
features2_2018 = data_glo2_2018[feature_list2]
features2_2017 = data_glo2_2017[feature_list2]

data_mean2_2020 = features2_2020['valence'].mean()
data_mean2_2019 = features2_2019['valence'].mean()
data_mean2_2018 = features2_2018['valence'].mean()
data_mean2_2017 = features2_2017['valence'].mean()
index = ['valence']

df = pd.DataFrame({'2018': data_mean2_2017, '2017': data_mean2_2018, '2019': data_mean2_2019, '2020': data_mean2_2020}, index=index)
ax = df.plot.bar(rot=0)
# Out:
# (48066, 38)
# (1420, 38)

# %% [markdown]
# ## Después de la extracción de los datos de el Periodo Coronavirus y el Normal, pasamos al análisis de los datos en los otros Notebooks...en orden:
# - [Data_Analysis1_Features.ipynb](Data_Analysis1_Features.ipynb)
#
#
# **De este Notebook extraemos los siguientes CSVs que usaremos posteriormente:**
# - data_global_coronaperiod.csv
# - data_global_normalperiod.csv
