# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Cargando datasets

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

pd.set_option('display.max_columns', None)
sns.set_style("darkgrid")

# Cargamos el dataframe final de extracción, donde están todas las canciones, con duplicados (los hemos dejado
# por si utilizamos en algún momento la columna position)
data_ana = pd.read_csv("data_global.csv", sep = ',', parse_dates=['release_year'])
print(data_ana.shape)

# Quitamos las columnas que no usaremos casi seguro
data_ana= data_ana.drop(columns=['Unnamed: 0', 'Position'])
print(data_ana.shape)

# Quitamos los duplicados por canciones, no nos sirven de momento para el análisis principal.
data_ana = data_ana.drop_duplicates(subset='spotify_id').copy()
print(data_ana.shape)

#Revisamos los tipos de datos:
print(data_ana.info())
# Out:
# (48066, 38)
# (48066, 36)
# (1581, 36)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1581 entries, 0 to 48064
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Track Name         1581 non-null   object
#  1   Artist             1581 non-null   object
#  2   Streams            1581 non-null   int64
#  3   date               1581 non-null   object
#  4   spotify_id         1581 non-null   object
#  5   year               1581 non-null   int64
#  6   Streamstotal       1581 non-null   int64
#  7   album              1581 non-null   object
#  8   release_date       1581 non-null   object
#  9   length             1581 non-null   float64
#  10  popularity         1581 non-null   float64
#  11  acousticness       1581 non-null   float64
#  12  danceability       1581 non-null   float64
#  13  energy             1581 non-null   float64
#  14  instrumentalness   1581 non-null   float64
#  15  liveness           1581 non-null   float64
#  16  loudness           1581 non-null   float64
#  17  speechiness        1581 non-null   float64
#  18  valence            1581 non-null   float64
#  19  tempo              1581 non-null   float64
#  20  time_signature     1581 non-null   int64
#  21  release_year       1581 non-null   datetime64[ns]
#  22  genre1             1567 non-null   object
#  23  genre2             1383 non-null   object
#  24  genre3             1117 non-null   object
#  25  genre4             710 non-null    object
#  26  genre5             475 non-null    object
#  27  genre6             223 non-null    object
#  28  genre7             108 non-null    object
#  29  genre8             38 non-null     object
#  30  genre9             14 non-null     object
#  31  genre10            2 non-null      object
#  32  genres_together    1567 non-null   object
#  33  artist_id          1581 non-null   object
#  34  artist_followers   1581 non-null   int64
#  35  artist_popularity  1581 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(5), object(18)
# memory usage: 457.0+ KB
# None
# /Users/victormac/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (30,31,32,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## Calcular columna de pesos respecto a los streams totales para Ponderación por años

# %%
# Vamos a añadir los pesos de cada canción en una nueva columna
# Versión optimizada corta y sin warnings

data_ana_2020 = data_ana.loc[data_ana['year'] == 2020]
data_ana_2019 = data_ana.loc[data_ana['year'] == 2019]
data_ana_2018 = data_ana.loc[data_ana['year'] == 2018]
data_ana_2017 = data_ana.loc[data_ana['year'] == 2017]

data_ana.loc[data_ana.year == 2020, 'streamstotal_weights'] = data_ana_2020['Streamstotal']/data_ana_2020['Streamstotal'].sum()
data_ana.loc[data_ana.year == 2019, 'streamstotal_weights'] = data_ana_2019['Streamstotal']/data_ana_2019['Streamstotal'].sum()
data_ana.loc[data_ana.year == 2018, 'streamstotal_weights'] = data_ana_2018['Streamstotal']/data_ana_2018['Streamstotal'].sum()
data_ana.loc[data_ana.year == 2017, 'streamstotal_weights'] = data_ana_2017['Streamstotal']/data_ana_2017['Streamstotal'].sum()

# Comprobaciones
print(data_ana.shape)

# Deberían sumar 1 los pesos de cada año
print(data_ana.loc[data_ana['year'] == 2020, 'streamstotal_weights'].sum())
print(data_ana.loc[data_ana['year'] == 2019, 'streamstotal_weights'].sum())
print(data_ana.loc[data_ana['year'] == 2018, 'streamstotal_weights'].sum())
print(data_ana.loc[data_ana['year'] == 2017, 'streamstotal_weights'].sum())

#Ver cómo sale
data_ana[data_ana['Track Name'] == 'Punto G']
# Out:
# (1581, 37)
# 1.0
# 0.9999999999999999
# 1.0
# 1.0
#     Track Name   Artist  Streams        date              spotify_id  year  \
# 204    Punto G  KAROL G    51826  2019-04-05  5Lb1pjnll07UQKxNpnnGBy  2019
# 232    Punto G  KAROL G   122406  2019-05-03  2E82gORVSA7UMEz5M1IP3b  2019
#
#      Streamstotal    album release_date    length  popularity  acousticness  \
# 204       1930173  Punto G   2019-04-05  0.275291        0.62       0.00796
# 232       1151711    OCEAN   2019-05-03  0.279327        0.62       0.00938
#
#      danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 204         0.787   0.751          0.000139    0.0857  0.863559     0.091633
# 232         0.791   0.746          0.000117    0.1250  0.864281     0.097713
#
#      valence     tempo  time_signature release_year genre1     genre2  \
# 204    0.926  0.691617               4   2019-01-01  latin  latin pop
# 232    0.905  0.691837               4   2019-01-01  latin  latin pop
#
#         genre3                genre4 genre5 genre6 genre7 genre8 genre9  \
# 204  reggaeton  reggaeton colombiano    NaN    NaN    NaN    NaN    NaN
# 232  reggaeton  reggaeton colombiano    NaN    NaN    NaN    NaN    NaN
#
#     genre10                                 genres_together  \
# 204     NaN  latin,latin pop,reggaeton,reggaeton colombiano
# 232     NaN  latin,latin pop,reggaeton,reggaeton colombiano
#
#                   artist_id  artist_followers  artist_popularity  \
# 204  790FomKkXshlbRYZFtlgla          11352617           0.887755
# 232  790FomKkXshlbRYZFtlgla          11352617           0.887755
#
#      streamstotal_weights
# 204              0.002070
# 232              0.001235

# %% [markdown]
# # Genres analysis

# %%
data_ana[data_ana['genre2'] =='latin'].head(50)
# Out:
#                                               Track Name           Artist  \
# 10358                                Coronao Now (Remix)          El Alfa
# 10407                                                 4K          El Alfa
# 10468                                        Coronao Now          El Alfa
# 11160                                        Te Quemaste    Manuel Turizo
# 11221                         Quiéreme Mientras Se Pueda    Manuel Turizo
# 11229                               Esclavo de Tus Besos    Manuel Turizo
# 11290                                               Sola    Manuel Turizo
# 11351                                        Esperándote    Manuel Turizo
# 11412                                   Una Lady Como Tú    Manuel Turizo
# 11473         Una Lady Como Tú (feat. Nicky Jam) - Remix    Manuel Turizo
# 13134                                      A Dónde Vamos            Morat
# 13195                                          Presiento            Morat
# 13259                                         No Termino            Morat
# 13306                                    Cuando Nadie Ve            Morat
# 13396                                    Besos En Guerra            Morat
# 13484                           Enamórate De Alguien Más            Morat
# 13492                                    Nunca Te Olvidé            Morat
# 13504                                          Presiento            Morat
# 13532                                   Otras Se Pierden            Morat
# 13544                                        ¿Qué Ganas?            Morat
# 13545                                    Cómo Te Atreves            Morat
# 13547                                    Besos En Guerra            Morat
# 13608                                     Amor Con Hielo            Morat
# 13673  Yo Contigo, Tú Conmigo - The Gong Gong Song / ...            Morat
# 13686                                    Cómo Te Atreves            Morat
# 13763                                    Cuánto Me Duele            Morat
# 14650               4   2018-01-01  colombian pop  latin
# 14711               4   2018-01-01  colombian pop  latin
# 14741               4   2018-01-01  colombian pop  latin
# 14764               3   2019-01-01  colombian pop  latin
# 14785               4   2019-01-01  colombian pop  latin
# 14786               3   2019-01-01  colombian pop  latin
# 14792               4   2019-01-01  colombian pop  latin
# 14823               4   2019-01-01  colombian pop  latin
# 14828               4   2017-01-01  colombian pop  latin
# 14889               4   2018-01-01  colombian pop  latin
# 14950               4   2016-01-01  colombian pop  latin
# 15016               4   2018-01-01  colombian pop  latin
# 15057               4   2017-01-01  colombian pop  latin
# 15118               4   2016-01-01  colombian pop  latin
# 15179               4   2016-01-01  colombian pop  latin
# 18190               4   2019-01-01  colombian pop  latin
# 18225               4   2020-01-01  colombian pop  latin
# 18244               4   2020-01-01  colombian pop  latin
# 18270               4   2020-01-01  colombian pop  latin
# 18296               4   2020-01-01  colombian pop  latin
#
#                      genre3     genre4                genre5    genre6 genre7  \
# 10358        rap dominicano  reggaeton              tropical       NaN    NaN
# 10407        rap dominicano  reggaeton              tropical       NaN    NaN
# 10468        rap dominicano  reggaeton              tropical       NaN    NaN
# 11160             latin pop  reggaeton  reggaeton colombiano  tropical    NaN
# 11221             latin pop  reggaeton  reggaeton colombiano  tropical    NaN
# 11229             latin pop  reggaeton  reggaeton colombiano  tropical    NaN
# 11290             latin pop  reggaeton  reggaeton colombiano  tropical    NaN
# 11351             latin pop  reggaeton  reggaeton colombiano  tropical    NaN
# 11412             latin pop  reggaeton  reggaeton colombiano  tropical    NaN
# 11473             latin pop  reggaeton  reggaeton colombiano  tropical    NaN
# 13134             latin pop        NaN                   NaN       NaN    NaN
# 13195             latin pop        NaN                   NaN       NaN    NaN
# 13259             latin pop        NaN                   NaN       NaN    NaN
# 13306             latin pop        NaN                   NaN       NaN    NaN
# 13396             latin pop        NaN                   NaN       NaN    NaN
# 13484             latin pop        NaN                   NaN       NaN    NaN
# 13492             latin pop        NaN                   NaN       NaN    NaN
# 13504             latin pop        NaN                   NaN       NaN    NaN
# 13532             latin pop        NaN                   NaN       NaN    NaN
# 13544             latin pop        NaN                   NaN       NaN    NaN
# 13545             latin pop        NaN                   NaN       NaN    NaN
# 13547             latin pop        NaN                   NaN       NaN    NaN
# 13608             latin pop        NaN                   NaN       NaN    NaN
# 13673             latin pop        NaN                   NaN       NaN    NaN
# 13686             latin pop        NaN                   NaN       NaN    NaN
# 13763             latin pop        NaN                   NaN       NaN    NaN
# 14474             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14535             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14582             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14620             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14650             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14711             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14741             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14764             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14785             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14786             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14792             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14823             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14828             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14889             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 14950             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 15016             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 15057             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 15118             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 15179             latin pop  reggaeton  reggaeton colombiano       NaN    NaN
# 18190  reggaeton colombiano        NaN                   NaN       NaN    NaN
# 18225  reggaeton colombiano        NaN                   NaN       NaN    NaN
# 18244  reggaeton colombiano        NaN                   NaN       NaN    NaN
# 18270  reggaeton colombiano        NaN                   NaN       NaN    NaN
# 18296  reggaeton colombiano        NaN                   NaN       NaN    NaN
#
#       genre8 genre9 genre10  \
# 10358    NaN    NaN     NaN
# 10407    NaN    NaN     NaN
# 10468    NaN    NaN     NaN
# 11160    NaN    NaN     NaN
# 11221    NaN    NaN     NaN
# 11229    NaN    NaN     NaN
# 11290    NaN    NaN     NaN
# 11351    NaN    NaN     NaN
# 11412    NaN    NaN     NaN
# 11473    NaN    NaN     NaN
# 13134    NaN    NaN     NaN
# 13195    NaN    NaN     NaN
# 13259    NaN    NaN     NaN
# 13306    NaN    NaN     NaN
# 13396    NaN    NaN     NaN
# 13484    NaN    NaN     NaN
# 13492    NaN    NaN     NaN
# 13504    NaN    NaN     NaN
# 13532    NaN    NaN     NaN
# 13544    NaN    NaN     NaN
# 13545    NaN    NaN     NaN
# 13547    NaN    NaN     NaN
# 13608    NaN    NaN     NaN
# 13673    NaN    NaN     NaN
# 13686    NaN    NaN     NaN
# 13763    NaN    NaN     NaN
# 14474    NaN    NaN     NaN
# 14535    NaN    NaN     NaN
# 14582    NaN    NaN     NaN
# 14620    NaN    NaN     NaN
# 14650    NaN    NaN     NaN
# 14711    NaN    NaN     NaN
# 14741    NaN    NaN     NaN
# 14764    NaN    NaN     NaN
# 14785    NaN    NaN     NaN
# 14786    NaN    NaN     NaN
# 14792    NaN    NaN     NaN
# 14823    NaN    NaN     NaN
# 14828    NaN    NaN     NaN
# 14889    NaN    NaN     NaN
# 14950    NaN    NaN     NaN
# 15016    NaN    NaN     NaN
# 15057    NaN    NaN     NaN
# 15118    NaN    NaN     NaN
# 15179    NaN    NaN     NaN
# 18190    NaN    NaN     NaN
# 18225    NaN    NaN     NaN
# 18244    NaN    NaN     NaN
# 18270    NaN    NaN     NaN
# 18296    NaN    NaN     NaN
#
#                                          genres_together  \
# 10358     dembow,latin,rap dominicano,reggaeton,tropical
# 10407     dembow,latin,rap dominicano,reggaeton,tropical
# 10468     dembow,latin,rap dominicano,reggaeton,tropical
# 11160  colombian pop,latin,latin pop,reggaeton,reggae...
# 11221  colombian pop,latin,latin pop,reggaeton,reggae...
# 11229  colombian pop,latin,latin pop,reggaeton,reggae...
# 11290  colombian pop,latin,latin pop,reggaeton,reggae...
# 11351  colombian pop,latin,latin pop,reggaeton,reggae...
# 11412  colombian pop,latin,latin pop,reggaeton,reggae...
# 11473  colombian pop,latin,latin pop,reggaeton,reggae...
# 13134                      colombian pop,latin,latin pop
# 13195                      colombian pop,latin,latin pop
# 13259                      colombian pop,latin,latin pop
# 13306                      colombian pop,latin,latin pop
# 13396                      colombian pop,latin,latin pop
# 13484                      colombian pop,latin,latin pop
# 13492                      colombian pop,latin,latin pop
# 13504                      colombian pop,latin,latin pop
# 13532                      colombian pop,latin,latin pop
# 13544                      colombian pop,latin,latin pop
# 13545                      colombian pop,latin,latin pop
# 13547                      colombian pop,latin,latin pop
# 13608                      colombian pop,latin,latin pop
# 13673                      colombian pop,latin,latin pop
# 13686                      colombian pop,latin,latin pop
# 13763                      colombian pop,latin,latin pop
# 14474  colombian pop,latin,latin pop,reggaeton,reggae...
# 14535  colombian pop,latin,latin pop,reggaeton,reggae...
# 14582  colombian pop,latin,latin pop,reggaeton,reggae...
# 14620  colombian pop,latin,latin pop,reggaeton,reggae...
# 14650  colombian pop,latin,latin pop,reggaeton,reggae...
# 14711  colombian pop,latin,latin pop,reggaeton,reggae...
# 14741  colombian pop,latin,latin pop,reggaeton,reggae...
# 14764  colombian pop,latin,latin pop,reggaeton,reggae...
# 14785  colombian pop,latin,latin pop,reggaeton,reggae...
# Ozuna              28
# C. Tangana         25
# Ed Sheeran         22
#                    ..
# OneRepublic         1
# Yago Roche          1
# Chuck Berry         1
# Los del Control     1
# Los Ronaldos        1
# Name: Artist, Length: 452, dtype: int64

# %%
number_genres = data_ana.genre1.value_counts()
number_genres.head(60)
# Out:
# latin                        380
# dance pop                    199
# colombian pop                 83
# latin pop                     72
# pop                           60
# trap espanol                  56
# cantautor                     54
# spanish pop                   50
# latin arena pop               34
# big room                      31
# r&b en espanol                28
# canadian contemporary r&b     22
# argentine hip hop             21
# latin viral pop               20
# electropop                    20
# canadian hip hop              19
# flamenco urbano               18
# dominican pop                 16
# rap espanol                   16
# modern rock                   15
# dfw rap                       13
# eurovision                    13
# boy band                      12
# conscious hip hop             12
# panamanian pop                11
# garage rock                   11
# champeta                      11
# canadian pop                  11
# trap latino                   10
# cubaton                        9
# puerto rican pop               9
# emo rap                        9
# dembow                         9
# electro latino                 9
# bachata                        9
# k-pop                          8
# edm                            8
# rap                            7
# latin talent show              7
# atl hip hop                    7
# reggaeton flow                 6
# australian dance               6
# classic rock                   6
# alternative r&b                6
# carnaval cadiz                 6
# art pop                        6
# electro house                  6
# brostep                        5
# colombian hip hop              4
# hip hop                        4
# melodic rap                    4
# funk carioca                   4
# new french touch               3
# brazilian edm                  3
# danish pop                     3
# neo mellow                     3
# rumba                          3
# rap catalan                    3
# reggaeton colombiano           3
# venezuelan hip hop             2
# Name: genre1, dtype: int64

# %%
# Para depurar el genre, los que el genre1 sea latin, se les asignará el valor en genre2, que es más específico
# y los que el genre1 no sea latin se les asignara ese genre1
data_ana_nolatinfirst = data_ana[data_ana['genre1'] != 'latin']
data_ana_latinfirst = data_ana[data_ana['genre1'] == 'latin']

data_ana.loc[data_ana.genre1 == 'latin', 'genre_final'] = data_ana_latinfirst['genre2']
data_ana.loc[data_ana.genre2 == 'latin pop', 'genre_final'] = data_ana_latinfirst['genre3']
data_ana.loc[data_ana.genre1 != 'latin', 'genre_final'] = data_ana_nolatinfirst['genre1']

# %%
number_genres_new = data_ana.genre_final.value_counts()
number_genres_new.head(60)
# Out:
# dance pop                    199
# reggaeton                    148
# latin hip hop                 90
# colombian pop                 83
# latin arena pop               75
# latin pop                     72
# pop                           60
# trap espanol                  56
# spanish pop                   55
# cantautor                     54
# puerto rican pop              47
# r&b en espanol                41
# big room                      31
# canadian contemporary r&b     22
# latin viral pop               22
# argentine hip hop             21
# electropop                    20
# canadian hip hop              19
# flamenco urbano               18
# reggaeton flow                18
# pop venezolano                17
# dominican pop                 16
# rap espanol                   16
# modern rock                   15
# dfw rap                       13
# eurovision                    13
# conscious hip hop             12
# boy band                      12
# panamanian pop                11
# canadian pop                  11
# champeta                      11
# garage rock                   11
# trap latino                   10
# bachata                        9
# emo rap                        9
# cubaton                        9
# electro latino                 9
# dembow                         9
# edm                            8
# k-pop                          8
# atl hip hop                    7
# latin talent show              7
# rap                            7
# classic rock                   6
# art pop                        6
# australian dance               6
# alternative r&b                6
# electro house                  6
# carnaval cadiz                 6
# brostep                        5
# melodic rap                    4
# rap latina                     4
# hip hop                        4
# funk carioca                   4
# colombian hip hop              4
# new french touch               3
# neo mellow                     3
# reggaeton colombiano           3
# rap catalan                    3
# latin alternative              3
# Name: genre_final, dtype: int64

# %%
#Tras un análisis por géneros, es complicado, porque el primer género listado no distingue bien
# Si encuentra latin, pasa a la siguiente columna y busca por los otros términos y así sicesivamente

list_genres_pop = 'k-pop, pop, boy band, eurovision'
list_genres_dancepop = 'dance, tropical, edm, electropop, big room'
list_genres_rock = 'rock, indie'
reggaeton = 'dembow, reggaeton, champeta'
list_genres_rap = 'hip hop, rap, funk, trap, r&b'
cantautor = 'cantautor, flamenco'

'''
list_genres_pop = ['k-pop', 'pop', 'boy band', 'eurovision']
list_genres_dancepop = ['dance', 'tropical', 'edm', 'electropop', 'big room']
list_genres_rock = ['rock', 'indie']
reggaeton = ['dembow', 'reggaeton', 'champeta']
list_genres_rap = ['hip hop', 'rap', 'funk', 'trap', 'r&b']
cantautor = ['cantautor','flamenco']'''
# Out:
# "\nlist_genres_pop = ['k-pop', 'pop', 'boy band', 'eurovision']\nlist_genres_dancepop = ['dance', 'tropical', 'edm', 'electropop', 'big room']\nlist_genres_rock = ['rock', 'indie']\nreggaeton = ['dembow', 'reggaeton', 'champeta']\nlist_genres_rap = ['hip hop', 'rap', 'funk', 'trap', 'r&b']\ncantautor = ['cantautor','flamenco']"

# %%
data_ana['genre_depurated'] = pd.np.where(data_ana.genre_final.str.contains("dance"), 'dance, tropical, edm, electropop, big room',
                              pd.np.where(data_ana.genre_final.str.contains("tropical"), 'dance, tropical, edm, electropop, big room',            
                              pd.np.where(data_ana.genre_final.str.contains("edm"), 'dance, tropical, edm, electropop, big room',
                              pd.np.where(data_ana.genre_final.str.contains("electropop"), 'dance, tropical, edm, electropop, big room',
                              pd.np.where(data_ana.genre_final.str.contains("big room"), 'dance, tropical, edm, electropop, big room',
                                          
                              pd.np.where(data_ana.genre_final.str.contains("pop"), 'pop, k-pop, boy band, eurovision, carnaval',
                              pd.np.where(data_ana.genre_final.str.contains("k-pop"), 'pop, k-pop, boy band, eurovision, carnaval',
                              pd.np.where(data_ana.genre_final.str.contains("carnaval"), 'pop, k-pop, boy band, eurovision, carnaval',                      
                              pd.np.where(data_ana.genre_final.str.contains("eurovision"), 'pop, k-pop, boy band, eurovision, carnaval',
                              pd.np.where(data_ana.genre_final.str.contains("boy band"), 'pop, k-pop, boy band, eurovision, carnaval',
                        
                              pd.np.where(data_ana.genre_final.str.contains("rock"), 'rock, indie',            
                              pd.np.where(data_ana.genre_final.str.contains("indie"), 'rock, indie',
                                          
                              pd.np.where(data_ana.genre_final.str.contains("bachata"), 'dembow, reggaeton, champeta, cubaton',                               
                              pd.np.where(data_ana.genre_final.str.contains("dembow"), 'dembow, reggaeton, champeta, cubaton',            
                              pd.np.where(data_ana.genre_final.str.contains("reggaeton"), 'dembow, reggaeton, champeta, cubaton',            
                              pd.np.where(data_ana.genre_final.str.contains("champeta"), 'dembow, reggaeton, champeta, cubaton',
                              pd.np.where(data_ana.genre_final.str.contains("cubaton"), 'dembow, reggaeton, champeta, cubaton',
                                          
                              pd.np.where(data_ana.genre_final.str.contains("hip hop"), "rap, hip hop, funk, trap, r&b",            
                              pd.np.where(data_ana.genre_final.str.contains
# 16845                            dembow,dominican pop  7mcJN2bWqCv7jvykgHp4KN
# 27049             dembow,dominican pop,rap dominicano  5UopXhshFFqRIMfeZrBclq
# 27085             dembow,dominican pop,rap dominicano  5UopXhshFFqRIMfeZrBclq
# 34896             dembow,dominican pop,rap dominicano  0odliLZMTk45CEVzF3Zocl
#
#        artist_followers  artist_popularity  streamstotal_weights genre_final  \
# 10358           1088494           0.846939              0.002806      dembow
# 10407           1088494           0.846939              0.003995      dembow
# 10468           1088494           0.846939              0.000398      dembow
# 13872            205737           0.704082              0.003469      dembow
# 13933            205737           0.704082              0.004798      dembow
# 16845             64455           0.581633              0.002912      dembow
# 27049             62214           0.602041              0.001127      dembow
# 27085             62214           0.602041              0.002033      dembow
# 34896            254727           0.704082              0.002019      dembow
#
#                             genre_depurated
# 10358  dembow, reggaeton, champeta, cubaton
# 10407  dembow, reggaeton, champeta, cubaton
# 10468  dembow, reggaeton, champeta, cubaton
# 13872  dembow, reggaeton, champeta, cubaton
# 13933  dembow, reggaeton, champeta, cubaton
# 16845  dembow, reggaeton, champeta, cubaton
# 27049  dembow, reggaeton, champeta, cubaton
# 27085  dembow, reggaeton, champeta, cubaton
# 34896  dembow, reggaeton, champeta, cubaton

# %%
number_genres2 = data_ana.genre_depurated.value_counts()
number_genres2.head(60)
# Out:
# pop, k-pop, boy band, eurovision, carnaval    536
# rap, hip hop, funk, trap, r&b                 370
# dance, tropical, edm, electropop, big room    288
# dembow, reggaeton, champeta, cubaton          207
# cantautor, flamenco                            72
# other                                          68
# rock, indie                                    40
# Name: genre_depurated, dtype: int64

# %%
#Total reproducciones 
data_group = data_ana.groupby(['genre_depurated']).agg(['sum', 'count'])
data_group['year']
#Falta hacerlo por ponderación con reproducciones
# Out:
#                                                 sum  count
# genre_depurated
# cantautor, flamenco                          145347     72
# dance, tropical, edm, electropop, big room   581235    288
# dembow, reggaeton, champeta, cubaton         417920    207
# other                                        137242     68
# pop, k-pop, boy band, eurovision, carnaval  1081925    536
# rap, hip hop, funk, trap, r&b                746908    370
# rock, indie                                   80717     40

# %%
data_group2 = data_group['Streamstotal']
data_group2.reset_index(inplace=True)
data_group2
# Out:
#                                genre_depurated  year        sum  count
# 0                          cantautor, flamenco  2017    5221747     15
# 1                          cantautor, flamenco  2018    6227040     15
# 2                          cantautor, flamenco  2019   12690328     18
# 3                          cantautor, flamenco  2020   50571544     24
# 4   dance, tropical, edm, electropop, big room  2017  132569316     96
# 5   dance, tropical, edm, electropop, big room  2018  137286328     87
# 6   dance, tropical, edm, electropop, big room  2019  138854616     63
# 7   dance, tropical, edm, electropop, big room  2020   82875835     42
# 8         dembow, reggaeton, champeta, cubaton  2017   54433879     35
# 9         dembow, reggaeton, champeta, cubaton  2018  101271842     32
# 10        dembow, reggaeton, champeta, cubaton  2019  173969882     51
# 11        dembow, reggaeton, champeta, cubaton  2020  357515126     89
# 12                                       other  2017   27022029     24
# 13                                       other  2018   14277073     15
# 14                                       other  2019   35092157     16
# 15                                       other  2020   15894422     13
# 16  pop, k-pop, boy band, eurovision, carnaval  2017  128309178    127
# 17  pop, k-pop, boy band, eurovision, carnaval  2018  273080559    135
# 18  pop, k-pop, boy band, eurovision, carnaval  2019  331547451    144
# 19  pop, k-pop, boy band, eurovision, carnaval  2020  357435012    130
# 20               rap, hip hop, funk, trap, r&b  2017   68913953     71
# 21               rap, hip hop, funk, trap, r&b  2018  168010492    103
# 22               rap, hip hop, funk, trap, r&b  2019  235355760     73
# 23               rap, hip hop, funk, trap, r&b  2020  251326575    123
# 24                                 rock, indie  2017    6829464     16
# 25                                 rock, indie  2018    3633433     14
# 26                                 rock, indie  2019    4997683      7
# 27                                 rock, indie  2020    4755101      3

# %%
data_group = data_ana.groupby(['genre_depurated', 'year']).agg(['sum', 'count'])
data_group2 = data_group['Streamstotal']
data_group2.reset_index(inplace=True)
sns.factorplot(x='year', y='sum', hue='genre_depurated', data=data_group2, kind='bar')
# Out:
# /Users/victormac/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
data_group = data_ana.groupby(['genre_depurated', 'year']).agg(['sum', 'count'])
data_group['Streamstotal']
# Out:
#                                                        sum  count
# genre_depurated                            year
# cantautor, flamenco                        2017    5221747     15
#                                            2018    6227040     15
#                                            2019   12690328     18
#                                            2020   50571544     24
# dance, tropical, edm, electropop, big room 2017  132569316     96
#                                            2018  137286328     87
#                                            2019  138854616     63
#                                            2020   82875835     42
# dembow, reggaeton, champeta, cubaton       2017   54433879     35
#                                            2018  101271842     32
#                                            2019  173969882     51
#                                            2020  357515126     89
# other                                      2017   27022029     24
#                                            2018   14277073     15
#                                            2019   35092157     16
#                                            2020   15894422     13
# pop, k-pop, boy band, eurovision, carnaval 2017  128309178    127
#                                            2018  273080559    135
#                                            2019  331547451    144
#                                            2020  357435012    130
# rap, hip hop, funk, trap, r&b              2017   68913953     71
#                                            2018  168010492    103
#                                            2019  235355760     73
#                                            2020  251326575    123
# rock, indie                                2017    6829464     16
#                                            2018    3633433     14
#                                            2019    4997683      7
#                                            2020    4755101      3

# %%
data_old_1959_2014 = data_old[data_old.release_year.between(fecha_1, fecha_2)]
sns.factorplot(x='year', y='Streamstotal', hue='release_year', data=data_old_1959_2014, kind='bar')

# %%
data_group3 = data_ana.groupby(['genre1', 'year']).agg(['sum', 'count'])
data_group3['Streamstotal'].sort_values(by='count', ascending=False)
# Out:
#                                sum  count
# genre1             year
# latin              2020  464763574    121
#                    2019  362823182     99
#                    2018  287218756     83
#                    2017  111362949     77
# dance pop          2017  103763118     75
# ...                            ...    ...
# dancehall          2017    5726377      1
# czech pop          2018     108262      1
# cumbia             2018    1492895      1
# cubaton            2020     874083      1
# venezuelan hip hop 2020     764827      1
#
# [234 rows x 2 columns]

# %%
data_group4 = data_ana.groupby(['genre1', 'year']).agg(['sum', 'count'])
data_group5 = data_group4['Streamstotal']
data_group5.reset_index(inplace=True)
sns.factorplot(x='year', y='sum', hue='genre1', data=data_group5, kind='bar')

# %%
data_ana[data_ana['genre_depurated'] == 'dembow, reggaeton, champeta, cubaton']
# Out:
#                                               Track Name         Artist  \
# 0                                                   Tusa        KAROL G
# 61                                                Follow        KAROL G
# 103                                               Créeme        KAROL G
# 153                                            Culpables        KAROL G
# 46419    0.0982  0.851609     0.067458    0.384  0.758591               4
# 47900    0.0771  0.831550     0.166184    0.681  0.785015               4
#
#           genre1          genre2     genre3                genre4 genre5  \
# 0          latin       latin pop  reggaeton  reggaeton colombiano    NaN
# 61         latin       latin pop  reggaeton  reggaeton colombiano    NaN
# 103        latin       latin pop  reggaeton  reggaeton colombiano    NaN
# 153        latin       latin pop  reggaeton  reggaeton colombiano    NaN
# 203        latin       latin pop  reggaeton  reggaeton colombiano    NaN
# ...          ...             ...        ...                   ...    ...
# 46155  reggaeton             NaN        NaN                   NaN    NaN
# 46297    cubaton       reggaeton   tropical                   NaN    NaN
# 46358    cubaton        tropical        NaN                   NaN    NaN
# 46419    cubaton        tropical        NaN                   NaN    NaN
# 47900  reggaeton  reggaeton flow        NaN                   NaN    NaN
#
#       genre6 genre7 genre8 genre9 genre10  \
# 0        NaN    NaN    NaN    NaN     NaN
# 61       NaN    NaN    NaN    NaN     NaN
# 103      NaN    NaN    NaN    NaN     NaN
# 153      NaN    NaN    NaN    NaN     NaN
# 203      NaN    NaN    NaN    NaN     NaN
# ...      ...    ...    ...    ...     ...
# 46155    NaN    NaN    NaN    NaN     NaN
# 46297    NaN    NaN    NaN    NaN     NaN
# 46358    NaN    NaN    NaN    NaN     NaN
# 46419    NaN    NaN    NaN    NaN     NaN
# 47900    NaN    NaN    NaN    NaN     NaN
#
#                                       genres_together               artist_id  \
# 0      latin,latin pop,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 61     latin,latin pop,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 103    latin,latin pop,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 153    latin,latin pop,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# 203    latin,latin pop,reggaeton,reggaeton colombiano  790FomKkXshlbRYZFtlgla
# ...                                               ...                     ...
# 46155                                       reggaeton  3HPOnbuwLP2qlwWQ7cgxYW
# 46297                      cubaton,reggaeton,tropical  0b2GL7Y02vu50qieoQmw1w
# 46358                                cubaton,tropical  4fCRFHEQgjqakvFgQCliMp
# 46419                                cubaton,tropical  4fCRFHEQgjqakvFgQCliMp
# 47900                        reggaeton,reggaeton flow  62lbdm09j0QUbWB7SqCJvt
#
#        artist_followers  artist_popularity  streamstotal_weights genre_final  \
# 0              11337789           0.887755              0.016786   reggaeton
# 61             11337789           0.887755              0.006258   reggaeton
# 103            11337789           0.887755              0.003430   reggaeton
# 153            11337789           0.887755              0.002232   reggaeton
# 203            11337789           0.887755              0.002071   reggaeton
# ...                 ...                ...                   ...         ...
# 46155            167636           0.540816              0.011897   reggaeton
# 46297             43986           0.591837              0.012278     cubaton
# 46358            128729           0.612245              0.004282     cubaton
# 46419            128729           0.612245              0.001188     cubaton
# 47900            129026           0.581633              0.000387   reggaeton
#
#                             genre_depurated
# 0      dembow, reggaeton, champeta, cubaton
# 61     dembow, reggaeton, champeta, cubaton
# 103    dembow, reggaeton, champeta, cubaton
# 153    dembow, reggaeton, champeta, cubaton
# 203    dembow, reggaeton, champeta, cubaton
# ...                                     ...
# 46155  dembow, reggaeton, champeta, cubaton
# 46297  dembow, reggaeton, champeta, cubaton
# 46358  dembow, reggaeton, champeta, cubaton
# 46419  dembow, reggaeton, champeta, cubaton
# 47900  dembow, reggaeton, champeta, cubaton
#
# [207 rows x 38 columns]
